# %%
import sys, os, json, random
import torch
import sys
import datetime

import cv2

import numpy as np
import pandas as pd

import skimage.io as io

import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = [16,9]
# %matplotlib inline

from shapely.geometry import Polygon

# path to the images
data_dir = "C:/Users/kurt_/car-parts-and-damage-detection/car-part-detection/car-part/File1"

# create paths for traininig and validaiton data
os.makedirs("C:/Users/kurt_/car-parts-and-damage-detection/car-part-detection/working/data/", exist_ok=True)
os.makedirs("C:/Users/kurt_/car-parts-and-damage-detection/car-part-detection/working/data/train/", exist_ok=True)
os.makedirs("C:/Users/kurt_/car-parts-and-damage-detection/car-part-detection/working/data/val/", exist_ok=True)


# create path to store the model config
os.makedirs("C:/Users/kurt_/car-parts-and-damage-detection/car-part-detection/working/model/", exist_ok=True)

data_working_dir = "C:/Users/kurt_/car-parts-and-damage-detection/car-part-detection/working/data/"
model_dir = "C:/Users/kurt_/car-parts-and-damage-detection/car-part-detection/working/model/"

# %%
import json
import os
import shutil
import random
from PIL import Image

# Paths to your dataset
images_dir = os.path.join(data_dir, "img")
annotations_dir = os.path.join(data_dir, "ann")

# Get list of images
images = [f for f in os.listdir(images_dir) if os.path.isfile(os.path.join(images_dir, f))]

# Shuffle the images
random.shuffle(images)

# Split the dataset (e.g., 80% train, 20% val)
split_index = int(0.8 * len(images))
train_images = images[:split_index]
val_images = images[split_index:]

def convert_to_coco(images, images_dir, annotations_dir, output_dir):
    coco_output = {
        "images": [],
        "annotations": [],
        "categories": []
    }

    category_mapping = {
        "Quarter-panel": 1,
        "Front-wheel": 2,
        "Back-window": 3,
        "Trunk": 4,
        "Front-door": 5,
        "Rocker-panel": 6,
        "Grille": 7,
        "Windshield": 8,
        "Front-window": 9,
        "Back-door": 10,
        "Headlight": 11,
        "Back-wheel": 12,
        "Back-windshield": 13,
        "Hood": 14,
        "Fender": 15,
        "Tail-light": 16,
        "License-plate": 17,
        "Front-bumper": 18,
        "Back-bumper": 19,
        "Mirror": 20,
        "Roof": 21
    }

    for category, id in category_mapping.items():
        coco_output["categories"].append({
            "id": id,
            "name": category
        })

    annotation_id = 1
    for idx, image_filename in enumerate(images):
        image_path = os.path.join(images_dir, image_filename)
        annotation_path = os.path.join(annotations_dir, image_filename + ".json")
        
        # Copy the image to the output directory
        shutil.copy(image_path, output_dir)
        
        # Open the image to get its dimensions
        with Image.open(image_path) as img:
            width, height = img.size
        
        coco_output["images"].append({
            "file_name": image_filename,
            "height": height,
            "width": width,
            "id": idx
        })
        
        with open(annotation_path) as f:
            objs = json.load(f)["objects"]

        for obj in objs:
            px = [point[0] for point in obj["points"]["exterior"]]
            py = [point[1] for point in obj["points"]["exterior"]]
            poly = [(x, y) for x, y in zip(px, py)]
            poly = [p for x in poly for p in x]

            category_id = category_mapping.get(obj["classTitle"], -1)
            if category_id == -1:
                continue  # Skip unknown categories
            
            bbox = [min(px), min(py), max(px) - min(px), max(py) - min(py)]
            
            coco_output["annotations"].append({
                "bbox": bbox,
                "category_id": category_id,
                "image_id": idx,
                "segmentation": [poly],
                "area": bbox[2] * bbox[3],
                "iscrowd": 0,
                "id": annotation_id
            })
            annotation_id += 1

    return coco_output

train_output = convert_to_coco(train_images, images_dir, annotations_dir, os.path.join(data_working_dir, "train"))
val_output = convert_to_coco(val_images, images_dir, annotations_dir, os.path.join(data_working_dir, "val"))

with open(os.path.join(data_working_dir, "train", "annotations.json"), "w") as f:
    json.dump(train_output, f, indent=4)

with open(os.path.join(data_working_dir, "val", "annotations.json"), "w") as f:
    json.dump(val_output, f, indent=4)

print("COCO annotations for train and val sets have been created.")
# Out:
# COCO annotations for train and val sets have been created.

# %%
from detectron2.data.datasets import register_coco_instances

# Register train and val datasets
register_coco_instances("car_train", {}, os.path.join(data_working_dir, "train", "annotations.json"), os.path.join(data_working_dir, "train"))
register_coco_instances("car_val", {}, os.path.join(data_working_dir, "val", "annotations.json"), os.path.join(data_working_dir, "val"))

# Load metadata
from detectron2.data import MetadataCatalog
car_metadata = MetadataCatalog.get("car_train")

# %%
import random
from detectron2.utils.visualizer import Visualizer
from detectron2.data import DatasetCatalog

dataset_dicts = DatasetCatalog.get("car_train")
for d in random.sample(dataset_dicts, 3):
    img = cv2.imread(d["file_name"])
    visualizer = Visualizer(img[:, :, ::-1], metadata=car_metadata, scale=0.5)
    vis = visualizer.draw_dataset_dict(d)
    plt.imshow(vis.get_image()[:, :, ::-1])
    plt.show()

# %%
import os
import torch
import detectron2
import datetime
from detectron2.engine import DefaultTrainer, hooks, HookBase
from detectron2.config import get_cfg
from detectron2 import model_zoo

# Define output directory
output_dir = "./output_" + datetime.datetime.now().strftime('%Y%m%d_%H%M%S')

# Create configuration
cfg = get_cfg()

# Set output directory
cfg.OUTPUT_DIR = output_dir

# Merge configuration from the model zoo
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))

# Set training and testing datasets
cfg.DATASETS.TRAIN = ("car_train",)
cfg.DATASETS.TEST = ("car_val",)  # for evaluation during training
cfg.DATALOADER.NUM_WORKERS = 4

# Set device to cuda if available
cfg.MODEL.DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'

# Set weights from the model zoo
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml")  # Let training initialize from model zoo

# Set batch size, learning rate, and maximum iterations
cfg.SOLVER.IMS_PER_BATCH = 4
cfg.SOLVER.BASE_LR = 0.00025
cfg.SOLVER.MAX_ITER = 3000  # Increase the maximum number of iterations
cfg.SOLVER.STEPS = []  # do not decay learning rate

# Set batch size per image and number of classes
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 8   # images used to calculate cls and reg loss during training.
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 21  # total number of classes

# Create output directory if it does not exist
os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)

# Custom Trainer to add hooks for status updates
class MyTrainer(DefaultTrainer):
    @classmethod
    def build_evaluator(cls, cfg, dataset_name, output_folder=None):
        from detectron2.evaluation import COCOEvaluator, inference_on_dataset, print_csv_format
        return COCOEvaluator(dataset_name, cfg, False, output_folder)

    def build_hooks(self):
        hooks = super().build_hooks()
        hooks.insert(0, PrintTrainingStatus())
        return hooks

# Custom hook to print training status
class PrintTrainingStatus(HookBase):
    def after_step(self):
        # Print training status every 100 iterations
        if self.trainer.iter % 500 == 0 or self.trainer.iter == self.trainer.max_iter:
            print(f"Iteration {self.trainer.iter}/{self.trainer.max_iter} - Loss: {self.trainer.storage.latest()['total_loss']}")

# Create a trainer
trainer = MyTrainer(cfg)

# Load the model or resume training
trainer.resume_or_load(resume=False)

# Train the model
trainer.train()
# Out:
# [10/12 18:17:52 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=22, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=84, bias=True)
#     )
#     (mask_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(14, 14), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(14, 14), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(14, 14), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(14, 14), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (mask_head): MaskRCNNConvUpsampleHead(
#       (mask_fcn1): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn2): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn3): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn4): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (deconv): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#       (deconv_relu): ReLU()
#       (predictor): Conv2d(256, 21, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )
# [10/12 18:17:52 d2.data.datasets.coco]: Loaded 798 images in COCO format from C:/Users/kurt_/car-parts-and-damage-detection/car-part-detection/working/data/train\annotations.json
# [10/12 18:17:52 d2.data.build]: Removed 0 images with no usable annotations. 798 images left.
# [10/12 18:17:52 d2.data.build]: Distribution of instances among all 21 categories:
# |   category    | #instances   |   category    | #instances   |   category   | #instances   |
# |:-------------:|:-------------|:-------------:|:-------------|:------------:|:-------------|
# | Quarter-panel | 682          |  Front-wheel  | 709          | Back-window  | 1003         |
# |     Trunk     | 331          |  Front-door   | 734          | Rocker-panel | 694          |
# |    Grille     | 456          |  Windshield   | 501          | Front-window | 756          |
# |   Back-door   | 579          |   Headlight   | 722          |  Back-wheel  | 692          |
# | Back-windsh.. | 220          |     Hood      | 565          |    Fender    | 749          |
# |  Tail-light   | 589          | License-plate | 293          | Front-bumper | 563          |
# |  Back-bumper  | 357          |    Mirror     | 782          |     Roof     | 634          |
# |               |              |               |              |              |              |
# |     total     | 12611        |               |              |              |              |
# [10/12 18:17:52 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [10/12 18:17:52 d2.data.build]: Using training sampler TrainingSampler
# [10/12 18:17:52 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [10/12 18:17:52 d2.data.common]: Serializing 798 elements to byte tensors and concatenating them all ...
# [10/12 18:17:52 d2.data.common]: Serialized dataset takes 6.07 MiB
# [10/12 18:17:52 d2.data.build]: Making batched data loader with batch_size=4
# [10/12 18:17:52 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x/137849600/model_final_f10217.pkl ...
# Skip loading parameter 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (22, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (22,) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 1024) in the checkpoint but (84, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (84,) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.mask_head.predictor.weight' to the model due to incompatible shapes: (80, 256, 1, 1) in the checkpoint but (21, 256, 1, 1) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.mask_head.predictor.bias' to the model due to incompatible shapes: (80,) in the checkpoint but (21,) in the model! You might want to double check if this is expected.
# Some model parameters or buffers are not found in the checkpoint:
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# roi_heads.mask_head.predictor.{bias, weight}
# [10/12 18:17:52 d2.engine.train_loop]: Starting training from iteration 0
# C:\Users\kurt_\anaconda3\envs\my-env-detectron2\lib\site-packages\torch\functional.py:513: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\TensorShape.cpp:3610.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Iteration 0/3000 - Loss: (7.535756230354309, 0)
# [10/12 18:18:58 d2.utils.events]:  eta: 0:29:38  iter: 19  total_loss: 6.611  loss_cls: 3.217  loss_box_reg: 0.7279  loss_mask: 0.6937  loss_rpn_cls: 1.701  loss_rpn_loc: 0.2544    time: 3.3127  last_time: 9.8669  data_time: 0.1763  last_data_time: 0.0038   lr: 4.9953e-06  max_mem: 4239M
# [10/12 18:20:14 d2.utils.events]:  eta: 0:29:46  iter: 39  total_loss: 6.027  loss_cls: 3.104  loss_box_reg: 0.815  loss_mask: 0.6931  loss_rpn_cls: 1.218  loss_rpn_loc: 0.2429    time: 3.5442  last_time: 9.1714  data_time: 0.0042  last_data_time: 0.0051   lr: 9.9902e-06  max_mem: 4239M
# [10/12 18:21:44 d2.utils.events]:  eta: 0:29:34  iter: 59  total_loss: 5.406  loss_cls: 2.919  loss_box_reg: 0.8039  loss_mask: 0.6924  loss_rpn_cls: 0.7187  loss_rpn_loc: 0.2009    time: 3.8850  last_time: 0.6002  data_time: 0.0039  last_data_time: 0.0031   lr: 1.4985e-05  max_mem: 4239M
# [10/12 18:23:12 d2.utils.events]:  eta: 0:29:34  iter: 79  total_loss: 4.92  loss_cls: 2.587  loss_box_reg: 0.8577  loss_mask: 0.6919  loss_rpn_cls: 0.4777  loss_rpn_loc: 0.2274    time: 4.0072  last_time: 10.3794  data_time: 0.0042  last_data_time: 0.0048   lr: 1.998e-05  max_mem: 4239M
# [10/12 18:24:36 d2.utils.events]:  eta: 0:29:20  iter: 99  total_loss: 4.249  loss_cls: 2.209  loss_box_reg: 0.7929  loss_mask: 0.6913  loss_rpn_cls: 0.3225  loss_rpn_loc: 0.2227    time: 4.0481  last_time: 11.5925  data_time: 0.0042  last_data_time: 0.0042   lr: 2.4975e-05  max_mem: 4239M
# [10/12 18:25:16 d2.utils.events]:  eta: 0:28:58  iter: 119  total_loss: 3.67  loss_cls: 1.725  loss_box_reg: 0.9375  loss_mask: 0.6898  loss_rpn_cls: 0.2132  loss_rpn_loc: 0.2154    time: 3.7071  last_time: 0.5405  data_time: 0.0041  last_data_time: 0.0050   lr: 2.997e-05  max_mem: 4239M
# [10/12 18:26:36 d2.utils.events]:  eta: 0:28:39  iter: 139  total_loss: 3.307  loss_cls: 1.398  loss_box_reg: 0.879  loss_mask: 0.6896  loss_rpn_cls: 0.1314  loss_rpn_loc: 0.1866    time: 3.7466  last_time: 0.6047  data_time: 0.0040  last_data_time: 0.0035   lr: 3.4965e-05  max_mem: 4239M
# [10/12 18:28:28 d2.utils.events]:  eta: 0:28:38  iter: 159  total_loss: 3.174  loss_cls: 1.328  loss_box_reg: 0.8618  loss_mask: 0.6873  loss_rpn_cls: 0.1252  loss_rpn_loc: 0.204    time: 3.9812  last_time: 5.9183  data_time: 0.0040  last_data_time: 0.0048   lr: 3.996e-05  max_mem: 4240M
# [10/12 18:29:51 d2.utils.events]:  eta: 0:28:37  iter: 179  total_loss: 3.291  loss_cls: 1.318  loss_box_reg: 0.9383  loss_mask: 0.6857  loss_rpn_cls: 0.1444  loss_rpn_loc: 0.2177    time: 3.9974  last_time: 10.3929  data_time: 0.0041  last_data_time: 0.0043   lr: 4.4955e-05  max_mem: 4240M
# [10/12 18:31:23 d2.utils.events]:  eta: 0:29:09  iter: 199  total_loss: 3.129  loss_cls: 1.283  loss_box_reg: 0.8622  loss_mask: 0.6852  loss_rpn_cls: 0.09861  loss_rpn_loc: 0.1636    time: 4.0596  last_time: 9.0168  data_time: 0.0037  last_data_time: 0.0029   lr: 4.995e-05  max_mem: 4240M
# [10/12 18:33:02 d2.utils.events]:  eta: 0:29:02  iter: 219  total_loss: 3.142  loss_cls: 1.246  loss_box_reg: 0.8584  loss_mask: 0.681  loss_rpn_cls: 0.1065  loss_rpn_loc: 0.1987    time: 4.1416  last_time: 10.2750  data_time: 0.0042  last_data_time: 0.0036   lr: 5.4945e-05  max_mem: 4240M
# [10/12 18:33:49 d2.utils.events]:  eta: 0:28:08  iter: 239  total_loss: 3.096  loss_cls: 1.242  loss_box_reg: 0.8735  loss_mask: 0.6792  loss_rpn_cls: 0.106  loss_rpn_loc: 0.1851    time: 3.9892  last_time: 0.6154  data_time: 0.0038  last_data_time: 0.0036   lr: 5.994e-05  max_mem: 4240M
# [10/12 18:35:01 d2.utils.events]:  eta: 0:27:52  iter: 259  total_loss: 3.185  loss_cls: 1.262  loss_box_reg: 1.012  loss_mask: 0.6797  loss_rpn_cls: 0.08818  loss_rpn_loc: 0.1653    time: 3.9609  last_time: 8.2661  data_time: 0.0042  last_data_time: 0.0039   lr: 6.4935e-05  max_mem: 4240M
# [10/12 18:36:49 d2.utils.events]:  eta: 0:27:40  iter: 279  total_loss: 3.033  loss_cls: 1.23  loss_box_reg: 0.8556  loss_mask: 0.6714  loss_rpn_cls: 0.08154  loss_rpn_loc: 0.1751    time: 4.0634  last_time: 9.5824  data_time: 0.0046  last_data_time: 0.0042   lr: 6.993e-05  max_mem: 4240M
# [10/12 18:38:33 d2.utils.events]:  eta: 0:27:36  iter: 299  total_loss: 3.068  loss_cls: 1.202  loss_box_reg: 0.9158  loss_mask: 0.668  loss_rpn_cls: 0.0755  loss_rpn_loc: 0.1811    time: 4.1415  last_time: 8.6178  data_time: 0.0044  last_data_time: 0.0027   lr: 7.4925e-05  max_mem: 4241M
# [10/12 18:39:50 d2.utils.events]:  eta: 0:27:19  iter: 319  total_loss: 3.092  loss_cls: 1.231  loss_box_reg: 0.9255  loss_mask: 0.6629  loss_rpn_cls: 0.07623  loss_rpn_loc: 0.1542    time: 4.1232  last_time: 0.6100  data_time: 0.0039  last_data_time: 0.0034   lr: 7.992e-05  max_mem: 4241M
# [10/12 18:41:23 d2.utils.events]:  eta: 0:27:10  iter: 339  total_loss: 2.944  loss_cls: 1.2  loss_box_reg: 0.8257  loss_mask: 0.6573  loss_rpn_cls: 0.06948  loss_rpn_loc: 0.1591    time: 4.1522  last_time: 10.3395  data_time: 0.0044  last_data_time: 0.0050   lr: 8.4915e-05  max_mem: 4241M
# [10/12 18:42:33 d2.utils.events]:  eta: 0:26:51  iter: 359  total_loss: 3.022  loss_cls: 1.19  loss_box_reg: 0.8882  loss_mask: 0.6466  loss_rpn_cls: 0.07706  loss_rpn_loc: 0.1681    time: 4.1163  last_time: 0.5300  data_time: 0.0039  last_data_time: 0.0043   lr: 8.991e-05  max_mem: 4241M
# [10/12 18:43:40 d2.utils.events]:  eta: 0:26:37  iter: 379  total_loss: 2.983  loss_cls: 1.153  loss_box_reg: 0.8782  loss_mask: 0.6423  loss_rpn_cls: 0.09237  loss_rpn_loc: 0.1837    time: 4.0749  last_time: 0.5933  data_time: 0.0041  last_data_time: 0.0038   lr: 9.4905e-05  max_mem: 4241M
# [10/12 18:44:28 d2.utils.events]:  eta: 0:26:19  iter: 399  total_loss: 2.933  loss_cls: 1.156  loss_box_reg: 0.9038  loss_mask: 0.6381  loss_rpn_cls: 0.07768  loss_rpn_loc: 0.1818    time: 3.9917  last_time: 8.4118  data_time: 0.0037  last_data_time: 0.0050   lr: 9.99e-05  max_mem: 4241M
# [10/12 18:45:36 d2.utils.events]:  eta: 0:26:12  iter: 419  total_loss: 3.079  loss_cls: 1.127  loss_box_reg: 1.018  loss_mask: 0.6367  loss_rpn_cls: 0.08321  loss_rpn_loc: 0.1693    time: 3.9633  last_time: 0.5103  data_time: 0.0038  last_data_time: 0.0029   lr: 0.0001049  max_mem: 4241M
# [10/12 18:47:02 d2.utils.events]:  eta: 0:26:02  iter: 439  total_loss: 2.898  loss_cls: 1.125  loss_box_reg: 0.8951  loss_mask: 0.629  loss_rpn_cls: 0.08849  loss_rpn_loc: 0.1882    time: 3.9799  last_time: 0.5447  data_time: 0.0040  last_data_time: 0.0036   lr: 0.00010989  max_mem: 4241M
# [10/12 18:48:16 d2.utils.events]:  eta: 0:25:49  iter: 459  total_loss: 2.878  loss_cls: 1.108  loss_box_reg: 0.9528  loss_mask: 0.612  loss_rpn_cls: 0.07562  loss_rpn_loc: 0.1509    time: 3.9677  last_time: 0.5642  data_time: 0.0039  last_data_time: 0.0032   lr: 0.00011489  max_mem: 4241M
# [10/12 18:49:31 d2.utils.events]:  eta: 0:25:36  iter: 479  total_loss: 2.864  loss_cls: 1.059  loss_box_reg: 0.9486  loss_mask: 0.5814  loss_rpn_cls: 0.05544  loss_rpn_loc: 0.1809    time: 3.9583  last_time: 10.3690  data_time: 0.0039  last_data_time: 0.0028   lr: 0.00011988  max_mem: 4241M
# [10/12 18:50:57 d2.utils.events]:  eta: 0:25:24  iter: 499  total_loss: 2.788  loss_cls: 1.089  loss_box_reg: 0.8362  loss_mask: 0.5942  loss_rpn_cls: 0.06601  loss_rpn_loc: 0.1822    time: 3.9705  last_time: 0.5437  data_time: 0.0039  last_data_time: 0.0044   lr: 0.00012488  max_mem: 4241M
# Iteration 500/3000 - Loss: (2.719388633966446, 500)
# [10/12 18:52:16 d2.utils.events]:  eta: 0:25:12  iter: 519  total_loss: 2.777  loss_cls: 1.076  loss_box_reg: 0.9181  loss_mask: 0.5773  loss_rpn_cls: 0.06541  loss_rpn_loc: 0.1668    time: 3.9713  last_time: 0.5958  data_time: 0.0042  last_data_time: 0.0036   lr: 0.00012987  max_mem: 4241M
# [10/12 18:53:29 d2.utils.events]:  eta: 0:24:59  iter: 539  total_loss: 2.678  loss_cls: 1.025  loss_box_reg: 0.9248  loss_mask: 0.5624  loss_rpn_cls: 0.06582  loss_rpn_loc: 0.155    time: 3.9585  last_time: 10.5620  data_time: 0.0041  last_data_time: 0.0035   lr: 0.00013487  max_mem: 4241M
# [10/12 18:55:10 d2.utils.events]:  eta: 0:24:48  iter: 559  total_loss: 2.716  loss_cls: 1.019  loss_box_reg: 0.9201  loss_mask: 0.5607  loss_rpn_cls: 0.06451  loss_rpn_loc: 0.1735    time: 3.9973  last_time: 10.3890  data_time: 0.0048  last_data_time: 0.0049   lr: 0.00013986  max_mem: 4241M
# [10/12 18:56:01 d2.utils.events]:  eta: 0:24:34  iter: 579  total_loss: 2.664  loss_cls: 1.014  loss_box_reg: 0.9088  loss_mask: 0.5335  loss_rpn_cls: 0.05721  loss_rpn_loc: 0.1501    time: 3.9474  last_time: 0.5913  data_time: 0.0041  last_data_time: 0.0036   lr: 0.00014486  max_mem: 4241M
# [10/12 18:57:13 d2.utils.events]:  eta: 0:24:21  iter: 599  total_loss: 2.507  loss_cls: 0.9472  loss_box_reg: 0.8605  loss_mask: 0.5101  loss_rpn_cls: 0.0629  loss_rpn_loc: 0.1546    time: 3.9355  last_time: 0.6001  data_time: 0.0039  last_data_time: 0.0045   lr: 0.00014985  max_mem: 4241M
# [10/12 18:58:52 d2.utils.events]:  eta: 0:24:10  iter: 619  total_loss: 2.575  loss_cls: 0.9921  loss_box_reg: 0.8314  loss_mask: 0.4948  loss_rpn_cls: 0.06858  loss_rpn_loc: 0.1483    time: 3.9691  last_time: 0.6368  data_time: 0.0039  last_data_time: 0.0039   lr: 0.00015485  max_mem: 4241M
# [10/12 19:00:43 d2.utils.events]:  eta: 0:24:00  iter: 639  total_loss: 2.568  loss_cls: 0.9134  loss_box_reg: 0.8685  loss_mask: 0.4937  loss_rpn_cls: 0.06058  loss_rpn_loc: 0.1518    time: 4.0174  last_time: 0.5659  data_time: 0.0040  last_data_time: 0.0050   lr: 0.00015984  max_mem: 4241M
# [10/12 19:01:27 d2.utils.events]:  eta: 0:23:47  iter: 659  total_loss: 2.398  loss_cls: 0.9133  loss_box_reg: 0.8635  loss_mask: 0.4575  loss_rpn_cls: 0.05973  loss_rpn_loc: 0.1519    time: 3.9620  last_time: 0.5960  data_time: 0.0042  last_data_time: 0.0039   lr: 0.00016484  max_mem: 4241M
# [10/12 19:02:24 d2.utils.events]:  eta: 0:23:34  iter: 679  total_loss: 2.502  loss_cls: 0.9302  loss_box_reg: 0.8712  loss_mask: 0.4249  loss_rpn_cls: 0.06414  loss_rpn_loc: 0.1591    time: 3.9294  last_time: 0.5962  data_time: 0.0042  last_data_time: 0.0052   lr: 0.00016983  max_mem: 4241M
# [10/12 19:03:20 d2.utils.events]:  eta: 0:23:21  iter: 699  total_loss: 2.361  loss_cls: 0.8334  loss_box_reg: 0.8419  loss_mask: 0.4479  loss_rpn_cls: 0.05249  loss_rpn_loc: 0.1484    time: 3.8980  last_time: 0.5933  data_time: 0.0038  last_data_time: 0.0043   lr: 0.00017483  max_mem: 4241M
# [10/12 19:04:15 d2.utils.events]:  eta: 0:23:07  iter: 719  total_loss: 2.304  loss_cls: 0.7868  loss_box_reg: 0.877  loss_mask: 0.4181  loss_rpn_cls: 0.06274  loss_rpn_loc: 0.1554    time: 3.8649  last_time: 6.0941  data_time: 0.0039  last_data_time: 0.0054   lr: 0.00017982  max_mem: 4241M
# [10/12 19:05:48 d2.utils.events]:  eta: 0:22:56  iter: 739  total_loss: 2.163  loss_cls: 0.7931  loss_box_reg: 0.8174  loss_mask: 0.4  loss_rpn_cls: 0.04908  loss_rpn_loc: 0.1296    time: 3.8869  last_time: 0.6152  data_time: 0.0042  last_data_time: 0.0034   lr: 0.00018482  max_mem: 4241M
# [10/12 19:07:00 d2.utils.events]:  eta: 0:22:44  iter: 759  total_loss: 2.076  loss_cls: 0.7249  loss_box_reg: 0.811  loss_mask: 0.3675  loss_rpn_cls: 0.05756  loss_rpn_loc: 0.1419    time: 3.8789  last_time: 0.5718  data_time: 0.0035  last_data_time: 0.0025   lr: 0.00018981  max_mem: 4241M
# [10/12 19:08:44 d2.utils.events]:  eta: 0:22:32  iter: 779  total_loss: 2.08  loss_cls: 0.694  loss_box_reg: 0.7933  loss_mask: 0.3714  loss_rpn_cls: 0.05106  loss_rpn_loc: 0.1527    time: 3.9130  last_time: 10.5937  data_time: 0.0031  last_data_time: 0.0025   lr: 0.00019481  max_mem: 4241M
# [10/12 19:10:00 d2.utils.events]:  eta: 0:22:19  iter: 799  total_loss: 2.059  loss_cls: 0.7113  loss_box_reg: 0.7901  loss_mask: 0.3558  loss_rpn_cls: 0.05212  loss_rpn_loc: 0.1434    time: 3.9103  last_time: 9.9072  data_time: 0.0036  last_data_time: 0.0036   lr: 0.0001998  max_mem: 4241M
# [10/12 19:11:41 d2.utils.events]:  eta: 0:22:07  iter: 819  total_loss: 2.082  loss_cls: 0.7629  loss_box_reg: 0.7097  loss_mask: 0.3431  loss_rpn_cls: 0.05218  loss_rpn_loc: 0.1376    time: 3.9379  last_time: 8.6045  data_time: 0.0037  last_data_time: 0.0041   lr: 0.0002048  max_mem: 4241M
# [10/12 19:12:34 d2.utils.events]:  eta: 0:21:50  iter: 839  total_loss: 1.928  loss_cls: 0.658  loss_box_reg: 0.7405  loss_mask: 0.3572  loss_rpn_cls: 0.04948  loss_rpn_loc: 0.1486    time: 3.9069  last_time: 0.5477  data_time: 0.0036  last_data_time: 0.0032   lr: 0.00020979  max_mem: 4241M
# [10/12 19:13:41 d2.utils.events]:  eta: 0:21:37  iter: 859  total_loss: 1.849  loss_cls: 0.6528  loss_box_reg: 0.7316  loss_mask: 0.3143  loss_rpn_cls: 0.04887  loss_rpn_loc: 0.1486    time: 3.8946  last_time: 0.5880  data_time: 0.0036  last_data_time: 0.0042   lr: 0.00021479  max_mem: 4241M
# [10/12 19:14:52 d2.utils.events]:  eta: 0:21:24  iter: 879  total_loss: 1.992  loss_cls: 0.6097  loss_box_reg: 0.7377  loss_mask: 0.3601  loss_rpn_cls: 0.04934  loss_rpn_loc: 0.1377    time: 3.8868  last_time: 0.6254  data_time: 0.0036  last_data_time: 0.0043   lr: 0.00021978  max_mem: 4241M
# [10/12 19:16:24 d2.utils.events]:  eta: 0:21:13  iter: 899  total_loss: 1.823  loss_cls: 0.6045  loss_box_reg: 0.7114  loss_mask: 0.3105  loss_rpn_cls: 0.04352  loss_rpn_loc: 0.1623    time: 3.9022  last_time: 8.7482  data_time: 0.0039  last_data_time: 0.0043   lr: 0.00022478  max_mem: 4241M
# [10/12 19:18:21 d2.utils.events]:  eta: 0:21:02  iter: 919  total_loss: 1.926  loss_cls: 0.6722  loss_box_reg: 0.7224  loss_mask: 0.3049  loss_rpn_cls: 0.04744  loss_rpn_loc: 0.1598    time: 3.9443  last_time: 10.4453  data_time: 0.0043  last_data_time: 0.0052   lr: 0.00022977  max_mem: 4243M
# [10/12 19:19:33 d2.utils.events]:  eta: 0:20:48  iter: 939  total_loss: 1.898  loss_cls: 0.5686  loss_box_reg: 0.6907  loss_mask: 0.3291  loss_rpn_cls: 0.04643  loss_rpn_loc: 0.1612    time: 3.9375  last_time: 9.2525  data_time: 0.0043  last_data_time: 0.0035   lr: 0.00023477  max_mem: 4243M
# [10/12 19:20:26 d2.utils.events]:  eta: 0:20:34  iter: 959  total_loss: 1.819  loss_cls: 0.6021  loss_box_reg: 0.6851  loss_mask: 0.3017  loss_rpn_cls: 0.05181  loss_rpn_loc: 0.144    time: 3.9103  last_time: 0.5946  data_time: 0.0040  last_data_time: 0.0043   lr: 0.00023976  max_mem: 4243M
# [10/12 19:21:58 d2.utils.events]:  eta: 0:20:22  iter: 979  total_loss: 1.678  loss_cls: 0.5287  loss_box_reg: 0.6099  loss_mask: 0.3113  loss_rpn_cls: 0.04755  loss_rpn_loc: 0.1663    time: 3.9241  last_time: 10.4547  data_time: 0.0036  last_data_time: 0.0034   lr: 0.00024476  max_mem: 4243M
# [10/12 19:23:30 d2.utils.events]:  eta: 0:20:11  iter: 999  total_loss: 1.752  loss_cls: 0.6276  loss_box_reg: 0.6605  loss_mask: 0.3018  loss_rpn_cls: 0.04506  loss_rpn_loc: 0.1467    time: 3.9382  last_time: 0.6133  data_time: 0.0041  last_data_time: 0.0030   lr: 0.00024975  max_mem: 4243M
# Iteration 1000/3000 - Loss: (1.7325187474489212, 1000)
# [10/12 19:25:15 d2.utils.events]:  eta: 0:20:01  iter: 1019  total_loss: 1.69  loss_cls: 0.5945  loss_box_reg: 0.6092  loss_mask: 0.2809  loss_rpn_cls: 0.04265  loss_rpn_loc: 0.1448    time: 3.9643  last_time: 0.5573  data_time: 0.0037  last_data_time: 0.0033   lr: 0.00025  max_mem: 4243M
# [10/12 19:26:26 d2.utils.events]:  eta: 0:19:50  iter: 1039  total_loss: 1.633  loss_cls: 0.5306  loss_box_reg: 0.5951  loss_mask: 0.2987  loss_rpn_cls: 0.04206  loss_rpn_loc: 0.1465    time: 3.9563  last_time: 0.6180  data_time: 0.0041  last_data_time: 0.0043   lr: 0.00025  max_mem: 4243M
# [10/12 19:27:48 d2.utils.events]:  eta: 0:19:42  iter: 1059  total_loss: 1.597  loss_cls: 0.4903  loss_box_reg: 0.6194  loss_mask: 0.278  loss_rpn_cls: 0.04796  loss_rpn_loc: 0.1386    time: 3.9588  last_time: 0.6273  data_time: 0.0034  last_data_time: 0.0029   lr: 0.00025  max_mem: 4243M
# [10/12 19:28:52 d2.utils.events]:  eta: 0:19:30  iter: 1079  total_loss: 1.622  loss_cls: 0.5532  loss_box_reg: 0.6049  loss_mask: 0.2871  loss_rpn_cls: 0.04074  loss_rpn_loc: 0.12    time: 3.9447  last_time: 0.5783  data_time: 0.0036  last_data_time: 0.0037   lr: 0.00025  max_mem: 4243M
# [10/12 19:30:01 d2.utils.events]:  eta: 0:19:19  iter: 1099  total_loss: 1.667  loss_cls: 0.5426  loss_box_reg: 0.6396  loss_mask: 0.2642  loss_rpn_cls: 0.03975  loss_rpn_loc: 0.1427    time: 3.9358  last_time: 0.5784  data_time: 0.0042  last_data_time: 0.0038   lr: 0.00025  max_mem: 4243M
# [10/12 19:31:09 d2.utils.events]:  eta: 0:19:11  iter: 1119  total_loss: 1.705  loss_cls: 0.617  loss_box_reg: 0.6512  loss_mask: 0.2691  loss_rpn_cls: 0.04528  loss_rpn_loc: 0.144    time: 3.9256  last_time: 0.8879  data_time: 0.0035  last_data_time: 0.0038   lr: 0.00025  max_mem: 4243M
# [10/12 19:32:40 d2.utils.events]:  eta: 0:19:01  iter: 1139  total_loss: 1.768  loss_cls: 0.5811  loss_box_reg: 0.6514  loss_mask: 0.2797  loss_rpn_cls: 0.04696  loss_rpn_loc: 0.1428    time: 3.9367  last_time: 12.9541  data_time: 0.0037  last_data_time: 0.0030   lr: 0.00025  max_mem: 4243M
# [10/12 19:35:04 d2.utils.events]:  eta: 0:18:51  iter: 1159  total_loss: 1.634  loss_cls: 0.5351  loss_box_reg: 0.5893  loss_mask: 0.2765  loss_rpn_cls: 0.0369  loss_rpn_loc: 0.1415    time: 3.9928  last_time: 11.1341  data_time: 0.0043  last_data_time: 0.0037   lr: 0.00025  max_mem: 4243M
# [10/12 19:36:31 d2.utils.events]:  eta: 0:18:39  iter: 1179  total_loss: 1.591  loss_cls: 0.5101  loss_box_reg: 0.5788  loss_mask: 0.2647  loss_rpn_cls: 0.04306  loss_rpn_loc: 0.1463    time: 3.9988  last_time: 0.7176  data_time: 0.0040  last_data_time: 0.0037   lr: 0.00025  max_mem: 4243M
# [10/12 19:38:05 d2.utils.events]:  eta: 0:18:24  iter: 1199  total_loss: 1.56  loss_cls: 0.5606  loss_box_reg: 0.5491  loss_mask: 0.2878  loss_rpn_cls: 0.04224  loss_rpn_loc: 0.1371    time: 4.0105  last_time: 0.5986  data_time: 0.0039  last_data_time: 0.0037   lr: 0.00025  max_mem: 4243M
# [10/12 19:39:28 d2.utils.events]:  eta: 0:18:12  iter: 1219  total_loss: 1.486  loss_cls: 0.4563  loss_box_reg: 0.5639  loss_mask: 0.2403  loss_rpn_cls: 0.0359  loss_rpn_loc: 0.1226    time: 4.0131  last_time: 0.6894  data_time: 0.0036  last_data_time: 0.0026   lr: 0.00025  max_mem: 4243M
# [10/12 19:41:03 d2.utils.events]:  eta: 0:18:02  iter: 1239  total_loss: 1.701  loss_cls: 0.5284  loss_box_reg: 0.6449  loss_mask: 0.2898  loss_rpn_cls: 0.03951  loss_rpn_loc: 0.1577    time: 4.0249  last_time: 0.5470  data_time: 0.0041  last_data_time: 0.0032   lr: 0.00025  max_mem: 4243M
# [10/12 19:42:32 d2.utils.events]:  eta: 0:17:52  iter: 1259  total_loss: 1.57  loss_cls: 0.4864  loss_box_reg: 0.5673  loss_mask: 0.256  loss_rpn_cls: 0.04071  loss_rpn_loc: 0.1433    time: 4.0316  last_time: 10.7518  data_time: 0.0040  last_data_time: 0.0038   lr: 0.00025  max_mem: 4243M
# [10/12 19:44:11 d2.utils.events]:  eta: 0:17:42  iter: 1279  total_loss: 1.592  loss_cls: 0.5132  loss_box_reg: 0.608  loss_mask: 0.2719  loss_rpn_cls: 0.04148  loss_rpn_loc: 0.1278    time: 4.0462  last_time: 6.7077  data_time: 0.0038  last_data_time: 0.0037   lr: 0.00025  max_mem: 4243M
# [10/12 19:45:53 d2.utils.events]:  eta: 0:17:28  iter: 1299  total_loss: 1.363  loss_cls: 0.4269  loss_box_reg: 0.5303  loss_mask: 0.2521  loss_rpn_cls: 0.03699  loss_rpn_loc: 0.1328    time: 4.0623  last_time: 11.0630  data_time: 0.0040  last_data_time: 0.0054   lr: 0.00025  max_mem: 4243M
# [10/12 19:47:57 d2.utils.events]:  eta: 0:17:18  iter: 1319  total_loss: 1.491  loss_cls: 0.5058  loss_box_reg: 0.5478  loss_mask: 0.2581  loss_rpn_cls: 0.04007  loss_rpn_loc: 0.1359    time: 4.0947  last_time: 6.7777  data_time: 0.0043  last_data_time: 0.0037   lr: 0.00025  max_mem: 4243M
# [10/12 19:49:39 d2.utils.events]:  eta: 0:17:09  iter: 1339  total_loss: 1.593  loss_cls: 0.5535  loss_box_reg: 0.5766  loss_mask: 0.2664  loss_rpn_cls: 0.04593  loss_rpn_loc: 0.1375    time: 4.1101  last_time: 12.1132  data_time: 0.0042  last_data_time: 0.0044   lr: 0.00025  max_mem: 4243M
# [10/12 19:50:53 d2.utils.events]:  eta: 0:16:58  iter: 1359  total_loss: 1.445  loss_cls: 0.5029  loss_box_reg: 0.5774  loss_mask: 0.2396  loss_rpn_cls: 0.03495  loss_rpn_loc: 0.1364    time: 4.1041  last_time: 0.5687  data_time: 0.0038  last_data_time: 0.0030   lr: 0.00025  max_mem: 4243M
# [10/12 19:52:18 d2.utils.events]:  eta: 0:16:46  iter: 1379  total_loss: 1.5  loss_cls: 0.5046  loss_box_reg: 0.5543  loss_mask: 0.2418  loss_rpn_cls: 0.03689  loss_rpn_loc: 0.1468    time: 4.1057  last_time: 10.1781  data_time: 0.0040  last_data_time: 0.0040   lr: 0.00025  max_mem: 4243M
# [10/12 19:53:46 d2.utils.events]:  eta: 0:16:40  iter: 1399  total_loss: 1.516  loss_cls: 0.5177  loss_box_reg: 0.5746  loss_mask: 0.26  loss_rpn_cls: 0.03999  loss_rpn_loc: 0.1374    time: 4.1102  last_time: 0.5921  data_time: 0.0045  last_data_time: 0.0065   lr: 0.00025  max_mem: 4243M
# [10/12 19:55:03 d2.utils.events]:  eta: 0:16:28  iter: 1419  total_loss: 1.53  loss_cls: 0.5164  loss_box_reg: 0.5215  loss_mask: 0.2242  loss_rpn_cls: 0.03431  loss_rpn_loc: 0.149    time: 4.1065  last_time: 10.1351  data_time: 0.0041  last_data_time: 0.0040   lr: 0.00025  max_mem: 4243M
# [10/12 19:56:34 d2.utils.events]:  eta: 0:16:13  iter: 1439  total_loss: 1.373  loss_cls: 0.5018  loss_box_reg: 0.5043  loss_mask: 0.2259  loss_rpn_cls: 0.03734  loss_rpn_loc: 0.1371    time: 4.1123  last_time: 0.5812  data_time: 0.0039  last_data_time: 0.0032   lr: 0.00025  max_mem: 4243M
# [10/12 19:57:32 d2.utils.events]:  eta: 0:16:03  iter: 1459  total_loss: 1.517  loss_cls: 0.5018  loss_box_reg: 0.5741  loss_mask: 0.2503  loss_rpn_cls: 0.04181  loss_rpn_loc: 0.1359    time: 4.0958  last_time: 0.5341  data_time: 0.0041  last_data_time: 0.0044   lr: 0.00025  max_mem: 4243M
# [10/12 19:58:31 d2.utils.events]:  eta: 0:15:49  iter: 1479  total_loss: 1.365  loss_cls: 0.4384  loss_box_reg: 0.5053  loss_mask: 0.2411  loss_rpn_cls: 0.04387  loss_rpn_loc: 0.1279    time: 4.0803  last_time: 10.3077  data_time: 0.0043  last_data_time: 0.0032   lr: 0.00025  max_mem: 4243M
# [10/12 19:59:51 d2.utils.events]:  eta: 0:15:34  iter: 1499  total_loss: 1.475  loss_cls: 0.4612  loss_box_reg: 0.5589  loss_mask: 0.2568  loss_rpn_cls: 0.03528  loss_rpn_loc: 0.141    time: 4.0790  last_time: 0.5861  data_time: 0.0047  last_data_time: 0.0058   lr: 0.00025  max_mem: 4243M
# Iteration 1500/3000 - Loss: (1.0803265273571014, 1500)
# [10/12 20:01:41 d2.utils.events]:  eta: 0:15:24  iter: 1519  total_loss: 1.395  loss_cls: 0.4826  loss_box_reg: 0.4852  loss_mask: 0.25  loss_rpn_cls: 0.03165  loss_rpn_loc: 0.1587    time: 4.0977  last_time: 0.5462  data_time: 0.0040  last_data_time: 0.0037   lr: 0.00025  max_mem: 4243M
# [10/12 20:03:09 d2.utils.events]:  eta: 0:15:11  iter: 1539  total_loss: 1.497  loss_cls: 0.447  loss_box_reg: 0.5697  loss_mask: 0.2686  loss_rpn_cls: 0.03474  loss_rpn_loc: 0.13    time: 4.1018  last_time: 10.1975  data_time: 0.0040  last_data_time: 0.0041   lr: 0.00025  max_mem: 4243M
# [10/12 20:04:24 d2.utils.events]:  eta: 0:14:59  iter: 1559  total_loss: 1.489  loss_cls: 0.5381  loss_box_reg: 0.5349  loss_mask: 0.2552  loss_rpn_cls: 0.0391  loss_rpn_loc: 0.1395    time: 4.0971  last_time: 9.3812  data_time: 0.0040  last_data_time: 0.0046   lr: 0.00025  max_mem: 4243M
# [10/12 20:05:51 d2.utils.events]:  eta: 0:14:49  iter: 1579  total_loss: 1.383  loss_cls: 0.4676  loss_box_reg: 0.5165  loss_mask: 0.2384  loss_rpn_cls: 0.03715  loss_rpn_loc: 0.1336    time: 4.1003  last_time: 0.5565  data_time: 0.0044  last_data_time: 0.0044   lr: 0.00025  max_mem: 4243M
# [10/12 20:07:40 d2.utils.events]:  eta: 0:14:38  iter: 1599  total_loss: 1.316  loss_cls: 0.4259  loss_box_reg: 0.4912  loss_mask: 0.2461  loss_rpn_cls: 0.03466  loss_rpn_loc: 0.1191    time: 4.1175  last_time: 8.8732  data_time: 0.0043  last_data_time: 0.0041   lr: 0.00025  max_mem: 4243M
# [10/12 20:08:35 d2.utils.events]:  eta: 0:14:24  iter: 1619  total_loss: 1.386  loss_cls: 0.4382  loss_box_reg: 0.5372  loss_mask: 0.2369  loss_rpn_cls: 0.03467  loss_rpn_loc: 0.1216    time: 4.1007  last_time: 0.5627  data_time: 0.0039  last_data_time: 0.0033   lr: 0.00025  max_mem: 4243M
# [10/12 20:10:05 d2.utils.events]:  eta: 0:14:10  iter: 1639  total_loss: 1.429  loss_cls: 0.4856  loss_box_reg: 0.5331  loss_mask: 0.2214  loss_rpn_cls: 0.02719  loss_rpn_loc: 0.1284    time: 4.1053  last_time: 6.0471  data_time: 0.0040  last_data_time: 0.0050   lr: 0.00025  max_mem: 4243M
# [10/12 20:11:32 d2.utils.events]:  eta: 0:13:58  iter: 1659  total_loss: 1.304  loss_cls: 0.4224  loss_box_reg: 0.473  loss_mask: 0.2348  loss_rpn_cls: 0.03411  loss_rpn_loc: 0.1269    time: 4.1084  last_time: 9.3349  data_time: 0.0047  last_data_time: 0.0040   lr: 0.00025  max_mem: 4243M
# [10/12 20:13:08 d2.utils.events]:  eta: 0:13:46  iter: 1679  total_loss: 1.444  loss_cls: 0.4776  loss_box_reg: 0.5461  loss_mask: 0.2346  loss_rpn_cls: 0.03247  loss_rpn_loc: 0.1381    time: 4.1167  last_time: 8.6895  data_time: 0.0042  last_data_time: 0.0031   lr: 0.00025  max_mem: 4243M
# [10/12 20:13:41 d2.utils.events]:  eta: 0:13:33  iter: 1699  total_loss: 1.328  loss_cls: 0.3954  loss_box_reg: 0.5301  loss_mask: 0.2392  loss_rpn_cls: 0.03046  loss_rpn_loc: 0.129    time: 4.0874  last_time: 0.5923  data_time: 0.0042  last_data_time: 0.0052   lr: 0.00025  max_mem: 4243M
# [10/12 20:15:02 d2.utils.events]:  eta: 0:13:21  iter: 1719  total_loss: 1.352  loss_cls: 0.4082  loss_box_reg: 0.5101  loss_mask: 0.2436  loss_rpn_cls: 0.03133  loss_rpn_loc: 0.1502    time: 4.0872  last_time: 0.5859  data_time: 0.0043  last_data_time: 0.0047   lr: 0.00025  max_mem: 4243M
# [10/12 20:16:24 d2.utils.events]:  eta: 0:13:09  iter: 1739  total_loss: 1.367  loss_cls: 0.4728  loss_box_reg: 0.49  loss_mask: 0.2395  loss_rpn_cls: 0.03131  loss_rpn_loc: 0.1226    time: 4.0874  last_time: 0.5953  data_time: 0.0043  last_data_time: 0.0038   lr: 0.00025  max_mem: 4243M
# [10/12 20:18:09 d2.utils.events]:  eta: 0:12:58  iter: 1759  total_loss: 1.34  loss_cls: 0.4302  loss_box_reg: 0.4793  loss_mask: 0.2521  loss_rpn_cls: 0.02801  loss_rpn_loc: 0.1377    time: 4.1006  last_time: 10.3474  data_time: 0.0043  last_data_time: 0.0036   lr: 0.00025  max_mem: 4243M
# [10/12 20:19:24 d2.utils.events]:  eta: 0:12:45  iter: 1779  total_loss: 1.353  loss_cls: 0.4293  loss_box_reg: 0.4994  loss_mask: 0.221  loss_rpn_cls: 0.02963  loss_rpn_loc: 0.1213    time: 4.0965  last_time: 0.6340  data_time: 0.0043  last_data_time: 0.0036   lr: 0.00025  max_mem: 4243M
# [10/12 20:20:48 d2.utils.events]:  eta: 0:12:33  iter: 1799  total_loss: 1.405  loss_cls: 0.4673  loss_box_reg: 0.5213  loss_mask: 0.2198  loss_rpn_cls: 0.03374  loss_rpn_loc: 0.1171    time: 4.0977  last_time: 8.3921  data_time: 0.0041  last_data_time: 0.0028   lr: 0.00025  max_mem: 4243M
# [10/12 20:22:14 d2.utils.events]:  eta: 0:12:20  iter: 1819  total_loss: 1.396  loss_cls: 0.4679  loss_box_reg: 0.5353  loss_mask: 0.2291  loss_rpn_cls: 0.02447  loss_rpn_loc: 0.1433    time: 4.0997  last_time: 10.4794  data_time: 0.0040  last_data_time: 0.0028   lr: 0.00025  max_mem: 4243M
# [10/12 20:23:09 d2.utils.events]:  eta: 0:12:07  iter: 1839  total_loss: 1.332  loss_cls: 0.4243  loss_box_reg: 0.5085  loss_mask: 0.2254  loss_rpn_cls: 0.03095  loss_rpn_loc: 0.1297    time: 4.0849  last_time: 0.5570  data_time: 0.0045  last_data_time: 0.0045   lr: 0.00025  max_mem: 4243M
# [10/12 20:24:09 d2.utils.events]:  eta: 0:11:55  iter: 1859  total_loss: 1.378  loss_cls: 0.4558  loss_box_reg: 0.4754  loss_mask: 0.2303  loss_rpn_cls: 0.0345  loss_rpn_loc: 0.1377    time: 4.0734  last_time: 0.5201  data_time: 0.0046  last_data_time: 0.0037   lr: 0.00025  max_mem: 4243M
# [10/12 20:25:27 d2.utils.events]:  eta: 0:11:42  iter: 1879  total_loss: 1.442  loss_cls: 0.467  loss_box_reg: 0.5332  loss_mask: 0.2189  loss_rpn_cls: 0.02902  loss_rpn_loc: 0.1063    time: 4.0716  last_time: 10.1743  data_time: 0.0045  last_data_time: 0.0043   lr: 0.00025  max_mem: 4243M
# [10/12 20:26:34 d2.utils.events]:  eta: 0:11:28  iter: 1899  total_loss: 1.282  loss_cls: 0.4038  loss_box_reg: 0.5192  loss_mask: 0.2103  loss_rpn_cls: 0.03196  loss_rpn_loc: 0.1291    time: 4.0639  last_time: 9.2443  data_time: 0.0043  last_data_time: 0.0039   lr: 0.00025  max_mem: 4243M
# [10/12 20:27:52 d2.utils.events]:  eta: 0:11:16  iter: 1919  total_loss: 1.316  loss_cls: 0.4814  loss_box_reg: 0.4674  loss_mask: 0.2097  loss_rpn_cls: 0.03483  loss_rpn_loc: 0.1309    time: 4.0620  last_time: 9.1539  data_time: 0.0039  last_data_time: 0.0037   lr: 0.00025  max_mem: 4243M
# [10/12 20:29:16 d2.utils.events]:  eta: 0:11:03  iter: 1939  total_loss: 1.292  loss_cls: 0.398  loss_box_reg: 0.536  loss_mask: 0.2393  loss_rpn_cls: 0.0297  loss_rpn_loc: 0.1292    time: 4.0635  last_time: 0.5308  data_time: 0.0044  last_data_time: 0.0036   lr: 0.00025  max_mem: 4243M
# [10/12 20:30:56 d2.utils.events]:  eta: 0:10:52  iter: 1959  total_loss: 1.348  loss_cls: 0.4548  loss_box_reg: 0.503  loss_mask: 0.237  loss_rpn_cls: 0.03446  loss_rpn_loc: 0.1361    time: 4.0734  last_time: 10.4782  data_time: 0.0051  last_data_time: 0.0031   lr: 0.00025  max_mem: 4243M
# [10/12 20:31:42 d2.utils.events]:  eta: 0:10:38  iter: 1979  total_loss: 1.339  loss_cls: 0.3917  loss_box_reg: 0.4546  loss_mask: 0.2237  loss_rpn_cls: 0.02742  loss_rpn_loc: 0.1229    time: 4.0554  last_time: 0.6003  data_time: 0.0039  last_data_time: 0.0037   lr: 0.00025  max_mem: 4243M
# [10/12 20:32:49 d2.utils.events]:  eta: 0:10:26  iter: 1999  total_loss: 1.315  loss_cls: 0.4716  loss_box_reg: 0.4644  loss_mask: 0.2238  loss_rpn_cls: 0.03142  loss_rpn_loc: 0.1286    time: 4.0480  last_time: 9.3942  data_time: 0.0042  last_data_time: 0.0038   lr: 0.00025  max_mem: 4243M
# Iteration 2000/3000 - Loss: (0.750898964703083, 2000)
# [10/12 20:33:48 d2.utils.events]:  eta: 0:10:11  iter: 2019  total_loss: 1.284  loss_cls: 0.3982  loss_box_reg: 0.5132  loss_mask: 0.2133  loss_rpn_cls: 0.03589  loss_rpn_loc: 0.1366    time: 4.0375  last_time: 10.2184  data_time: 0.0039  last_data_time: 0.0037   lr: 0.00025  max_mem: 4243M
# [10/12 20:35:08 d2.utils.events]:  eta: 0:09:57  iter: 2039  total_loss: 1.248  loss_cls: 0.3749  loss_box_reg: 0.4747  loss_mask: 0.2357  loss_rpn_cls: 0.03115  loss_rpn_loc: 0.1337    time: 4.0371  last_time: 10.3725  data_time: 0.0045  last_data_time: 0.0038   lr: 0.00025  max_mem: 4243M
# ...
# [10/12 21:13:19 d2.utils.events]:  eta: 0:04:29  iter: 2559  total_loss: 1.207  loss_cls: 0.3786  loss_box_reg: 0.4985  loss_mask: 0.2164  loss_rpn_cls: 0.03003  loss_rpn_loc: 0.1222    time: 4.1118  last_time: 0.5068  data_time: 0.0044  last_data_time: 0.0043   lr: 0.00025  max_mem: 4243M
# [10/12 21:14:53 d2.utils.events]:  eta: 0:04:17  iter: 2579  total_loss: 1.18  loss_cls: 0.325  loss_box_reg: 0.4783  loss_mask: 0.2193  loss_rpn_cls: 0.02952  loss_rpn_loc: 0.1273    time: 4.1164  last_time: 0.5450  data_time: 0.0043  last_data_time: 0.0034   lr: 0.00025  max_mem: 4243M
# [10/12 21:16:06 d2.utils.events]:  eta: 0:04:04  iter: 2599  total_loss: 1.172  loss_cls: 0.2972  loss_box_reg: 0.4218  loss_mask: 0.2175  loss_rpn_cls: 0.0301  loss_rpn_loc: 0.1243    time: 4.1126  last_time: 10.0334  data_time: 0.0041  last_data_time: 0.0046   lr: 0.00025  max_mem: 4243M
# [10/12 21:17:21 d2.utils.events]:  eta: 0:03:52  iter: 2619  total_loss: 1.098  loss_cls: 0.3583  loss_box_reg: 0.4289  loss_mask: 0.1916  loss_rpn_cls: 0.02473  loss_rpn_loc: 0.1188    time: 4.1100  last_time: 9.1794  data_time: 0.0042  last_data_time: 0.0045   lr: 0.00025  max_mem: 4243M
# [10/12 21:19:02 d2.utils.events]:  eta: 0:03:40  iter: 2639  total_loss: 1.1  loss_cls: 0.3233  loss_box_reg: 0.4342  loss_mask: 0.1912  loss_rpn_cls: 0.02694  loss_rpn_loc: 0.1313    time: 4.1169  last_time: 0.5990  data_time: 0.0042  last_data_time: 0.0045   lr: 0.00025  max_mem: 4243M
# [10/12 21:20:19 d2.utils.events]:  eta: 0:03:27  iter: 2659  total_loss: 1.241  loss_cls: 0.3769  loss_box_reg: 0.4713  loss_mask: 0.2156  loss_rpn_cls: 0.03043  loss_rpn_loc: 0.1132    time: 4.1150  last_time: 0.5747  data_time: 0.0046  last_data_time: 0.0039   lr: 0.00025  max_mem: 4243M
# [10/12 21:21:11 d2.utils.events]:  eta: 0:03:15  iter: 2679  total_loss: 1.253  loss_cls: 0.3512  loss_box_reg: 0.5085  loss_mask: 0.2077  loss_rpn_cls: 0.03119  loss_rpn_loc: 0.1256    time: 4.1035  last_time: 0.5852  data_time: 0.0038  last_data_time: 0.0047   lr: 0.00025  max_mem: 4243M
# [10/12 21:22:40 d2.utils.events]:  eta: 0:03:03  iter: 2699  total_loss: 1.192  loss_cls: 0.3594  loss_box_reg: 0.4399  loss_mask: 0.1948  loss_rpn_cls: 0.02917  loss_rpn_loc: 0.124    time: 4.1061  last_time: 0.5827  data_time: 0.0041  last_data_time: 0.0039   lr: 0.00025  max_mem: 4243M
# [10/12 21:24:10 d2.utils.events]:  eta: 0:02:51  iter: 2719  total_loss: 1.224  loss_cls: 0.409  loss_box_reg: 0.4525  loss_mask: 0.2026  loss_rpn_cls: 0.02437  loss_rpn_loc: 0.1294    time: 4.1091  last_time: 10.2521  data_time: 0.0045  last_data_time: 0.0039   lr: 0.00025  max_mem: 4243M
# [10/12 21:25:49 d2.utils.events]:  eta: 0:02:39  iter: 2739  total_loss: 1.203  loss_cls: 0.3636  loss_box_reg: 0.4477  loss_mask: 0.1899  loss_rpn_cls: 0.03094  loss_rpn_loc: 0.1214    time: 4.1152  last_time: 0.5982  data_time: 0.0046  last_data_time: 0.0041   lr: 0.00025  max_mem: 4243M
# [10/12 21:27:14 d2.utils.events]:  eta: 0:02:26  iter: 2759  total_loss: 1.171  loss_cls: 0.364  loss_box_reg: 0.4636  loss_mask: 0.2067  loss_rpn_cls: 0.03106  loss_rpn_loc: 0.1132    time: 4.1162  last_time: 0.6088  data_time: 0.0039  last_data_time: 0.0027   lr: 0.00025  max_mem: 4243M
# [10/12 21:28:35 d2.utils.events]:  eta: 0:02:14  iter: 2779  total_loss: 1.168  loss_cls: 0.3508  loss_box_reg: 0.4627  loss_mask: 0.2072  loss_rpn_cls: 0.02825  loss_rpn_loc: 0.1087    time: 4.1158  last_time: 0.6065  data_time: 0.0046  last_data_time: 0.0041   lr: 0.00025  max_mem: 4243M
# [10/12 21:29:53 d2.utils.events]:  eta: 0:02:02  iter: 2799  total_loss: 1.11  loss_cls: 0.3768  loss_box_reg: 0.4151  loss_mask: 0.1907  loss_rpn_cls: 0.02503  loss_rpn_loc: 0.1112    time: 4.1141  last_time: 0.5859  data_time: 0.0042  last_data_time: 0.0036   lr: 0.00025  max_mem: 4243M
# [10/12 21:31:18 d2.utils.events]:  eta: 0:01:50  iter: 2819  total_loss: 1.224  loss_cls: 0.4042  loss_box_reg: 0.4388  loss_mask: 0.2273  loss_rpn_cls: 0.02692  loss_rpn_loc: 0.1346    time: 4.1151  last_time: 6.0656  data_time: 0.0043  last_data_time: 0.0035   lr: 0.00025  max_mem: 4243M
# [10/12 21:32:22 d2.utils.events]:  eta: 0:01:37  iter: 2839  total_loss: 1.206  loss_cls: 0.3672  loss_box_reg: 0.4479  loss_mask: 0.2209  loss_rpn_cls: 0.0231  loss_rpn_loc: 0.1057    time: 4.1088  last_time: 0.5435  data_time: 0.0040  last_data_time: 0.0037   lr: 0.00025  max_mem: 4243M
# [10/12 21:33:41 d2.utils.events]:  eta: 0:01:25  iter: 2859  total_loss: 1.124  loss_cls: 0.345  loss_box_reg: 0.3876  loss_mask: 0.2057  loss_rpn_cls: 0.02364  loss_rpn_loc: 0.1135    time: 4.1076  last_time: 0.5655  data_time: 0.0037  last_data_time: 0.0041   lr: 0.00025  max_mem: 4243M
# [10/12 21:34:49 d2.utils.events]:  eta: 0:01:13  iter: 2879  total_loss: 1.199  loss_cls: 0.3322  loss_box_reg: 0.4591  loss_mask: 0.1936  loss_rpn_cls: 0.02349  loss_rpn_loc: 0.1095    time: 4.1028  last_time: 0.5999  data_time: 0.0043  last_data_time: 0.0043   lr: 0.00025  max_mem: 4243M
# [10/12 21:36:21 d2.utils.events]:  eta: 0:01:01  iter: 2899  total_loss: 1.121  loss_cls: 0.3425  loss_box_reg: 0.4016  loss_mask: 0.2037  loss_rpn_cls: 0.02335  loss_rpn_loc: 0.1224    time: 4.1061  last_time: 12.8751  data_time: 0.0034  last_data_time: 0.0033   lr: 0.00025  max_mem: 4243M
# [10/12 21:37:54 d2.utils.events]:  eta: 0:00:49  iter: 2919  total_loss: 1.207  loss_cls: 0.318  loss_box_reg: 0.4792  loss_mask: 0.1986  loss_rpn_cls: 0.02676  loss_rpn_loc: 0.119    time: 4.1099  last_time: 0.5275  data_time: 0.0043  last_data_time: 0.0036   lr: 0.00025  max_mem: 4243M
# [10/12 21:39:46 d2.utils.events]:  eta: 0:00:36  iter: 2939  total_loss: 1.19  loss_cls: 0.3326  loss_box_reg: 0.4734  loss_mask: 0.2271  loss_rpn_cls: 0.02618  loss_rpn_loc: 0.1215    time: 4.1200  last_time: 10.3625  data_time: 0.0044  last_data_time: 0.0037   lr: 0.00025  max_mem: 4243M
# [10/12 21:40:53 d2.utils.events]:  eta: 0:00:24  iter: 2959  total_loss: 1.219  loss_cls: 0.4059  loss_box_reg: 0.468  loss_mask: 0.2287  loss_rpn_cls: 0.03025  loss_rpn_loc: 0.1342    time: 4.1148  last_time: 10.3402  data_time: 0.0043  last_data_time: 0.0037   lr: 0.00025  max_mem: 4243M
# [10/12 21:42:24 d2.utils.events]:  eta: 0:00:12  iter: 2979  total_loss: 1.213  loss_cls: 0.3784  loss_box_reg: 0.4505  loss_mask: 0.2075  loss_rpn_cls: 0.02519  loss_rpn_loc: 0.1185    time: 4.1177  last_time: 8.2577  data_time: 0.0047  last_data_time: 0.0058   lr: 0.00025  max_mem: 4243M
# [10/12 21:43:35 d2.utils.events]:  eta: 0:00:00  iter: 2999  total_loss: 1.154  loss_cls: 0.3329  loss_box_reg: 0.4212  loss_mask: 0.1991  loss_rpn_cls: 0.02775  loss_rpn_loc: 0.1193    time: 4.1137  last_time: 0.5493  data_time: 0.0044  last_data_time: 0.0054   lr: 0.00025  max_mem: 4243M
# [10/12 21:43:35 d2.engine.hooks]: Overall training speed: 2998 iterations in 3:25:32 (4.1137 s / it)
# [10/12 21:43:35 d2.engine.hooks]: Total training time: 3:25:36 (0:00:03 on hooks)
# [10/12 21:43:35 d2.data.datasets.coco]: Loaded 200 images in COCO format from C:/Users/kurt_/car-parts-and-damage-detection/car-part-detection/working/data/val\annotations.json
# [10/12 21:43:35 d2.data.build]: Distribution of instances among all 21 categories:
# |   category    | #instances   |   category    | #instances   |   category   | #instances   |
# |:-------------:|:-------------|:-------------:|:-------------|:------------:|:-------------|
# | Quarter-panel | 173          |  Front-wheel  | 176          | Back-window  | 234          |
# |     Trunk     | 85           |  Front-door   | 183          | Rocker-panel | 166          |
# |    Grille     | 121          |  Windshield   | 131          | Front-window | 195          |
# |   Back-door   | 142          |   Headlight   | 192          |  Back-wheel  | 173          |
# | Back-windsh.. | 51           |     Hood      | 147          |    Fender    | 186          |
# |  Tail-light   | 132          | License-plate | 77           | Front-bumper | 142          |
# |  Back-bumper  | 86           |    Mirror     | 205          |     Roof     | 159          |
# |               |              |               |              |              |              |
# |     total     | 3156         |               |              |              |              |
# [10/12 21:43:35 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [10/12 21:43:35 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [10/12 21:43:35 d2.data.common]: Serializing 200 elements to byte tensors and concatenating them all ...
# [10/12 21:43:35 d2.data.common]: Serialized dataset takes 1.53 MiB
# WARNING [10/12 21:43:35 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# [10/12 21:43:35 d2.evaluation.evaluator]: Start inference on 200 batches
# [10/12 21:43:42 d2.evaluation.evaluator]: Inference done 11/200. Dataloading: 0.0007 s/iter. Inference: 0.1678 s/iter. Eval: 0.0541 s/iter. Total: 0.2226 s/iter. ETA=0:00:42
# [10/12 21:43:47 d2.evaluation.evaluator]: Inference done 35/200. Dataloading: 0.0007 s/iter. Inference: 0.1687 s/iter. Eval: 0.0435 s/iter. Total: 0.2129 s/iter. ETA=0:00:35
# [10/12 21:43:52 d2.evaluation.evaluator]: Inference done 68/200. Dataloading: 0.0007 s/iter. Inference: 0.1475 s/iter. Eval: 0.0407 s/iter. Total: 0.1890 s/iter. ETA=0:00:24
# [10/12 21:43:57 d2.evaluation.evaluator]: Inference done 99/200. Dataloading: 0.0007 s/iter. Inference: 0.1419 s/iter. Eval: 0.0402 s/iter. Total: 0.1828 s/iter. ETA=0:00:18
# [10/12 21:44:02 d2.evaluation.evaluator]: Inference done 136/200. Dataloading: 0.0007 s/iter. Inference: 0.1293 s/iter. Eval: 0.0399 s/iter. Total: 0.1699 s/iter. ETA=0:00:10
# [10/12 21:44:08 d2.evaluation.evaluator]: Inference done 169/200. Dataloading: 0.0007 s/iter. Inference: 0.1304 s/iter. Eval: 0.0396 s/iter. Total: 0.1707 s/iter. ETA=0:00:05
# [10/12 21:44:13 d2.evaluation.evaluator]: Total inference time: 0:00:32.573219 (0.167042 s / iter per device, on 1 devices)
# [10/12 21:44:13 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:24 (0.124321 s / iter per device, on 1 devices)
# [10/12 21:44:13 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [10/12 21:44:13 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# [10/12 21:44:13 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [10/12 21:44:13 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.19 seconds.
# [10/12 21:44:13 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [10/12 21:44:13 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.06 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.459
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.763
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.492
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.089
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.313
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.534
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.512
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.595
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.596
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.176
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.460
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.660
# [10/12 21:44:13 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 45.876 | 76.259 | 49.213 | 8.926 | 31.253 | 53.414 |
# [10/12 21:44:13 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category        | AP     | category      | AP     | category     | AP     |
# |:----------------|:-------|:--------------|:-------|:-------------|:-------|
# | Quarter-panel   | 25.282 | Front-wheel   | 52.248 | Back-window  | 49.268 |
# | Trunk           | 15.230 | Front-door    | 63.615 | Rocker-panel | 50.130 |
# | Grille          | 37.650 | Windshield    | 66.217 | Front-window | 43.741 |
# | Back-door       | 65.839 | Headlight     | 51.782 | Back-wheel   | 50.376 |
# | Back-windshield | 45.212 | Hood          | 60.760 | Fender       | 48.250 |
# | Tail-light      | 40.997 | License-plate | 34.898 | Front-bumper | 56.450 |
# | Back-bumper     | 45.643 | Mirror        | 34.894 | Roof         | 24.916 |
# Loading and preparing results...
# DONE (t=0.09s)
# creating index...
# index created!
# [10/12 21:44:14 d2.evaluation.fast_eval_api]: Evaluate annotation type *segm*
# [10/12 21:44:14 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.39 seconds.
# [10/12 21:44:14 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [10/12 21:44:14 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.06 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.464
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.734
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.491
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.057
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.279
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.580
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.517
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.596
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.596
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.167
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.440
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.675
# [10/12 21:44:14 d2.evaluation.coco_evaluation]: Evaluation results for segm:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 46.388 | 73.407 | 49.085 | 5.717 | 27.924 | 58.042 |
# [10/12 21:44:14 d2.evaluation.coco_evaluation]: Per-category segm AP:
# | category        | AP     | category      | AP     | category     | AP     |
# |:----------------|:-------|:--------------|:-------|:-------------|:-------|
# | Quarter-panel   | 21.299 | Front-wheel   | 61.677 | Back-window  | 48.801 |
# | Trunk           | 11.987 | Front-door    | 68.108 | Rocker-panel | 12.531 |
# | Grille          | 36.798 | Windshield    | 69.622 | Front-window | 50.712 |
# | Back-door       | 63.256 | Headlight     | 56.101 | Back-wheel   | 55.570 |
# | Back-windshield | 54.611 | Hood          | 68.644 | Fender       | 40.394 |
# | Tail-light      | 43.020 | License-plate | 34.173 | Front-bumper | 50.839 |
# | Back-bumper     | 46.934 | Mirror        | 47.076 | Roof         | 31.988 |
# [10/12 21:44:14 d2.engine.defaults]: Evaluation results for car_val in csv format:
# [10/12 21:44:14 d2.evaluation.testing]: copypaste: Task: bbox
# [10/12 21:44:14 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [10/12 21:44:14 d2.evaluation.testing]: copypaste: 45.8760,76.2590,49.2135,8.9257,31.2532,53.4141
# [10/12 21:44:14 d2.evaluation.testing]: copypaste: Task: segm
# [10/12 21:44:14 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [10/12 21:44:14 d2.evaluation.testing]: copypaste: 46.3877,73.4075,49.0853,5.7173,27.9240,58.0415

# %%
import os
import torch
from detectron2.engine import DefaultPredictor  # Import DefaultPredictor

# Set the path to the trained model
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")  # path to the model we just trained
# Set a custom testing threshold
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5

# Create a predictor
predictor = DefaultPredictor(cfg)
# Out:
# [10/12 21:46:51 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from ./output_20241012_181751\model_final.pth ...
# C:\Users\kurt_\anaconda3\envs\my-env-detectron2\lib\site-packages\fvcore\common\checkpoint.py:252: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(f, map_location=torch.device("cpu"))

# %%
import json
import pandas as pd

metrics_path = "C:/Users/kurt_/car-parts-and-damage-detection/car-part-detection/output_20241012_181751/metrics.json"
metrics_columns = [
    "data_time",
    "eta_seconds",
    "fast_rcnn/cls_accuracy",
    "fast_rcnn/false_negative",
    "fast_rcnn/fg_cls_accuracy",
    "iteration",
    "loss_box_reg",
    "loss_cls",
    "loss_mask",
    "loss_rpn_cls",
    "loss_rpn_loc",
    "lr",
    "mask_rcnn/accuracy",
    "mask_rcnn/false_negative",
    "mask_rcnn/false_positive",
    "rank_data_time",
    "roi_head/num_bg_samples",
    "roi_head/num_fg_samples",
    "rpn/num_neg_anchors",
    "rpn/num_pos_anchors",
    "time",
    "total_loss"
]


data = []
with open(metrics_path, 'r') as f:
    for line in f:
        json_data = json.loads(line)
        filtered_data = {metric: json_data.get(metric, None) for metric in metrics_columns}
        data.append(filtered_data)

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#      data_time  eta_seconds  fast_rcnn/cls_accuracy  fast_rcnn/false_negative  \
# 0     0.003757  1778.721472                0.000000                    0.0000
# 1     0.004266  1786.503116                0.031250                    0.0000
# 2     0.003814  1774.432149                0.281250                    0.3750
# 3     0.004029  1774.540356                0.718750                    0.9375
# 4     0.004229  1760.185740                0.750000                    1.0000
# ..         ...          ...                     ...                       ...
# 146   0.004358    36.957888                0.875000                    0.1875
# 147   0.004089    24.584768                0.859375                    0.2500
# 148   0.004554    12.345822                0.875000                    0.2500
# 149   0.004245     0.000000                0.875000                    0.2500
# 150        NaN          NaN                     NaN                       NaN
#
#      fast_rcnn/fg_cls_accuracy  iteration  loss_box_reg  loss_cls  loss_mask  \
# 0                       0.0000         19      0.727930  3.216833   0.693677
# 1                       0.0000         39      0.814991  3.104049   0.693099
# 2                       0.0000         59      0.803935  2.918550   0.692438
# 3                       0.0000         79      0.857741  2.586980   0.691852
# 4                       0.0000         99      0.792871  2.208747   0.691339
# ..                         ...        ...           ...       ...        ...
# 146                     0.6875       2939      0.473386  0.332637   0.227094
# 147                     0.6250       2959      0.468044  0.405895   0.228669
# 148                     0.6250       2979      0.450537  0.378396   0.207507
# 149                     0.6875       2999      0.421186  0.332851   0.199095
# 150                        NaN       3000           NaN       NaN        NaN
#
#      loss_rpn_cls  ...  mask_rcnn/accuracy  mask_rcnn/false_negative  \
# 0        1.700828  ...            0.481266                  0.457282
# 1        1.218242  ...            0.507015                  0.473134
# 2        0.718701  ...            0.554608                  0.315222
# 3        0.477737  ...            0.590880                  0.253791
# 4        0.322466  ...            0.615753                  0.252853
# ..            ...  ...                 ...                       ...
# 146      0.026180  ...            0.902663                  0.088560
# 147      0.030247  ...            0.901786                  0.083425
# 148      0.025192  ...            0.915896                  0.083918
# 149      0.027746  ...            0.914142                  0.080180
# 150           NaN  ...                 NaN                       NaN
#
#      mask_rcnn/false_positive  rank_data_time  roi_head/num_bg_samples  \
# 0                    0.589385        0.003757                      6.0
# 1                    0.518350        0.004266                      6.0
# 2                    0.583719        0.003814                      6.0
# 3                    0.558643        0.004029                      6.0
# 4                    0.500865        0.004229                      6.0
# ..                        ...             ...                      ...
# 146                  0.089810        0.004358                      6.0
# 147                  0.095929        0.004089                      6.0
# 148                  0.083691        0.004554                      6.0
# 149                  0.101389        0.004245                      6.0
# 150                       NaN             NaN                      NaN
#
#      roi_head/num_fg_samples  rpn/num_neg_anchors  rpn/num_pos_anchors  \
# 0                        2.0              168.375               87.625
# 1                        2.0              166.375               89.625
# 2                        2.0              176.125               79.875
# 3                        2.0              168.750               87.250
# 4                        2.0              164.375               91.625
# ..                       ...                  ...                  ...
# 146                      2.0              173.000               83.000
# 147                      2.0              164.250               91.750
# 148                      2.0              171.500               84.500
# 149                      2.0              170.500               85.500
# 150                      NaN                  NaN                  NaN
#
#          time  total_loss
# 0    0.596886    6.611365
# 1    0.607585    6.027338
# 2    0.605213    5.405708
# 3    0.616590    4.920369
# 4    0.604332    4.248926
# ..        ...         ...
# 146  7.183139    1.190171
# 147  0.590353    1.219376
# 148  0.799253    1.213153
# 149  0.598507    1.153764
# 150       NaN         NaN
#
# [151 rows x 22 columns]

# %%
df = df.dropna()
df
# Out:
#      data_time  eta_seconds  fast_rcnn/cls_accuracy  fast_rcnn/false_negative  \
# 0     0.003757  1778.721472                0.000000                    0.0000
# 1     0.004266  1786.503116                0.031250                    0.0000
# 2     0.003814  1774.432149                0.281250                    0.3750
# 3     0.004029  1774.540356                0.718750                    0.9375
# 4     0.004229  1760.185740                0.750000                    1.0000
# ..         ...          ...                     ...                       ...
# 145   0.004316    49.176836                0.906250                    0.2500
# 146   0.004358    36.957888                0.875000                    0.1875
# 147   0.004089    24.584768                0.859375                    0.2500
# 148   0.004554    12.345822                0.875000                    0.2500
# 149   0.004245     0.000000                0.875000                    0.2500
#
#      fast_rcnn/fg_cls_accuracy  iteration  loss_box_reg  loss_cls  loss_mask  \
# 0                       0.0000         19      0.727930  3.216833   0.693677
# 1                       0.0000         39      0.814991  3.104049   0.693099
# 2                       0.0000         59      0.803935  2.918550   0.692438
# 3                       0.0000         79      0.857741  2.586980   0.691852
# 4                       0.0000         99      0.792871  2.208747   0.691339
# ..                         ...        ...           ...       ...        ...
# 145                     0.6250       2919      0.479155  0.317997   0.198598
# 146                     0.6875       2939      0.473386  0.332637   0.227094
# 147                     0.6250       2959      0.468044  0.405895   0.228669
# 148                     0.6250       2979      0.450537  0.378396   0.207507
# 149                     0.6875       2999      0.421186  0.332851   0.199095
#
#      loss_rpn_cls  ...  mask_rcnn/accuracy  mask_rcnn/false_negative  \
# 0        1.700828  ...            0.481266                  0.457282
# 1        1.218242  ...            0.507015                  0.473134
# 2        0.718701  ...            0.554608                  0.315222
# 3        0.477737  ...            0.590880                  0.253791
# 4        0.322466  ...            0.615753                  0.252853
# ..            ...  ...                 ...                       ...
# 145      0.026755  ...            0.915338                  0.086613
# 146      0.026180  ...            0.902663                  0.088560
# 147      0.030247  ...            0.901786                  0.083425
# 148      0.025192  ...            0.915896                  0.083918
# 149      0.027746  ...            0.914142                  0.080180
#
#      mask_rcnn/false_positive  rank_data_time  roi_head/num_bg_samples  \
# 0                    0.589385        0.003757                      6.0
# 1                    0.518350        0.004266                      6.0
# 2                    0.583719        0.003814                      6.0
# 3                    0.558643        0.004029                      6.0
# 4                    0.500865        0.004229                      6.0
# ..                        ...             ...                      ...
# 145                  0.098864        0.004316                      6.0
# 146                  0.089810        0.004358                      6.0
# 147                  0.095929        0.004089                      6.0
# 148                  0.083691        0.004554                      6.0
# 149                  0.101389        0.004245                      6.0
#
#      roi_head/num_fg_samples  rpn/num_neg_anchors  rpn/num_pos_anchors  \
# 0                        2.0              168.375               87.625
# 1                        2.0              166.375               89.625
# 2                        2.0              176.125               79.875
# 3                        2.0              168.750               87.250
# 4                        2.0              164.375               91.625
# ..                       ...                  ...                  ...
# 145                      2.0              169.375               86.625
# 146                      2.0              173.000               83.000
# 147                      2.0              164.250               91.750
# 148                      2.0              171.500               84.500
# 149                      2.0              170.500               85.500
#
#          time  total_loss
# 0    0.596886    6.611365
# 1    0.607585    6.027338
# 2    0.605213    5.405708
# 3    0.616590    4.920369
# 4    0.604332    4.248926
# ..        ...         ...
# 145  0.728208    1.207458
# 146  7.183139    1.190171
# 147  0.590353    1.219376
# 148  0.799253    1.213153
# 149  0.598507    1.153764
#
# [150 rows x 22 columns]

# %%
# F1 Skoru Hesaplama
# F1 Skoru = 2 * (Precision * Recall) / (Precision + Recall)
# Precision = TP / (TP + FP)
# Recall = TP / (TP + FN)

# Varsayımsal olarak mask_rcnn accuracy ve false negative / positive kullanılarak hesaplama
precision = 1 - df['mask_rcnn/false_positive']
recall = 1 - df['mask_rcnn/false_negative']
f1_score = 2 * (precision * recall) / (precision + recall)

# %%
import matplotlib.pyplot as plt
#(Loss) 
plt.figure(figsize=(10, 6))
plt.plot(df['iteration'], df['total_loss'], label='Total Loss')
plt.plot(df['iteration'], df['loss_cls'], label='Classification Loss')
plt.plot(df['iteration'], df['loss_box_reg'], label='Box Regression Loss')
plt.plot(df['iteration'], df['loss_mask'], label='Mask Loss')
plt.plot(df['iteration'], df['loss_rpn_cls'], label='RPN Classification Loss')
plt.plot(df['iteration'], df['loss_rpn_loc'], label='RPN Location Loss')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.title('Loss During Training')
plt.legend()
plt.grid(True)
plt.show()

#  Mask R-CNN Accuracy, False Positive, False Negative 
plt.figure(figsize=(10, 6))
plt.plot(df['iteration'], df['mask_rcnn/accuracy'], label='Mask R-CNN Accuracy')
plt.plot(df['iteration'], df['mask_rcnn/false_positive'], label='Mask R-CNN False Positive')
plt.plot(df['iteration'], df['mask_rcnn/false_negative'], label='Mask R-CNN False Negative')
plt.xlabel('Iteration')
plt.ylabel('Accuracy / Error Rate')
plt.title('Mask R-CNN Accuracy and Error Rates')
plt.legend()
plt.grid(True)
plt.show()

# %%
#f1 score
plt.figure(figsize=(10, 6))
plt.plot(df['iteration'], f1_score, label='F1 Score', color='purple')
plt.xlabel('Iteration')
plt.ylabel('F1 Score')
plt.title('F1 Score During Training')
plt.legend()
plt.grid(True)
plt.show()

# Recall
plt.figure(figsize=(10, 6))
plt.plot(df['iteration'], recall, label='Recall', color='green')
plt.xlabel('Iteration')
plt.ylabel('Recall')
plt.title('Recall During Training')
plt.legend()
plt.grid(True)
plt.show()

# Precision
plt.figure(figsize=(10, 6))
plt.plot(df['iteration'], precision, label='Precision', color='blue')
plt.xlabel('Iteration')
plt.ylabel('Precision')
plt.title('Precision During Training')
plt.legend()
plt.grid(True)
plt.show()

# %%
df = df.assign(precision=precision, recall=recall, f1_score=f1_score,)
result_table = df[['iteration', 'precision', 'recall', 'f1_score']]
result_table
# Out:
#      iteration  precision    recall  f1_score
# 0           19   0.410615  0.542718  0.467514
# 1           39   0.481650  0.526866  0.503244
# 2           59   0.416281  0.684778  0.517792
# 3           79   0.441357  0.746209  0.554655
# 4           99   0.499135  0.747147  0.598464
# ..         ...        ...       ...       ...
# 145       2919   0.901136  0.913387  0.907220
# 146       2939   0.910190  0.911440  0.910815
# 147       2959   0.904071  0.916575  0.910280
# 148       2979   0.916309  0.916082  0.916196
# 149       2999   0.898611  0.919820  0.909092
#
# [150 rows x 4 columns]

# %%
import cv2
import matplotlib.pyplot as plt
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog

# Load image
im = cv2.imread("C:/Users/kurt_/Downloads/deneme.jpg")

# Make predictions using the predictor
output = predictor(im)

# Visualize original image
plt.subplot(1, 2, 1)
plt.imshow(im[:, :, ::-1])
plt.title('Original Image')
plt.axis('off')

# Draw the predictions on the test image
v = Visualizer(im[:, :, ::-1], metadata=MetadataCatalog.get(cfg.DATASETS.TRAIN[0]), scale=1)
out = v.draw_instance_predictions(output["instances"].to("cpu"))

# Show the image with predictions
plt.subplot(1, 2, 2)
plt.imshow(out.get_image()[:, :, ::-1])
plt.title('Predicted Image')
plt.axis('off')

plt.show()

detected_classes = output["instances"].pred_classes.tolist()

front_components = {6, 10, 13, 17,16}  # Grille, Headlight, Hood, Front-bumper
back_components = {3, 15, 2, 18, 16}  # Trunk, Tail-light, Back-window, Back-bumper, License-plate
side_components = {0, 1, 4, 5, 8, 9, 11, 19, 20}  # Quarter-panel, Front-wheel, Front-door, Rocker-panel, Front-window, Back-door, Back-wheel

# Score for each component type, normalized to 1 for simplicity
score_per_component = 0.33333

def determine_car_view(detected_classes):
    # Count detected components in each component group
    front_count = len(front_components.intersection(detected_classes))
    back_count = len(back_components.intersection(detected_classes))
    side_count = len(side_components.intersection(detected_classes))
    
    # Calculate the score based on the component count
    front_score = front_count * score_per_component / len(front_components) if front_count > 0 else 0
    back_score = back_count * score_per_component / len(back_components) if back_count > 0 else 0
    side_score = side_count * score_per_component / len(side_components) if side_count > 0 else 0

    print(f'Front score: {front_score}')
    print(f'Back score: {back_score}')
    print(f'Side score: {side_score}')

    # Determine the view based on the scores
    if front_score > max(back_score, side_score):
        return "Front"
    elif back_score > max(front_score, side_score):
        return "Back"
    elif side_score > max(front_score, back_score):
        return "Side"
    else:
        return "Unknown"

# Example use case
view = determine_car_view(detected_classes)
print(f'The detected view of the car is: {view}')
# Out:
# Front score: 0.066666
# Back score: 0.066666
# Side score: 0.2592566666666667
# The detected view of the car is: Side
