# %%
import sys, os, json, random
import torch
import sys
import datetime

import cv2

import numpy as np
import pandas as pd

import skimage.io as io

import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = [16,9]
# %matplotlib inline

from shapely.geometry import Polygon

# path to the images
data_dir = "C:/Users/kurt_/car-parts-and-damage-detection-v3/car-part-detection/car-part/File1"

# create paths for traininig and validaiton data
os.makedirs("C:/Users/kurt_/car-parts-and-damage-detection-v3/car-part-detection/working/data/", exist_ok=True)
os.makedirs("C:/Users/kurt_/car-parts-and-damage-detection-v3/car-part-detection/working/data/train/", exist_ok=True)
os.makedirs("C:/Users/kurt_/car-parts-and-damage-detection-v3/car-part-detection/working/data/val/", exist_ok=True)


# create path to store the model config
os.makedirs("C:/Users/kurt_/car-parts-and-damage-detection-v3/car-part-detection/working/model/", exist_ok=True)

data_working_dir = "C:/Users/kurt_/car-parts-and-damage-detection-v3/car-part-detection/working/data/"
model_dir = "C:/Users/kurt_/car-parts-and-damage-detection-v3/car-part-detection/working/model/"

# %%
import json
import os
import shutil
import random
from PIL import Image

# Paths to your dataset
images_dir = os.path.join(data_dir, "img")
annotations_dir = os.path.join(data_dir, "ann")

# Get list of images
images = [f for f in os.listdir(images_dir) if os.path.isfile(os.path.join(images_dir, f))]

# Shuffle the images
random.shuffle(images)

# Split the dataset (e.g., 80% train, 20% val)
split_index = int(0.8 * len(images))
train_images = images[:split_index]
val_images = images[split_index:]

def convert_to_coco(images, images_dir, annotations_dir, output_dir):
    coco_output = {
        "images": [],
        "annotations": [],
        "categories": []
    }

    category_mapping = {
        "Quarter-panel": 1,
        "Front-wheel": 2,
        "Back-window": 3,
        "Trunk": 4,
        "Front-door": 5,
        "Rocker-panel": 6,
        "Grille": 7,
        "Windshield": 8,
        "Front-window": 9,
        "Back-door": 10,
        "Headlight": 11,
        "Back-wheel": 12,
        "Back-windshield": 13,
        "Hood": 14,
        "Fender": 15,
        "Tail-light": 16,
        "License-plate": 17,
        "Front-bumper": 18,
        "Back-bumper": 19,
        "Mirror": 20,
        "Roof": 21
    }

    for category, id in category_mapping.items():
        coco_output["categories"].append({
            "id": id,
            "name": category
        })

    annotation_id = 1
    for idx, image_filename in enumerate(images):
        image_path = os.path.join(images_dir, image_filename)
        annotation_path = os.path.join(annotations_dir, image_filename + ".json")
        
        # Copy the image to the output directory
        shutil.copy(image_path, output_dir)
        
        # Open the image to get its dimensions
        with Image.open(image_path) as img:
            width, height = img.size
        
        coco_output["images"].append({
            "file_name": image_filename,
            "height": height,
            "width": width,
            "id": idx
        })
        
        with open(annotation_path) as f:
            objs = json.load(f)["objects"]

        for obj in objs:
            px = [point[0] for point in obj["points"]["exterior"]]
            py = [point[1] for point in obj["points"]["exterior"]]
            poly = [(x, y) for x, y in zip(px, py)]
            poly = [p for x in poly for p in x]

            category_id = category_mapping.get(obj["classTitle"], -1)
            if category_id == -1:
                continue  # Skip unknown categories
            
            bbox = [min(px), min(py), max(px) - min(px), max(py) - min(py)]
            
            coco_output["annotations"].append({
                "bbox": bbox,
                "category_id": category_id,
                "image_id": idx,
                "segmentation": [poly],
                "area": bbox[2] * bbox[3],
                "iscrowd": 0,
                "id": annotation_id
            })
            annotation_id += 1

    return coco_output

train_output = convert_to_coco(train_images, images_dir, annotations_dir, os.path.join(data_working_dir, "train"))
val_output = convert_to_coco(val_images, images_dir, annotations_dir, os.path.join(data_working_dir, "val"))

with open(os.path.join(data_working_dir, "train", "annotations.json"), "w") as f:
    json.dump(train_output, f, indent=4)

with open(os.path.join(data_working_dir, "val", "annotations.json"), "w") as f:
    json.dump(val_output, f, indent=4)

print("COCO annotations for train and val sets have been created.")
# Out:
# COCO annotations for train and val sets have been created.

# %%
from detectron2.data.datasets import register_coco_instances

# Register train and val datasets
register_coco_instances("car_train", {}, os.path.join(data_working_dir, "train", "annotations.json"), os.path.join(data_working_dir, "train"))
register_coco_instances("car_val", {}, os.path.join(data_working_dir, "val", "annotations.json"), os.path.join(data_working_dir, "val"))

# Load metadata
from detectron2.data import MetadataCatalog
car_metadata = MetadataCatalog.get("car_train")

# %%
import random
from detectron2.utils.visualizer import Visualizer
from detectron2.data import DatasetCatalog

dataset_dicts = DatasetCatalog.get("car_train")
for d in random.sample(dataset_dicts, 3):
    img = cv2.imread(d["file_name"])
    visualizer = Visualizer(img[:, :, ::-1], metadata=car_metadata, scale=0.5)
    vis = visualizer.draw_dataset_dict(d)
    plt.imshow(vis.get_image()[:, :, ::-1])
    plt.show()

# %%
import os
import torch
import detectron2
import datetime
from detectron2.engine import DefaultTrainer, hooks, HookBase
from detectron2.config import get_cfg
from detectron2 import model_zoo

# Define output directory
output_dir = "./output_" + datetime.datetime.now().strftime('%Y%m%d_%H%M%S')

# Create configuration
cfg = get_cfg()

# Set output directory
cfg.OUTPUT_DIR = output_dir

# Merge configuration from the model zoo
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))

# Set training and testing datasets
cfg.DATASETS.TRAIN = ("car_train",)
cfg.DATASETS.TEST = ("car_val",)  # for evaluation during training
cfg.DATALOADER.NUM_WORKERS = 4

# Set device to cuda if available
cfg.MODEL.DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'

# Set weights from the model zoo
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml")  # Let training initialize from model zoo

# Set batch size, learning rate, and maximum iterations
cfg.SOLVER.IMS_PER_BATCH = 8 # before 4
cfg.SOLVER.BASE_LR = 0.00025
cfg.SOLVER.MAX_ITER = 2650  # before 3000
cfg.SOLVER.STEPS = []  # do not decay learning rate

# Set batch size per image and number of classes
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 2   # before 8
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 21  # total number of classes

# Create output directory if it does not exist
os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)

# Custom Trainer to add hooks for status updates
class MyTrainer(DefaultTrainer):
    @classmethod
    def build_evaluator(cls, cfg, dataset_name, output_folder=None):
        from detectron2.evaluation import COCOEvaluator, inference_on_dataset, print_csv_format
        return COCOEvaluator(dataset_name, cfg, False, output_folder)

    def build_hooks(self):
        hooks = super().build_hooks()
        hooks.insert(0, PrintTrainingStatus())
        return hooks

# Custom hook to print training status
class PrintTrainingStatus(HookBase):
    def after_step(self):
        # Print training status every 100 iterations
        if self.trainer.iter % 500 == 0 or self.trainer.iter == self.trainer.max_iter:
            print(f"Iteration {self.trainer.iter}/{self.trainer.max_iter} - Loss: {self.trainer.storage.latest()['total_loss']}")

# Create a trainer
trainer = MyTrainer(cfg)

# Load the model or resume training
trainer.resume_or_load(resume=False)

# Train the model
trainer.train()
# Out:
# [10/27 15:16:27 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=22, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=84, bias=True)
#     )
#     (mask_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(14, 14), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(14, 14), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(14, 14), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(14, 14), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (mask_head): MaskRCNNConvUpsampleHead(
#       (mask_fcn1): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn2): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn3): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn4): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (deconv): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#       (deconv_relu): ReLU()
#       (predictor): Conv2d(256, 21, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )
# [10/27 15:16:27 d2.data.datasets.coco]: Loaded 798 images in COCO format from C:/Users/kurt_/car-parts-and-damage-detection-v3/car-part-detection/working/data/train\annotations.json
# [10/27 15:16:28 d2.data.build]: Removed 0 images with no usable annotations. 798 images left.
# [10/27 15:16:28 d2.data.build]: Distribution of instances among all 21 categories:
# |   category    | #instances   |   category    | #instances   |   category   | #instances   |
# |:-------------:|:-------------|:-------------:|:-------------|:------------:|:-------------|
# | Quarter-panel | 682          |  Front-wheel  | 701          | Back-window  | 982          |
# |     Trunk     | 332          |  Front-door   | 731          | Rocker-panel | 687          |
# |    Grille     | 450          |  Windshield   | 501          | Front-window | 763          |
# |   Back-door   | 573          |   Headlight   | 730          |  Back-wheel  | 691          |
# | Back-windsh.. | 221          |     Hood      | 565          |    Fender    | 748          |
# |  Tail-light   | 586          | License-plate | 299          | Front-bumper | 562          |
# |  Back-bumper  | 362          |    Mirror     | 786          |     Roof     | 634          |
# |               |              |               |              |              |              |
# |     total     | 12586        |               |              |              |              |
# [10/27 15:16:28 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [10/27 15:16:28 d2.data.build]: Using training sampler TrainingSampler
# [10/27 15:16:28 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [10/27 15:16:28 d2.data.common]: Serializing 798 elements to byte tensors and concatenating them all ...
# [10/27 15:16:28 d2.data.common]: Serialized dataset takes 6.09 MiB
# [10/27 15:16:28 d2.data.build]: Making batched data loader with batch_size=8
# [10/27 15:16:28 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x/137849600/model_final_f10217.pkl ...
# Skip loading parameter 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (22, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (22,) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 1024) in the checkpoint but (84, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (84,) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.mask_head.predictor.weight' to the model due to incompatible shapes: (80, 256, 1, 1) in the checkpoint but (21, 256, 1, 1) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.mask_head.predictor.bias' to the model due to incompatible shapes: (80,) in the checkpoint but (21,) in the model! You might want to double check if this is expected.
# Some model parameters or buffers are not found in the checkpoint:
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# roi_heads.mask_head.predictor.{bias, weight}
# [10/27 15:16:28 d2.engine.train_loop]: Starting training from iteration 0
# C:\Users\kurt_\anaconda3\envs\my-env-detectron2\lib\site-packages\torch\functional.py:513: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\TensorShape.cpp:3610.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Iteration 0/2650 - Loss: (4.4131570011377335, 0)
# [10/27 15:21:58 d2.utils.events]:  eta: 7:56:24  iter: 19  total_loss: 4.984  loss_cls: 3.058  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 1.672  loss_rpn_loc: 0.2409    time: 15.9510  last_time: 10.2666  data_time: 0.1825  last_data_time: 0.0116   lr: 4.9953e-06  max_mem: 8047M
# [10/27 15:28:40 d2.utils.events]:  eta: 8:50:39  iter: 39  total_loss: 4.367  loss_cls: 2.875  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 1.259  loss_rpn_loc: 0.2532    time: 18.1284  last_time: 25.9477  data_time: 0.0108  last_data_time: 0.0066   lr: 9.9902e-06  max_mem: 8048M
# [10/27 15:35:10 d2.utils.events]:  eta: 17:31:03  iter: 59  total_loss: 3.434  loss_cls: 2.479  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.7492  loss_rpn_loc: 0.2158    time: 18.5980  last_time: 10.2104  data_time: 0.0103  last_data_time: 0.0073   lr: 1.4985e-05  max_mem: 8048M
# [10/27 15:40:25 d2.utils.events]:  eta: 8:33:15  iter: 79  total_loss: 2.699  loss_cls: 1.863  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.5414  loss_rpn_loc: 0.2265    time: 17.8758  last_time: 9.9254  data_time: 0.0116  last_data_time: 0.0170   lr: 1.998e-05  max_mem: 8048M
# [10/27 15:45:34 d2.utils.events]:  eta: 8:10:06  iter: 99  total_loss: 1.699  loss_cls: 1.088  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.3358  loss_rpn_loc: 0.2215    time: 17.3803  last_time: 25.6945  data_time: 0.0092  last_data_time: 0.0153   lr: 2.4975e-05  max_mem: 8048M
# [10/27 15:52:07 d2.utils.events]:  eta: 8:13:58  iter: 119  total_loss: 0.7878  loss_cls: 0.3612  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.1931  loss_rpn_loc: 0.2235    time: 17.7591  last_time: 25.3057  data_time: 0.0091  last_data_time: 0.0090   lr: 2.997e-05  max_mem: 8048M
# [10/27 15:57:57 d2.utils.events]:  eta: 8:10:04  iter: 139  total_loss: 0.5266  loss_cls: 0.1118  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.1634  loss_rpn_loc: 0.214    time: 17.7218  last_time: 10.7952  data_time: 0.0088  last_data_time: 0.0088   lr: 3.4965e-05  max_mem: 8048M
# [10/27 16:03:48 d2.utils.events]:  eta: 8:06:09  iter: 159  total_loss: 0.4218  loss_cls: 0.04285  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.1398  loss_rpn_loc: 0.2187    time: 17.7021  last_time: 10.9678  data_time: 0.0084  last_data_time: 0.0087   lr: 3.996e-05  max_mem: 8048M
# [10/27 16:09:07 d2.utils.events]:  eta: 7:58:22  iter: 179  total_loss: 0.3221  loss_cls: 0.02044  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.1133  loss_rpn_loc: 0.1733    time: 17.5068  last_time: 8.8045  data_time: 0.0094  last_data_time: 0.0183   lr: 4.4955e-05  max_mem: 8048M
# [10/27 16:15:16 d2.utils.events]:  eta: 7:56:39  iter: 199  total_loss: 0.3385  loss_cls: 0.02426  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.1144  loss_rpn_loc: 0.1878    time: 17.5997  last_time: 10.2966  data_time: 0.0096  last_data_time: 0.0095   lr: 4.995e-05  max_mem: 8048M
# [10/27 16:20:55 d2.utils.events]:  eta: 7:49:30  iter: 219  total_loss: 0.3115  loss_cls: 0.01405  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.1021  loss_rpn_loc: 0.1879    time: 17.5394  last_time: 11.2561  data_time: 0.0083  last_data_time: 0.0059   lr: 5.4945e-05  max_mem: 8049M
# [10/27 16:26:02 d2.utils.events]:  eta: 7:45:38  iter: 239  total_loss: 0.2758  loss_cls: 0.0144  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.08394  loss_rpn_loc: 0.1786    time: 17.3546  last_time: 26.1641  data_time: 0.0081  last_data_time: 0.0076   lr: 5.994e-05  max_mem: 8049M
# [10/27 16:33:18 d2.utils.events]:  eta: 7:47:10  iter: 259  total_loss: 0.2982  loss_cls: 0.007754  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.08535  loss_rpn_loc: 0.1982    time: 17.7000  last_time: 25.1222  data_time: 0.0101  last_data_time: 0.0061   lr: 6.4935e-05  max_mem: 8049M
# [10/27 16:38:32 d2.utils.events]:  eta: 7:38:36  iter: 279  total_loss: 0.2881  loss_cls: 0.005839  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.09198  loss_rpn_loc: 0.1834    time: 17.5560  last_time: 9.8991  data_time: 0.0094  last_data_time: 0.0082   lr: 6.993e-05  max_mem: 8049M
# [10/27 16:44:46 d2.utils.events]:  eta: 7:39:37  iter: 299  total_loss: 0.2895  loss_cls: 0.004538  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.0937  loss_rpn_loc: 0.1865    time: 17.6328  last_time: 29.0099  data_time: 0.0086  last_data_time: 0.0101   lr: 7.4925e-05  max_mem: 8049M
# [10/27 16:51:47 d2.utils.events]:  eta: 7:39:01  iter: 319  total_loss: 0.2704  loss_cls: 0.004362  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.07773  loss_rpn_loc: 0.1777    time: 17.8471  last_time: 26.0003  data_time: 0.0092  last_data_time: 0.0067   lr: 7.992e-05  max_mem: 8049M
# [10/27 16:57:35 d2.utils.events]:  eta: 7:33:10  iter: 339  total_loss: 0.2644  loss_cls: 0.005211  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.085  loss_rpn_loc: 0.1717    time: 17.8210  last_time: 10.5122  data_time: 0.0090  last_data_time: 0.0070   lr: 8.4915e-05  max_mem: 8049M
# [10/27 17:04:00 d2.utils.events]:  eta: 7:33:29  iter: 359  total_loss: 0.2756  loss_cls: 0.002578  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.07529  loss_rpn_loc: 0.1843    time: 17.9002  last_time: 10.0980  data_time: 0.0097  last_data_time: 0.0103   lr: 8.991e-05  max_mem: 8049M
# [10/27 17:10:54 d2.utils.events]:  eta: 7:39:18  iter: 379  total_loss: 0.2609  loss_cls: 0.003073  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.0733  loss_rpn_loc: 0.1765    time: 18.0501  last_time: 27.0259  data_time: 0.0093  last_data_time: 0.0091   lr: 9.4905e-05  max_mem: 8049M
# [10/27 17:17:23 d2.utils.events]:  eta: 7:37:27  iter: 399  total_loss: 0.2542  loss_cls: 0.001899  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.07639  loss_rpn_loc: 0.1701    time: 18.1208  last_time: 11.1677  data_time: 0.0101  last_data_time: 0.0069   lr: 9.99e-05  max_mem: 8049M
# [10/27 17:23:21 d2.utils.events]:  eta: 7:33:23  iter: 419  total_loss: 0.2427  loss_cls: 0.003435  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.06671  loss_rpn_loc: 0.1644    time: 18.1103  last_time: 27.2815  data_time: 0.0089  last_data_time: 0.0096   lr: 0.0001049  max_mem: 8049M
# [10/27 17:29:43 d2.utils.events]:  eta: 7:38:32  iter: 439  total_loss: 0.2701  loss_cls: 0.001743  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.0867  loss_rpn_loc: 0.1853    time: 18.1551  last_time: 26.2264  data_time: 0.0083  last_data_time: 0.0099   lr: 0.00010989  max_mem: 8049M
# [10/27 17:35:26 d2.utils.events]:  eta: 7:25:15  iter: 459  total_loss: 0.2297  loss_cls: 0.00163  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.06796  loss_rpn_loc: 0.1612    time: 18.1113  last_time: 11.3568  data_time: 0.0096  last_data_time: 0.0076   lr: 0.00011489  max_mem: 8049M
# [10/27 17:42:17 d2.utils.events]:  eta: 7:53:28  iter: 479  total_loss: 0.2675  loss_cls: 0.002056  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.07196  loss_rpn_loc: 0.1816    time: 18.2132  last_time: 27.4252  data_time: 0.0107  last_data_time: 0.0169   lr: 0.00011988  max_mem: 8049M
# [10/27 17:47:34 d2.utils.events]:  eta: 7:17:07  iter: 499  total_loss: 0.2281  loss_cls: 0.001031  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.06934  loss_rpn_loc: 0.1606    time: 18.1177  last_time: 25.9605  data_time: 0.0097  last_data_time: 0.0083   lr: 0.00012488  max_mem: 8049M
# Iteration 500/2650 - Loss: (0.20044768182560802, 500)
# [10/27 17:54:35 d2.utils.events]:  eta: 8:17:37  iter: 519  total_loss: 0.2468  loss_cls: 0.0005959  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.07262  loss_rpn_loc: 0.1737    time: 18.2304  last_time: 26.2339  data_time: 0.0091  last_data_time: 0.0093   lr: 0.00012987  max_mem: 8049M
# [10/27 18:01:03 d2.utils.events]:  eta: 9:13:20  iter: 539  total_loss: 0.2346  loss_cls: 0.00158  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.06132  loss_rpn_loc: 0.1755    time: 18.2749  last_time: 10.4399  data_time: 0.0094  last_data_time: 0.0081   lr: 0.00013487  max_mem: 8049M
# [10/27 18:06:56 d2.utils.events]:  eta: 8:40:06  iter: 559  total_loss: 0.2272  loss_cls: 0.001462  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.0598  loss_rpn_loc: 0.1589    time: 18.2510  last_time: 26.1593  data_time: 0.0092  last_data_time: 0.0125   lr: 0.00013986  max_mem: 8049M
# [10/27 18:13:11 d2.utils.events]:  eta: 9:05:51  iter: 579  total_loss: 0.2301  loss_cls: 0.0007405  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.06482  loss_rpn_loc: 0.1675    time: 18.2689  last_time: 25.5954  data_time: 0.0092  last_data_time: 0.0060   lr: 0.00014486  max_mem: 8049M
# [10/27 18:18:47 d2.utils.events]:  eta: 8:26:48  iter: 599  total_loss: 0.222  loss_cls: 0.0005681  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.05745  loss_rpn_loc: 0.1596    time: 18.2191  last_time: 10.8007  data_time: 0.0089  last_data_time: 0.0089   lr: 0.00014985  max_mem: 8049M
# [10/27 18:24:24 d2.utils.events]:  eta: 7:22:55  iter: 619  total_loss: 0.2116  loss_cls: 0.001143  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.06183  loss_rpn_loc: 0.1443    time: 18.1750  last_time: 11.0121  data_time: 0.0092  last_data_time: 0.0106   lr: 0.00015485  max_mem: 8050M
# [10/27 18:30:27 d2.utils.events]:  eta: 7:49:35  iter: 639  total_loss: 0.2179  loss_cls: 0.000606  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.05882  loss_rpn_loc: 0.1556    time: 18.1753  last_time: 11.1311  data_time: 0.0095  last_data_time: 0.0094   lr: 0.00015984  max_mem: 8050M
# [10/27 18:36:12 d2.utils.events]:  eta: 7:14:12  iter: 659  total_loss: 0.2088  loss_cls: 0.0006652  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.05948  loss_rpn_loc: 0.1558    time: 18.1464  last_time: 25.1418  data_time: 0.0089  last_data_time: 0.0084   lr: 0.00016484  max_mem: 8050M
# [10/27 18:42:32 d2.utils.events]:  eta: 7:40:14  iter: 679  total_loss: 0.2186  loss_cls: 0.0004328  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.05601  loss_rpn_loc: 0.1596    time: 18.1715  last_time: 24.3294  data_time: 0.0100  last_data_time: 0.0172   lr: 0.00016983  max_mem: 8050M
# [10/27 18:48:47 d2.utils.events]:  eta: 8:03:46  iter: 699  total_loss: 0.2223  loss_cls: 0.0005339  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.05068  loss_rpn_loc: 0.1715    time: 18.1887  last_time: 11.6329  data_time: 0.0095  last_data_time: 0.0063   lr: 0.00017483  max_mem: 8050M
# [10/27 18:55:31 d2.utils.events]:  eta: 8:28:56  iter: 719  total_loss: 0.2279  loss_cls: 0.0003717  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.06057  loss_rpn_loc: 0.1612    time: 18.2442  last_time: 11.1266  data_time: 0.0092  last_data_time: 0.0074   lr: 0.00017982  max_mem: 8050M
# [10/27 19:01:32 d2.utils.events]:  eta: 8:23:39  iter: 739  total_loss: 0.2094  loss_cls: 0.0004105  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.05591  loss_rpn_loc: 0.1578    time: 18.2390  last_time: 25.5868  data_time: 0.0091  last_data_time: 0.0072   lr: 0.00018482  max_mem: 8050M
# [10/27 19:07:09 d2.utils.events]:  eta: 7:50:46  iter: 759  total_loss: 0.2018  loss_cls: 0.0004225  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.05593  loss_rpn_loc: 0.1366    time: 18.2028  last_time: 10.9238  data_time: 0.0095  last_data_time: 0.0083   lr: 0.00018981  max_mem: 8050M
# [10/27 19:11:56 d2.utils.events]:  eta: 6:48:01  iter: 779  total_loss: 0.2136  loss_cls: 0.0004097  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.05592  loss_rpn_loc: 0.1588    time: 18.1036  last_time: 10.0999  data_time: 0.0095  last_data_time: 0.0072   lr: 0.00019481  max_mem: 8050M
# [10/27 19:19:14 d2.utils.events]:  eta: 7:40:48  iter: 799  total_loss: 0.2215  loss_cls: 0.0002494  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.06158  loss_rpn_loc: 0.1625    time: 18.1986  last_time: 11.2602  data_time: 0.0086  last_data_time: 0.0100   lr: 0.0001998  max_mem: 8050M
# [10/27 19:25:01 d2.utils.events]:  eta: 7:34:00  iter: 819  total_loss: 0.1879  loss_cls: 0.0003011  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.04991  loss_rpn_loc: 0.137    time: 18.1783  last_time: 25.8829  data_time: 0.0088  last_data_time: 0.0071   lr: 0.0002048  max_mem: 8050M
# [10/27 19:30:29 d2.utils.events]:  eta: 7:07:30  iter: 839  total_loss: 0.2132  loss_cls: 0.0005384  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.0609  loss_rpn_loc: 0.1413    time: 18.1352  last_time: 26.3890  data_time: 0.0094  last_data_time: 0.0058   lr: 0.00020979  max_mem: 8050M
# [10/27 19:36:55 d2.utils.events]:  eta: 7:22:32  iter: 859  total_loss: 0.221  loss_cls: 0.0002739  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.05856  loss_rpn_loc: 0.1616    time: 18.1620  last_time: 11.2416  data_time: 0.0079  last_data_time: 0.0058   lr: 0.00021479  max_mem: 8050M
# [10/27 19:42:57 d2.utils.events]:  eta: 7:17:35  iter: 879  total_loss: 0.2122  loss_cls: 0.0004325  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.04856  loss_rpn_loc: 0.1677    time: 18.1608  last_time: 10.6077  data_time: 0.0089  last_data_time: 0.0079   lr: 0.00021978  max_mem: 8050M
# [10/27 19:48:31 d2.utils.events]:  eta: 6:29:50  iter: 899  total_loss: 0.207  loss_cls: 0.0001709  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.05454  loss_rpn_loc: 0.1467    time: 18.1286  last_time: 26.2133  data_time: 0.0090  last_data_time: 0.0097   lr: 0.00022478  max_mem: 8050M
# [10/27 19:55:15 d2.utils.events]:  eta: 7:09:12  iter: 919  total_loss: 0.1997  loss_cls: 0.0001614  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.04868  loss_rpn_loc: 0.1477    time: 18.1729  last_time: 10.6455  data_time: 0.0099  last_data_time: 0.0081   lr: 0.00022977  max_mem: 8050M
# [10/27 20:01:16 d2.utils.events]:  eta: 7:02:45  iter: 939  total_loss: 0.1811  loss_cls: 0.0002765  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.04213  loss_rpn_loc: 0.1387    time: 18.1703  last_time: 27.5950  data_time: 0.0109  last_data_time: 0.0060   lr: 0.00023477  max_mem: 8050M
# [10/27 20:07:41 d2.utils.events]:  eta: 6:57:48  iter: 959  total_loss: 0.1974  loss_cls: 0.0001643  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.04938  loss_rpn_loc: 0.1429    time: 18.1932  last_time: 11.4116  data_time: 0.0088  last_data_time: 0.0063   lr: 0.00023976  max_mem: 8050M
# [10/27 20:13:42 d2.utils.events]:  eta: 6:12:00  iter: 979  total_loss: 0.21  loss_cls: 0.0001289  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.05398  loss_rpn_loc: 0.1524    time: 18.1901  last_time: 11.5969  data_time: 0.0087  last_data_time: 0.0076   lr: 0.00024476  max_mem: 8050M
# [10/27 20:19:04 d2.utils.events]:  eta: 5:45:34  iter: 999  total_loss: 0.2171  loss_cls: 0.0002094  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.05181  loss_rpn_loc: 0.1553    time: 18.1480  last_time: 11.1081  data_time: 0.0076  last_data_time: 0.0077   lr: 0.00024975  max_mem: 8050M
# Iteration 1000/2650 - Loss: (0.20634086422660403, 1000)
# [10/27 20:25:32 d2.utils.events]:  eta: 6:03:06  iter: 1019  total_loss: 0.1936  loss_cls: 0.0001371  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.04543  loss_rpn_loc: 0.1466    time: 18.1732  last_time: 28.3945  data_time: 0.0093  last_data_time: 0.0074   lr: 0.00025  max_mem: 8050M
# [10/27 20:31:36 d2.utils.events]:  eta: 5:48:28  iter: 1039  total_loss: 0.1984  loss_cls: 0.0001896  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.04974  loss_rpn_loc: 0.1493    time: 18.1735  last_time: 30.8285  data_time: 0.0085  last_data_time: 0.0081   lr: 0.00025  max_mem: 8050M
# [10/27 20:37:33 d2.utils.events]:  eta: 5:39:33  iter: 1059  total_loss: 0.1996  loss_cls: 0.0001787  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.05046  loss_rpn_loc: 0.1466    time: 18.1671  last_time: 27.3227  data_time: 0.0080  last_data_time: 0.0068   lr: 0.00025  max_mem: 8050M
# [10/27 20:44:29 d2.utils.events]:  eta: 5:42:56  iter: 1079  total_loss: 0.1992  loss_cls: 9.247e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.04824  loss_rpn_loc: 0.1527    time: 18.2165  last_time: 12.2225  data_time: 0.0089  last_data_time: 0.0153   lr: 0.00025  max_mem: 8050M
# [10/27 20:50:45 d2.utils.events]:  eta: 5:41:53  iter: 1099  total_loss: 0.1865  loss_cls: 0.0002365  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.04649  loss_rpn_loc: 0.1368    time: 18.2267  last_time: 30.2615  data_time: 0.0121  last_data_time: 0.0174   lr: 0.00025  max_mem: 8050M
# [10/27 20:57:02 d2.utils.events]:  eta: 5:31:50  iter: 1119  total_loss: 0.1952  loss_cls: 0.000104  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.04589  loss_rpn_loc: 0.1408    time: 18.2382  last_time: 11.9822  data_time: 0.0092  last_data_time: 0.0152   lr: 0.00025  max_mem: 8050M
# [10/27 21:03:18 d2.utils.events]:  eta: 5:29:50  iter: 1139  total_loss: 0.1926  loss_cls: 0.0001118  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.04576  loss_rpn_loc: 0.1526    time: 18.2479  last_time: 10.2555  data_time: 0.0087  last_data_time: 0.0073   lr: 0.00025  max_mem: 8050M
# [10/27 21:09:48 d2.utils.events]:  eta: 5:31:19  iter: 1159  total_loss: 0.184  loss_cls: 0.0001423  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.04538  loss_rpn_loc: 0.1399    time: 18.2694  last_time: 25.4108  data_time: 0.0085  last_data_time: 0.0067   lr: 0.00025  max_mem: 8050M
# [10/27 21:15:06 d2.utils.events]:  eta: 5:26:52  iter: 1179  total_loss: 0.1847  loss_cls: 0.000129  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.04668  loss_rpn_loc: 0.14    time: 18.2292  last_time: 10.0484  data_time: 0.0079  last_data_time: 0.0091   lr: 0.00025  max_mem: 8050M
# [10/27 21:21:09 d2.utils.events]:  eta: 5:22:25  iter: 1199  total_loss: 0.1827  loss_cls: 0.0001258  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.04343  loss_rpn_loc: 0.1387    time: 18.2277  last_time: 24.8231  data_time: 0.0104  last_data_time: 0.0099   lr: 0.00025  max_mem: 8050M
# [10/27 21:27:06 d2.utils.events]:  eta: 5:24:21  iter: 1219  total_loss: 0.1783  loss_cls: 6.729e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.04604  loss_rpn_loc: 0.1277    time: 18.2217  last_time: 10.3669  data_time: 0.0091  last_data_time: 0.0080   lr: 0.00025  max_mem: 8050M
# [10/27 21:32:57 d2.utils.events]:  eta: 5:51:12  iter: 1239  total_loss: 0.1892  loss_cls: 9.135e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.04255  loss_rpn_loc: 0.1412    time: 18.2106  last_time: 10.3835  data_time: 0.0080  last_data_time: 0.0076   lr: 0.00025  max_mem: 8050M
# [10/27 21:39:03 d2.utils.events]:  eta: 5:13:56  iter: 1259  total_loss: 0.1766  loss_cls: 8.604e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.04122  loss_rpn_loc: 0.1337    time: 18.2119  last_time: 25.9514  data_time: 0.0088  last_data_time: 0.0074   lr: 0.00025  max_mem: 8050M
# [10/27 21:45:19 d2.utils.events]:  eta: 5:41:15  iter: 1279  total_loss: 0.1876  loss_cls: 0.0001099  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.04406  loss_rpn_loc: 0.1423    time: 18.2212  last_time: 10.9454  data_time: 0.0091  last_data_time: 0.0082   lr: 0.00025  max_mem: 8050M
# [10/27 21:49:52 d2.utils.events]:  eta: 5:03:08  iter: 1299  total_loss: 0.1946  loss_cls: 0.0002371  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.0488  loss_rpn_loc: 0.1453    time: 18.1507  last_time: 26.2062  data_time: 0.0092  last_data_time: 0.0192   lr: 0.00025  max_mem: 8050M
# [10/27 21:55:07 d2.utils.events]:  eta: 4:46:42  iter: 1319  total_loss: 0.1823  loss_cls: 7.389e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.04284  loss_rpn_loc: 0.1411    time: 18.1147  last_time: 9.9666  data_time: 0.0076  last_data_time: 0.0079   lr: 0.00025  max_mem: 8050M
# [10/27 22:01:54 d2.utils.events]:  eta: 4:48:41  iter: 1339  total_loss: 0.1757  loss_cls: 6.683e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03934  loss_rpn_loc: 0.136    time: 18.1477  last_time: 24.3968  data_time: 0.0083  last_data_time: 0.0094   lr: 0.00025  max_mem: 8050M
# [10/27 22:08:12 d2.utils.events]:  eta: 4:41:46  iter: 1359  total_loss: 0.1838  loss_cls: 4.086e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.04115  loss_rpn_loc: 0.1383    time: 18.1588  last_time: 11.1239  data_time: 0.0085  last_data_time: 0.0087   lr: 0.00025  max_mem: 8050M
# [10/27 22:14:19 d2.utils.events]:  eta: 4:33:46  iter: 1379  total_loss: 0.2087  loss_cls: 5.664e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.04428  loss_rpn_loc: 0.16    time: 18.1616  last_time: 10.7065  data_time: 0.0079  last_data_time: 0.0080   lr: 0.00025  max_mem: 8050M
# [10/27 22:20:42 d2.utils.events]:  eta: 4:29:28  iter: 1399  total_loss: 0.1703  loss_cls: 8.19e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.04193  loss_rpn_loc: 0.1307    time: 18.1760  last_time: 25.8214  data_time: 0.0095  last_data_time: 0.0080   lr: 0.00025  max_mem: 8050M
# [10/27 22:27:02 d2.utils.events]:  eta: 4:25:53  iter: 1419  total_loss: 0.1834  loss_cls: 2.54e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.04047  loss_rpn_loc: 0.1344    time: 18.1875  last_time: 10.9321  data_time: 0.0079  last_data_time: 0.0064   lr: 0.00025  max_mem: 8050M
# [10/27 22:32:37 d2.utils.events]:  eta: 4:19:06  iter: 1439  total_loss: 0.1692  loss_cls: 7.104e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.04036  loss_rpn_loc: 0.1273    time: 18.1678  last_time: 11.7897  data_time: 0.0078  last_data_time: 0.0070   lr: 0.00025  max_mem: 8050M
# [10/27 22:38:37 d2.utils.events]:  eta: 4:16:19  iter: 1459  total_loss: 0.2006  loss_cls: 0.000143  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.04544  loss_rpn_loc: 0.1457    time: 18.1653  last_time: 11.2375  data_time: 0.0088  last_data_time: 0.0081   lr: 0.00025  max_mem: 8050M
# [10/27 22:44:22 d2.utils.events]:  eta: 4:02:32  iter: 1479  total_loss: 0.1912  loss_cls: 4.467e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.04423  loss_rpn_loc: 0.1476    time: 18.1526  last_time: 10.5291  data_time: 0.0078  last_data_time: 0.0085   lr: 0.00025  max_mem: 8050M
# [10/27 22:50:11 d2.utils.events]:  eta: 4:02:24  iter: 1499  total_loss: 0.1722  loss_cls: 5.738e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03936  loss_rpn_loc: 0.1287    time: 18.1436  last_time: 11.2689  data_time: 0.0081  last_data_time: 0.0078   lr: 0.00025  max_mem: 8050M
# Iteration 1500/2650 - Loss: (0.18030522488697898, 1500)
# [10/27 22:57:04 d2.utils.events]:  eta: 3:54:58  iter: 1519  total_loss: 0.1817  loss_cls: 6.045e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03807  loss_rpn_loc: 0.1431    time: 18.1762  last_time: 25.9242  data_time: 0.0086  last_data_time: 0.0077   lr: 0.00025  max_mem: 8050M
# [10/27 23:03:35 d2.utils.events]:  eta: 3:50:49  iter: 1539  total_loss: 0.1814  loss_cls: 3.321e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.04167  loss_rpn_loc: 0.1476    time: 18.1941  last_time: 25.2461  data_time: 0.0086  last_data_time: 0.0067   lr: 0.00025  max_mem: 8050M
# [10/27 23:09:24 d2.utils.events]:  eta: 3:45:57  iter: 1559  total_loss: 0.1683  loss_cls: 2.167e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03721  loss_rpn_loc: 0.1306    time: 18.1845  last_time: 25.7864  data_time: 0.0082  last_data_time: 0.0081   lr: 0.00025  max_mem: 8050M
# [10/27 23:15:22 d2.utils.events]:  eta: 3:41:37  iter: 1579  total_loss: 0.1618  loss_cls: 4.627e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03888  loss_rpn_loc: 0.1218    time: 18.1814  last_time: 26.1565  data_time: 0.0081  last_data_time: 0.0075   lr: 0.00025  max_mem: 8050M
# [10/27 23:21:26 d2.utils.events]:  eta: 3:38:20  iter: 1599  total_loss: 0.1647  loss_cls: 3.138e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03653  loss_rpn_loc: 0.1267    time: 18.1811  last_time: 25.3216  data_time: 0.0086  last_data_time: 0.0100   lr: 0.00025  max_mem: 8050M
# [10/27 23:27:29 d2.utils.events]:  eta: 3:40:33  iter: 1619  total_loss: 0.183  loss_cls: 7.682e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03879  loss_rpn_loc: 0.1402    time: 18.1807  last_time: 11.4491  data_time: 0.0085  last_data_time: 0.0060   lr: 0.00025  max_mem: 8050M
# [10/27 23:33:06 d2.utils.events]:  eta: 3:29:40  iter: 1639  total_loss: 0.1829  loss_cls: 4.302e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.04184  loss_rpn_loc: 0.1337    time: 18.1645  last_time: 10.0434  data_time: 0.0089  last_data_time: 0.0070   lr: 0.00025  max_mem: 8050M
# [10/27 23:39:39 d2.utils.events]:  eta: 3:31:59  iter: 1659  total_loss: 0.1698  loss_cls: 4.455e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03873  loss_rpn_loc: 0.13    time: 18.1827  last_time: 25.3604  data_time: 0.0082  last_data_time: 0.0094   lr: 0.00025  max_mem: 8050M
# [10/27 23:44:39 d2.utils.events]:  eta: 3:20:55  iter: 1679  total_loss: 0.1554  loss_cls: 4.848e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03625  loss_rpn_loc: 0.1219    time: 18.1448  last_time: 25.9535  data_time: 0.0077  last_data_time: 0.0087   lr: 0.00025  max_mem: 8050M
# [10/27 23:50:16 d2.utils.events]:  eta: 3:15:23  iter: 1699  total_loss: 0.1785  loss_cls: 5.851e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03711  loss_rpn_loc: 0.1378    time: 18.1293  last_time: 10.9573  data_time: 0.0086  last_data_time: 0.0094   lr: 0.00025  max_mem: 8050M
# [10/27 23:55:49 d2.utils.events]:  eta: 3:09:40  iter: 1719  total_loss: 0.1862  loss_cls: 4.335e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03826  loss_rpn_loc: 0.1435    time: 18.1123  last_time: 10.7058  data_time: 0.0093  last_data_time: 0.0076   lr: 0.00025  max_mem: 8050M
# [10/28 00:02:08 d2.utils.events]:  eta: 3:05:57  iter: 1739  total_loss: 0.1726  loss_cls: 5.282e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03383  loss_rpn_loc: 0.1345    time: 18.1219  last_time: 25.9291  data_time: 0.0083  last_data_time: 0.0080   lr: 0.00025  max_mem: 8050M
# [10/28 00:08:21 d2.utils.events]:  eta: 3:02:42  iter: 1759  total_loss: 0.1733  loss_cls: 3.131e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03707  loss_rpn_loc: 0.1365    time: 18.1275  last_time: 25.8398  data_time: 0.0091  last_data_time: 0.0081   lr: 0.00025  max_mem: 8050M
# [10/28 00:14:42 d2.utils.events]:  eta: 3:00:20  iter: 1779  total_loss: 0.1785  loss_cls: 4.858e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03132  loss_rpn_loc: 0.1466    time: 18.1382  last_time: 25.2629  data_time: 0.0084  last_data_time: 0.0088   lr: 0.00025  max_mem: 8050M
# [10/28 00:21:01 d2.utils.events]:  eta: 2:54:52  iter: 1799  total_loss: 0.173  loss_cls: 7.628e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03817  loss_rpn_loc: 0.1278    time: 18.1470  last_time: 25.4142  data_time: 0.0089  last_data_time: 0.0103   lr: 0.00025  max_mem: 8050M
# [10/28 00:27:28 d2.utils.events]:  eta: 2:51:55  iter: 1819  total_loss: 0.1665  loss_cls: 3.619e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03758  loss_rpn_loc: 0.1291    time: 18.1601  last_time: 26.2493  data_time: 0.0087  last_data_time: 0.0078   lr: 0.00025  max_mem: 8050M
# [10/28 00:33:20 d2.utils.events]:  eta: 2:47:54  iter: 1839  total_loss: 0.1667  loss_cls: 5.403e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03807  loss_rpn_loc: 0.1313    time: 18.1543  last_time: 10.3677  data_time: 0.0094  last_data_time: 0.0185   lr: 0.00025  max_mem: 8050M
# [10/28 00:38:27 d2.utils.events]:  eta: 2:42:10  iter: 1859  total_loss: 0.1638  loss_cls: 2.162e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03362  loss_rpn_loc: 0.1301    time: 18.1243  last_time: 11.7229  data_time: 0.0092  last_data_time: 0.0082   lr: 0.00025  max_mem: 8050M
# [10/28 00:44:44 d2.utils.events]:  eta: 2:38:24  iter: 1879  total_loss: 0.1854  loss_cls: 2.532e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03528  loss_rpn_loc: 0.1482    time: 18.1319  last_time: 10.6173  data_time: 0.0079  last_data_time: 0.0073   lr: 0.00025  max_mem: 8050M
# [10/28 00:50:15 d2.utils.events]:  eta: 2:34:17  iter: 1899  total_loss: 0.1681  loss_cls: 7.3e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.0326  loss_rpn_loc: 0.1278    time: 18.1151  last_time: 25.5481  data_time: 0.0099  last_data_time: 0.0075   lr: 0.00025  max_mem: 8050M
# [10/28 00:56:02 d2.utils.events]:  eta: 2:29:10  iter: 1919  total_loss: 0.163  loss_cls: 2.364e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03396  loss_rpn_loc: 0.1329    time: 18.1071  last_time: 25.7584  data_time: 0.0083  last_data_time: 0.0098   lr: 0.00025  max_mem: 8050M
# [10/28 01:01:53 d2.utils.events]:  eta: 2:25:23  iter: 1939  total_loss: 0.169  loss_cls: 2.794e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03658  loss_rpn_loc: 0.1265    time: 18.1013  last_time: 14.3966  data_time: 0.0092  last_data_time: 0.0086   lr: 0.00025  max_mem: 8050M
# [10/28 01:07:44 d2.utils.events]:  eta: 2:20:43  iter: 1959  total_loss: 0.1631  loss_cls: 3.079e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03138  loss_rpn_loc: 0.1265    time: 18.0959  last_time: 10.3614  data_time: 0.0081  last_data_time: 0.0090   lr: 0.00025  max_mem: 8050M
# [10/28 01:13:36 d2.utils.events]:  eta: 2:16:38  iter: 1979  total_loss: 0.177  loss_cls: 7.156e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03925  loss_rpn_loc: 0.1344    time: 18.0906  last_time: 11.9772  data_time: 0.0083  last_data_time: 0.0072   lr: 0.00025  max_mem: 8050M
# [10/28 01:19:29 d2.utils.events]:  eta: 2:13:28  iter: 1999  total_loss: 0.1711  loss_cls: 2.189e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03673  loss_rpn_loc: 0.1329    time: 18.0864  last_time: 25.8772  data_time: 0.0089  last_data_time: 0.0063   lr: 0.00025  max_mem: 8050M
# Iteration 2000/2650 - Loss: (0.16362337244208902, 2000)
# [10/28 01:24:46 d2.utils.events]:  eta: 2:08:22  iter: 2019  total_loss: 0.1712  loss_cls: 3.155e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.0353  loss_rpn_loc: 0.1416    time: 18.0640  last_time: 25.6208  data_time: 0.0091  last_data_time: 0.0072   lr: 0.00025  max_mem: 8050M
# [10/28 01:31:19 d2.utils.events]:  eta: 2:04:24  iter: 2039  total_loss: 0.1664  loss_cls: 8.015e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03556  loss_rpn_loc: 0.1329    time: 18.0798  last_time: 11.1310  data_time: 0.0086  last_data_time: 0.0105   lr: 0.00025  max_mem: 8050M
# [10/28 01:38:10 d2.utils.events]:  eta: 2:00:26  iter: 2059  total_loss: 0.1625  loss_cls: 4.278e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03272  loss_rpn_loc: 0.1312    time: 18.1035  last_time: 25.9101  data_time: 0.0081  last_data_time: 0.0065   lr: 0.00025  max_mem: 8050M
# [10/28 01:43:26 d2.utils.events]:  eta: 1:55:35  iter: 2079  total_loss: 0.1588  loss_cls: 1.568e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03489  loss_rpn_loc: 0.1251    time: 18.0813  last_time: 10.3678  data_time: 0.0086  last_data_time: 0.0086   lr: 0.00025  max_mem: 8050M
# [10/28 01:49:43 d2.utils.events]:  eta: 1:51:52  iter: 2099  total_loss: 0.1696  loss_cls: 2.441e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03333  loss_rpn_loc: 0.1318    time: 18.0888  last_time: 10.8054  data_time: 0.0089  last_data_time: 0.0067   lr: 0.00025  max_mem: 8050M
# [10/28 01:55:47 d2.utils.events]:  eta: 1:47:41  iter: 2119  total_loss: 0.1626  loss_cls: 1.628e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.0369  loss_rpn_loc: 0.1304    time: 18.0910  last_time: 26.0551  data_time: 0.0080  last_data_time: 0.0076   lr: 0.00025  max_mem: 8050M
# [10/28 02:01:42 d2.utils.events]:  eta: 1:43:20  iter: 2139  total_loss: 0.1613  loss_cls: 0.0001354  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.0329  loss_rpn_loc: 0.1259    time: 18.0875  last_time: 11.6286  data_time: 0.0085  last_data_time: 0.0063   lr: 0.00025  max_mem: 8050M
# [10/28 02:07:06 d2.utils.events]:  eta: 1:38:52  iter: 2159  total_loss: 0.1714  loss_cls: 2.305e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03757  loss_rpn_loc: 0.1334    time: 18.0704  last_time: 11.2065  data_time: 0.0078  last_data_time: 0.0084   lr: 0.00025  max_mem: 8050M
# [10/28 02:13:13 d2.utils.events]:  eta: 1:35:14  iter: 2179  total_loss: 0.1674  loss_cls: 3.389e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03341  loss_rpn_loc: 0.1334    time: 18.0727  last_time: 25.0153  data_time: 0.0081  last_data_time: 0.0084   lr: 0.00025  max_mem: 8050M
# [10/28 02:18:53 d2.utils.events]:  eta: 1:30:51  iter: 2199  total_loss: 0.1672  loss_cls: 5.65e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03139  loss_rpn_loc: 0.1336    time: 18.0629  last_time: 11.6709  data_time: 0.0092  last_data_time: 0.0066   lr: 0.00025  max_mem: 8050M
# [10/28 02:25:12 d2.utils.events]:  eta: 1:26:32  iter: 2219  total_loss: 0.1667  loss_cls: 3.143e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03815  loss_rpn_loc: 0.1277    time: 18.0710  last_time: 27.5241  data_time: 0.0088  last_data_time: 0.0087   lr: 0.00025  max_mem: 8050M
# [10/28 02:30:47 d2.utils.events]:  eta: 1:22:26  iter: 2239  total_loss: 0.1773  loss_cls: 2.769e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03928  loss_rpn_loc: 0.14    time: 18.0593  last_time: 10.8456  data_time: 0.0085  last_data_time: 0.0072   lr: 0.00025  max_mem: 8050M
# [10/28 02:36:24 d2.utils.events]:  eta: 1:18:18  iter: 2259  total_loss: 0.1713  loss_cls: 2.879e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.0336  loss_rpn_loc: 0.1327    time: 18.0483  last_time: 10.5751  data_time: 0.0087  last_data_time: 0.0080   lr: 0.00025  max_mem: 8050M
# [10/28 02:41:59 d2.utils.events]:  eta: 1:14:07  iter: 2279  total_loss: 0.1771  loss_cls: 1.727e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03533  loss_rpn_loc: 0.1339    time: 18.0371  last_time: 10.5996  data_time: 0.0077  last_data_time: 0.0076   lr: 0.00025  max_mem: 8050M
# [10/28 02:47:55 d2.utils.events]:  eta: 1:10:26  iter: 2299  total_loss: 0.1507  loss_cls: 4.727e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03095  loss_rpn_loc: 0.1198    time: 18.0350  last_time: 11.0185  data_time: 0.0093  last_data_time: 0.0097   lr: 0.00025  max_mem: 8050M
# [10/28 02:54:49 d2.utils.events]:  eta: 1:07:15  iter: 2319  total_loss: 0.163  loss_cls: 2.387e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03092  loss_rpn_loc: 0.1244    time: 18.0579  last_time: 11.3111  data_time: 0.0105  last_data_time: 0.0116   lr: 0.00025  max_mem: 8050M
# [10/28 03:00:53 d2.utils.events]:  eta: 1:03:17  iter: 2339  total_loss: 0.1584  loss_cls: 2.239e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03243  loss_rpn_loc: 0.1286    time: 18.0591  last_time: 26.4445  data_time: 0.0094  last_data_time: 0.0167   lr: 0.00025  max_mem: 8050M
# [10/28 03:07:32 d2.utils.events]:  eta: 0:59:12  iter: 2359  total_loss: 0.1528  loss_cls: 1.724e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03426  loss_rpn_loc: 0.1218    time: 18.0754  last_time: 26.7582  data_time: 0.0076  last_data_time: 0.0064   lr: 0.00025  max_mem: 8050M
# [10/28 03:13:43 d2.utils.events]:  eta: 0:55:01  iter: 2379  total_loss: 0.1682  loss_cls: 3.03e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03316  loss_rpn_loc: 0.13    time: 18.0791  last_time: 11.3344  data_time: 0.0072  last_data_time: 0.0070   lr: 0.00025  max_mem: 8050M
# [10/28 03:20:28 d2.utils.events]:  eta: 0:50:57  iter: 2399  total_loss: 0.1632  loss_cls: 2.043e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03371  loss_rpn_loc: 0.1327    time: 18.0972  last_time: 26.9871  data_time: 0.0082  last_data_time: 0.0059   lr: 0.00025  max_mem: 8050M
# [10/28 03:26:53 d2.utils.events]:  eta: 0:46:55  iter: 2419  total_loss: 0.1721  loss_cls: 3.014e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03407  loss_rpn_loc: 0.1312    time: 18.1069  last_time: 26.9824  data_time: 0.0079  last_data_time: 0.0066   lr: 0.00025  max_mem: 8050M
# [10/28 03:32:48 d2.utils.events]:  eta: 0:42:55  iter: 2439  total_loss: 0.1576  loss_cls: 1.629e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03163  loss_rpn_loc: 0.1221    time: 18.1040  last_time: 10.3234  data_time: 0.0081  last_data_time: 0.0067   lr: 0.00025  max_mem: 8050M
# [10/28 03:38:47 d2.utils.events]:  eta: 0:38:56  iter: 2459  total_loss: 0.1651  loss_cls: 1.372e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03303  loss_rpn_loc: 0.1269    time: 18.1026  last_time: 26.1563  data_time: 0.0082  last_data_time: 0.0081   lr: 0.00025  max_mem: 8050M
# [10/28 03:44:49 d2.utils.events]:  eta: 0:34:50  iter: 2479  total_loss: 0.1559  loss_cls: 1.207e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03304  loss_rpn_loc: 0.1231    time: 18.1027  last_time: 11.2577  data_time: 0.0088  last_data_time: 0.0160   lr: 0.00025  max_mem: 8050M
# [10/28 03:51:36 d2.utils.events]:  eta: 0:30:54  iter: 2499  total_loss: 0.1549  loss_cls: 2.369e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.02952  loss_rpn_loc: 0.1251    time: 18.1205  last_time: 25.0586  data_time: 0.0095  last_data_time: 0.0099   lr: 0.00025  max_mem: 8050M
# Iteration 2500/2650 - Loss: (0.16811709842022537, 2500)
# [10/28 03:58:29 d2.utils.events]:  eta: 0:26:50  iter: 2519  total_loss: 0.1601  loss_cls: 2.917e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03252  loss_rpn_loc: 0.1249    time: 18.1407  last_time: 25.7541  data_time: 0.0081  last_data_time: 0.0066   lr: 0.00025  max_mem: 8050M
# [10/28 04:04:03 d2.utils.events]:  eta: 0:22:34  iter: 2539  total_loss: 0.1536  loss_cls: 2.41e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.0307  loss_rpn_loc: 0.1239    time: 18.1295  last_time: 11.5274  data_time: 0.0089  last_data_time: 0.0114   lr: 0.00025  max_mem: 8050M
# [10/28 04:10:08 d2.utils.events]:  eta: 0:18:29  iter: 2559  total_loss: 0.1617  loss_cls: 1.859e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03075  loss_rpn_loc: 0.1283    time: 18.1301  last_time: 25.3252  data_time: 0.0085  last_data_time: 0.0061   lr: 0.00025  max_mem: 8050M
# [10/28 04:16:12 d2.utils.events]:  eta: 0:14:22  iter: 2579  total_loss: 0.1741  loss_cls: 2.163e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03377  loss_rpn_loc: 0.1394    time: 18.1309  last_time: 10.2050  data_time: 0.0082  last_data_time: 0.0067   lr: 0.00025  max_mem: 8050M
# [10/28 04:22:30 d2.utils.events]:  eta: 0:10:17  iter: 2599  total_loss: 0.1591  loss_cls: 1.957e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.0334  loss_rpn_loc: 0.1306    time: 18.1368  last_time: 12.1264  data_time: 0.0083  last_data_time: 0.0089   lr: 0.00025  max_mem: 8050M
# [10/28 04:28:05 d2.utils.events]:  eta: 0:06:09  iter: 2619  total_loss: 0.1596  loss_cls: 1.63e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03066  loss_rpn_loc: 0.1246    time: 18.1263  last_time: 24.9135  data_time: 0.0081  last_data_time: 0.0069   lr: 0.00025  max_mem: 8050M
# [10/28 04:33:10 d2.utils.events]:  eta: 0:02:02  iter: 2639  total_loss: 0.1583  loss_cls: 3.271e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03389  loss_rpn_loc: 0.1231    time: 18.1044  last_time: 10.3023  data_time: 0.0085  last_data_time: 0.0092   lr: 0.00025  max_mem: 8050M
# [10/28 04:36:14 d2.utils.events]:  eta: 0:00:00  iter: 2649  total_loss: 0.1629  loss_cls: 5.658e-05  loss_box_reg: 0  loss_mask: 0  loss_rpn_cls: 0.03254  loss_rpn_loc: 0.1268    time: 18.1052  last_time: 25.9621  data_time: 0.0086  last_data_time: 0.0083   lr: 0.00025  max_mem: 8050M
# [10/28 04:36:14 d2.engine.hooks]: Overall training speed: 2648 iterations in 13:19:02 (18.1053 s / it)
# [10/28 04:36:14 d2.engine.hooks]: Total training time: 13:19:06 (0:00:03 on hooks)
# [10/28 04:36:14 d2.data.datasets.coco]: Loaded 200 images in COCO format from C:/Users/kurt_/car-parts-and-damage-detection-v3/car-part-detection/working/data/val\annotations.json
# [10/28 04:36:14 d2.data.build]: Distribution of instances among all 21 categories:
# |   category    | #instances   |   category    | #instances   |   category   | #instances   |
# |:-------------:|:-------------|:-------------:|:-------------|:------------:|:-------------|
# | Quarter-panel | 173          |  Front-wheel  | 184          | Back-window  | 255          |
# |     Trunk     | 84           |  Front-door   | 186          | Rocker-panel | 173          |
# |    Grille     | 127          |  Windshield   | 131          | Front-window | 188          |
# |   Back-door   | 148          |   Headlight   | 184          |  Back-wheel  | 174          |
# | Back-windsh.. | 50           |     Hood      | 147          |    Fender    | 187          |
# |  Tail-light   | 135          | License-plate | 71           | Front-bumper | 143          |
# |  Back-bumper  | 81           |    Mirror     | 201          |     Roof     | 159          |
# |               |              |               |              |              |              |
# |     total     | 3181         |               |              |              |              |
# [10/28 04:36:14 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [10/28 04:36:14 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [10/28 04:36:14 d2.data.common]: Serializing 200 elements to byte tensors and concatenating them all ...
# [10/28 04:36:14 d2.data.common]: Serialized dataset takes 1.50 MiB
# WARNING [10/28 04:36:14 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# [10/28 04:36:14 d2.evaluation.evaluator]: Start inference on 200 batches
# [10/28 04:36:21 d2.evaluation.evaluator]: Inference done 11/200. Dataloading: 0.0006 s/iter. Inference: 0.0731 s/iter. Eval: 0.0001 s/iter. Total: 0.0737 s/iter. ETA=0:00:13
# [10/28 04:36:26 d2.evaluation.evaluator]: Inference done 83/200. Dataloading: 0.0007 s/iter. Inference: 0.0693 s/iter. Eval: 0.0001 s/iter. Total: 0.0701 s/iter. ETA=0:00:08
# [10/28 04:36:31 d2.evaluation.evaluator]: Inference done 154/200. Dataloading: 0.0007 s/iter. Inference: 0.0697 s/iter. Eval: 0.0001 s/iter. Total: 0.0704 s/iter. ETA=0:00:03
# [10/28 04:36:35 d2.evaluation.evaluator]: Total inference time: 0:00:14.234558 (0.072998 s / iter per device, on 1 devices)
# [10/28 04:36:35 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:13 (0.069497 s / iter per device, on 1 devices)
# [10/28 04:36:35 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [10/28 04:36:35 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# WARNING [10/28 04:36:35 d2.evaluation.coco_evaluation]: No predictions from the model!
# [10/28 04:36:35 d2.engine.defaults]: Evaluation results for car_val in csv format:
# [10/28 04:36:35 d2.evaluation.testing]: copypaste: Task: bbox
# [10/28 04:36:35 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [10/28 04:36:35 d2.evaluation.testing]: copypaste: nan,nan,nan,nan,nan,nan

# %%
import os
import torch
from detectron2.engine import DefaultPredictor  # Import DefaultPredictor

# Set the path to the trained model
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")  # path to the model we just trained
# Set a custom testing threshold
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5

# Create a predictor
predictor = DefaultPredictor(cfg)
# Out:
# [10/28 04:38:39 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from ./output_20241027_151627\model_final.pth ...
# C:\Users\kurt_\anaconda3\envs\my-env-detectron2\lib\site-packages\fvcore\common\checkpoint.py:252: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(f, map_location=torch.device("cpu"))

# %%
import json
import pandas as pd

metrics_path = r"C:\Users\kurt_\car-parts-and-damage-detection-v3\car-part-detection\output_20241027_151627\metrics.json"
metrics_columns = [
    "data_time",
    "eta_seconds",
    "fast_rcnn/cls_accuracy",
    "fast_rcnn/false_negative",
    "fast_rcnn/fg_cls_accuracy",
    "iteration",
    "loss_box_reg",
    "loss_cls",
    "loss_mask",
    "loss_rpn_cls",
    "loss_rpn_loc",
    "lr",
    "mask_rcnn/accuracy",
    "mask_rcnn/false_negative",
    "mask_rcnn/false_positive",
    "rank_data_time",
    "roi_head/num_bg_samples",
    "roi_head/num_fg_samples",
    "rpn/num_neg_anchors",
    "rpn/num_pos_anchors",
    "time",
    "total_loss"
]


data = []
with open(metrics_path, 'r') as f:
    for line in f:
        json_data = json.loads(line)
        filtered_data = {metric: json_data.get(metric, None) for metric in metrics_columns}
        data.append(filtered_data)

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#      data_time   eta_seconds  fast_rcnn/cls_accuracy fast_rcnn/false_negative  \
# 0     0.011181  28584.808292                 0.06250                     None
# 1     0.008331  31839.542946                 0.34375                     None
# 2     0.008223  63063.039242                 0.93750                     None
# 3     0.009559  30795.747170                 1.00000                     None
# 4     0.007779  29406.866985                 1.00000                     None
# ..         ...           ...                     ...                      ...
# 129   0.008266    617.475185                 1.00000                     None
# 130   0.007903    369.468906                 1.00000                     None
# 131   0.008144    122.496867                 1.00000                     None
# 132   0.008272      0.000000                 1.00000                     None
# 133        NaN           NaN                     NaN                     None
#
#     fast_rcnn/fg_cls_accuracy  iteration  loss_box_reg  loss_cls  loss_mask  \
# 0                        None         19           0.0  3.057812        0.0
# 1                        None         39           0.0  2.874933        0.0
# 2                        None         59           0.0  2.479050        0.0
# 3                        None         79           0.0  1.862760        0.0
# 4                        None         99           0.0  1.087532        0.0
# ..                        ...        ...           ...       ...        ...
# 129                      None       2599           0.0  0.000020        0.0
# 130                      None       2619           0.0  0.000016        0.0
# 131                      None       2639           0.0  0.000033        0.0
# 132                      None       2649           0.0  0.000057        0.0
# 133                      None       2650           NaN       NaN        NaN
#
#      loss_rpn_cls  ...  mask_rcnn/accuracy  mask_rcnn/false_negative  \
# 0        1.671841  ...                None                      None
# 1        1.258690  ...                None                      None
# 2        0.749214  ...                None                      None
# 3        0.541370  ...                None                      None
# 4        0.335824  ...                None                      None
# ..            ...  ...                 ...                       ...
# 129      0.033403  ...                None                      None
# 130      0.030665  ...                None                      None
# 131      0.033894  ...                None                      None
# 132      0.032542  ...                None                      None
# 133           NaN  ...                None                      None
#
#     mask_rcnn/false_positive rank_data_time roi_head/num_bg_samples  \
# 0                       None       0.011181                     2.0
# 1                       None       0.008331                     2.0
# 2                       None       0.008223                     2.0
# 3                       None       0.009559                     2.0
# 4                       None       0.007779                     2.0
# ..                       ...            ...                     ...
# 129                     None       0.008266                     2.0
# 130                     None       0.007903                     2.0
# 131                     None       0.008144                     2.0
# 132                     None       0.008272                     2.0
# 133                     None            NaN                     NaN
#
#      roi_head/num_fg_samples  rpn/num_neg_anchors  rpn/num_pos_anchors  \
# 0                        0.0             169.3750              86.6250
# 1                        0.0             167.7500              88.2500
# 2                        0.0             177.0000              79.0000
# 3                        0.0             170.1875              85.8125
# 4                        0.0             166.4375              89.5625
# ..                       ...                  ...                  ...
# 129                      0.0             171.0000              85.0000
# 130                      0.0             170.3125              85.6875
# 131                      0.0             169.5000              86.5000
# 132                      0.0             174.3750              81.6250
# 133                      NaN                  NaN                  NaN
#
#           time  total_loss
# 0    10.868748    4.984396
# 1    25.515139    4.366842
# 2    25.313738    3.433519
# 3    10.648627    2.698918
# 4    10.861023    1.698705
# ..         ...         ...
# 129  25.051629    0.159140
# 130  11.418548    0.159593
# 131  11.098252    0.158307
# 132  11.138601    0.162924
# 133        NaN         NaN
#
# [134 rows x 22 columns]

# %%
# F1 Skoru Hesaplama
# F1 Skoru = 2 * (Precision * Recall) / (Precision + Recall)
# Precision = TP / (TP + FP)
# Recall = TP / (TP + FN)

# Varsayımsal olarak mask_rcnn accuracy ve false negative / positive kullanılarak hesaplama
precision = 1 - df['mask_rcnn/false_positive']
recall = 1 - df['mask_rcnn/false_negative']
f1_score = 2 * (precision * recall) / (precision + recall)
accuracy = df['mask_rcnn/accuracy']

# %%
#(Loss) 
plt.figure(figsize=(10, 6))
plt.plot(df['iteration'], df['total_loss'], label='Total Loss')
plt.plot(df['iteration'], df['loss_cls'], label='Classification Loss')
plt.plot(df['iteration'], df['loss_box_reg'], label='Box Regression Loss')
plt.plot(df['iteration'], df['loss_mask'], label='Mask Loss')
plt.plot(df['iteration'], df['loss_rpn_cls'], label='RPN Classification Loss')
plt.plot(df['iteration'], df['loss_rpn_loc'], label='RPN Location Loss')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.title('Loss During Training')
plt.legend()
plt.grid(True)
plt.show()

#  Mask R-CNN Accuracy, False Positive, False Negative 
plt.figure(figsize=(10, 6))
plt.plot(df['iteration'], df['mask_rcnn/accuracy'], label='Mask R-CNN Accuracy')
plt.plot(df['iteration'], df['mask_rcnn/false_positive'], label='Mask R-CNN False Positive')
plt.plot(df['iteration'], df['mask_rcnn/false_negative'], label='Mask R-CNN False Negative')
plt.xlabel('Iteration')
plt.ylabel('Accuracy / Error Rate')
plt.title('Mask R-CNN Accuracy and Error Rates')
plt.legend()
plt.grid(True)
plt.show()
