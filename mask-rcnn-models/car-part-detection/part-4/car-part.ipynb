# %%
import sys, os, json, random
import torch
import sys
import datetime

import cv2

import numpy as np
import pandas as pd

import skimage.io as io

import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = [16,9]
# %matplotlib inline

from shapely.geometry import Polygon

# path to the images
data_dir = "C:/Users/kurt_/car-parts-and-damage-detection-v4/car-part-detection/car-part/File1"

# create paths for traininig and validaiton data
os.makedirs("C:/Users/kurt_/car-parts-and-damage-detection-v4/car-part-detection/working/data/", exist_ok=True)
os.makedirs("C:/Users/kurt_/car-parts-and-damage-detection-v4/car-part-detection/working/data/train/", exist_ok=True)
os.makedirs("C:/Users/kurt_/car-parts-and-damage-detection-v4/car-part-detection/working/data/val/", exist_ok=True)


# create path to store the model config
os.makedirs("C:/Users/kurt_/car-parts-and-damage-detection-v4/car-part-detection/working/model/", exist_ok=True)

data_working_dir = "C:/Users/kurt_/car-parts-and-damage-detection-v4/car-part-detection/working/data/"
model_dir = "C:/Users/kurt_/car-parts-and-damage-detection-v4/car-part-detection/working/model/"

# %%
import json
import os
import shutil
import random
from PIL import Image

# Paths to your dataset
images_dir = os.path.join(data_dir, "img")
annotations_dir = os.path.join(data_dir, "ann")

# Get list of images
images = [f for f in os.listdir(images_dir) if os.path.isfile(os.path.join(images_dir, f))]

# Shuffle the images
random.shuffle(images)

# Split the dataset (e.g., 80% train, 20% val)
split_index = int(0.8 * len(images))
train_images = images[:split_index]
val_images = images[split_index:]

def convert_to_coco(images, images_dir, annotations_dir, output_dir):
    coco_output = {
        "images": [],
        "annotations": [],
        "categories": []
    }

    category_mapping = {
        "Quarter-panel": 1,
        "Front-wheel": 2,
        "Back-window": 3,
        "Trunk": 4,
        "Front-door": 5,
        "Rocker-panel": 6,
        "Grille": 7,
        "Windshield": 8,
        "Front-window": 9,
        "Back-door": 10,
        "Headlight": 11,
        "Back-wheel": 12,
        "Back-windshield": 13,
        "Hood": 14,
        "Fender": 15,
        "Tail-light": 16,
        "License-plate": 17,
        "Front-bumper": 18,
        "Back-bumper": 19,
        "Mirror": 20,
        "Roof": 21
    }

    for category, id in category_mapping.items():
        coco_output["categories"].append({
            "id": id,
            "name": category
        })

    annotation_id = 1
    for idx, image_filename in enumerate(images):
        image_path = os.path.join(images_dir, image_filename)
        annotation_path = os.path.join(annotations_dir, image_filename + ".json")
        
        # Copy the image to the output directory
        shutil.copy(image_path, output_dir)
        
        # Open the image to get its dimensions
        with Image.open(image_path) as img:
            width, height = img.size
        
        coco_output["images"].append({
            "file_name": image_filename,
            "height": height,
            "width": width,
            "id": idx
        })
        
        with open(annotation_path) as f:
            objs = json.load(f)["objects"]

        for obj in objs:
            px = [point[0] for point in obj["points"]["exterior"]]
            py = [point[1] for point in obj["points"]["exterior"]]
            poly = [(x, y) for x, y in zip(px, py)]
            poly = [p for x in poly for p in x]

            category_id = category_mapping.get(obj["classTitle"], -1)
            if category_id == -1:
                continue  # Skip unknown categories
            
            bbox = [min(px), min(py), max(px) - min(px), max(py) - min(py)]
            
            coco_output["annotations"].append({
                "bbox": bbox,
                "category_id": category_id,
                "image_id": idx,
                "segmentation": [poly],
                "area": bbox[2] * bbox[3],
                "iscrowd": 0,
                "id": annotation_id
            })
            annotation_id += 1

    return coco_output

train_output = convert_to_coco(train_images, images_dir, annotations_dir, os.path.join(data_working_dir, "train"))
val_output = convert_to_coco(val_images, images_dir, annotations_dir, os.path.join(data_working_dir, "val"))

with open(os.path.join(data_working_dir, "train", "annotations.json"), "w") as f:
    json.dump(train_output, f, indent=4)

with open(os.path.join(data_working_dir, "val", "annotations.json"), "w") as f:
    json.dump(val_output, f, indent=4)

print("COCO annotations for train and val sets have been created.")
# Out:
# COCO annotations for train and val sets have been created.

# %%
from detectron2.data.datasets import register_coco_instances

# Register train and val datasets
register_coco_instances("car_train", {}, os.path.join(data_working_dir, "train", "annotations.json"), os.path.join(data_working_dir, "train"))
register_coco_instances("car_val", {}, os.path.join(data_working_dir, "val", "annotations.json"), os.path.join(data_working_dir, "val"))

# Load metadata
from detectron2.data import MetadataCatalog
car_metadata = MetadataCatalog.get("car_train")

# %%
import random
from detectron2.utils.visualizer import Visualizer
from detectron2.data import DatasetCatalog

dataset_dicts = DatasetCatalog.get("car_train")
for d in random.sample(dataset_dicts, 3):
    img = cv2.imread(d["file_name"])
    visualizer = Visualizer(img[:, :, ::-1], metadata=car_metadata, scale=0.5)
    vis = visualizer.draw_dataset_dict(d)
    plt.imshow(vis.get_image()[:, :, ::-1])
    plt.show()

# %%
import os
import torch
import detectron2
import datetime
from detectron2.engine import DefaultTrainer, hooks, HookBase
from detectron2.config import get_cfg
from detectron2 import model_zoo

# Define output directory
output_dir = "./output_" + datetime.datetime.now().strftime('%Y%m%d_%H%M%S')

# Create configuration
cfg = get_cfg()

# Set output directory
cfg.OUTPUT_DIR = output_dir

# Merge configuration from the model zoo
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_C4_1x.yaml"))

# Set training and testing datasets
cfg.DATASETS.TRAIN = ("car_train",)
cfg.DATASETS.TEST = ("car_val",)  # for evaluation during training
cfg.DATALOADER.NUM_WORKERS = 4

# Set device to cuda if available
cfg.MODEL.DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'

# Set weights from the model zoo
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-InstanceSegmentation/mask_rcnn_R_50_C4_1x.yaml")  # Let training initialize from model zoo

# Set batch size, learning rate, and maximum iterations
cfg.SOLVER.IMS_PER_BATCH = 6
cfg.SOLVER.BASE_LR = 0.00025
cfg.SOLVER.MAX_ITER = 2500
cfg.SOLVER.STEPS = []
# Set batch size per image and number of classes
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 16
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 21  # total number of classes

cfg.TEST.EVAL_PERIOD = 600

# Create output directory if it does not exist
os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)

# Custom Trainer to add hooks for status updates
class MyTrainer(DefaultTrainer):
    @classmethod
    def build_evaluator(cls, cfg, dataset_name, output_folder=None):
        from detectron2.evaluation import COCOEvaluator, inference_on_dataset, print_csv_format
        return COCOEvaluator(dataset_name, cfg, False, output_folder)

    def build_hooks(self):
        hooks = super().build_hooks()
        hooks.insert(0, PrintTrainingStatus())
        return hooks

# Custom hook to print training status
class PrintTrainingStatus(HookBase):
    def after_step(self):
        # Print training status every 100 iterations
        if self.trainer.iter % 500 == 0 or self.trainer.iter == self.trainer.max_iter:
            print(f"Iteration {self.trainer.iter}/{self.trainer.max_iter} - Loss: {self.trainer.storage.latest()['total_loss']}")

# Create a trainer
trainer = MyTrainer(cfg)

# Load the model or resume training
trainer.resume_or_load(resume=False)

# Train the model
trainer.train()
# Out:
# [10/29 03:04:03 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): ResNet(
#     (stem): BasicStem(
#       (conv1): Conv2d(
#         3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#         (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#       )
#     )
#     (res2): Sequential(
#       (0): BottleneckBlock(
#         (shortcut): Conv2d(
#           64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv1): Conv2d(
#           64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#       )
#       (1): BottleneckBlock(
#         (conv1): Conv2d(
#           256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#       )
#       (2): BottleneckBlock(
#         (conv1): Conv2d(
#           256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#       )
#     )
#     (res3): Sequential(
#       (0): BottleneckBlock(
#         (shortcut): Conv2d(
#           256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#         (conv1): Conv2d(
#           256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#       )
#       (1): BottleneckBlock(
#         (conv1): Conv2d(
#           512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#       )
#       (2): BottleneckBlock(
#         (conv1): Conv2d(
#           512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#       )
#       (3): BottleneckBlock(
#         (conv1): Conv2d(
#           512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#       )
#     )
#     (res4): Sequential(
#       (0): BottleneckBlock(
#         (shortcut): Conv2d(
#           512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#         (conv1): Conv2d(
#           512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (1): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (2): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (3): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (4): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (5): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(1024, 15, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(1024, 60, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): Res5ROIHeads(
#     (pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(14, 14), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#       )
#     )
#     (res5): Sequential(
#       (0): BottleneckBlock(
#         (shortcut): Conv2d(
#           1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#           (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#         )
#         (conv1): Conv2d(
#           1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#         )
#       )
#       (1): BottleneckBlock(
#         (conv1): Conv2d(
#           2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#         )
#       )
#       (2): BottleneckBlock(
#         (conv1): Conv2d(
#           2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#         )
#       )
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=2048, out_features=22, bias=True)
#       (bbox_pred): Linear(in_features=2048, out_features=84, bias=True)
#     )
#     (mask_head): MaskRCNNConvUpsampleHead(
#       (deconv): ConvTranspose2d(2048, 256, kernel_size=(2, 2), stride=(2, 2))
#       (deconv_relu): ReLU()
#       (predictor): Conv2d(256, 21, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )
# [10/29 03:04:03 d2.data.datasets.coco]: Loaded 798 images in COCO format from C:/Users/kurt_/car-parts-and-damage-detection-v4/car-part-detection/working/data/train\annotations.json
# [10/29 03:04:03 d2.data.build]: Removed 0 images with no usable annotations. 798 images left.
# [10/29 03:04:03 d2.data.build]: Distribution of instances among all 21 categories:
# |   category    | #instances   |   category    | #instances   |   category   | #instances   |
# |:-------------:|:-------------|:-------------:|:-------------|:------------:|:-------------|
# | Quarter-panel | 688          |  Front-wheel  | 710          | Back-window  | 1005         |
# |     Trunk     | 338          |  Front-door   | 736          | Rocker-panel | 692          |
# |    Grille     | 461          |  Windshield   | 509          | Front-window | 771          |
# |   Back-door   | 575          |   Headlight   | 729          |  Back-wheel  | 695          |
# | Back-windsh.. | 217          |     Hood      | 570          |    Fender    | 752          |
# |  Tail-light   | 576          | License-plate | 303          | Front-bumper | 569          |
# |  Back-bumper  | 361          |    Mirror     | 797          |     Roof     | 635          |
# |               |              |               |              |              |              |
# |     total     | 12689        |               |              |              |              |
# [10/29 03:04:03 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [10/29 03:04:03 d2.data.build]: Using training sampler TrainingSampler
# [10/29 03:04:03 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [10/29 03:04:03 d2.data.common]: Serializing 798 elements to byte tensors and concatenating them all ...
# [10/29 03:04:03 d2.data.common]: Serialized dataset takes 6.10 MiB
# [10/29 03:04:03 d2.data.build]: Making batched data loader with batch_size=6
# [10/29 03:04:03 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-InstanceSegmentation/mask_rcnn_R_50_C4_1x/137259246/model_final_9243eb.pkl ...
# Skip loading parameter 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (81, 2048) in the checkpoint but (22, 2048) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (22,) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 2048) in the checkpoint but (84, 2048) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (84,) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.mask_head.predictor.weight' to the model due to incompatible shapes: (80, 256, 1, 1) in the checkpoint but (21, 256, 1, 1) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.mask_head.predictor.bias' to the model due to incompatible shapes: (80,) in the checkpoint but (21,) in the model! You might want to double check if this is expected.
# Some model parameters or buffers are not found in the checkpoint:
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# roi_heads.mask_head.predictor.{bias, weight}
# [10/29 03:04:03 d2.engine.train_loop]: Starting training from iteration 0
# C:\Users\kurt_\anaconda3\envs\my-env-detectron2\lib\site-packages\torch\functional.py:513: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\TensorShape.cpp:3610.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Iteration 0/2500 - Loss: (5.899731129407883, 0)
# [10/29 03:04:19 d2.utils.events]:  eta: 0:24:53  iter: 19  total_loss: 5.769  loss_cls: 2.899  loss_box_reg: 0.8891  loss_mask: 0.6945  loss_rpn_cls: 0.9502  loss_rpn_loc: 0.3247    time: 0.6066  last_time: 0.6022  data_time: 0.1876  last_data_time: 0.0072   lr: 4.9953e-06  max_mem: 3372M
# [10/29 03:04:32 d2.utils.events]:  eta: 0:24:43  iter: 39  total_loss: 5.602  loss_cls: 2.771  loss_box_reg: 0.934  loss_mask: 0.694  loss_rpn_cls: 0.8361  loss_rpn_loc: 0.3371    time: 0.6107  last_time: 0.6479  data_time: 0.0060  last_data_time: 0.0057   lr: 9.9902e-06  max_mem: 3372M
# [10/29 03:04:45 d2.utils.events]:  eta: 0:24:52  iter: 59  total_loss: 5.154  loss_cls: 2.502  loss_box_reg: 0.9202  loss_mask: 0.6934  loss_rpn_cls: 0.718  loss_rpn_loc: 0.3085    time: 0.6193  last_time: 0.6335  data_time: 0.0066  last_data_time: 0.0067   lr: 1.4985e-05  max_mem: 3372M
# [10/29 03:04:57 d2.utils.events]:  eta: 0:24:52  iter: 79  total_loss: 4.67  loss_cls: 2.122  loss_box_reg: 0.9224  loss_mask: 0.6927  loss_rpn_cls: 0.6242  loss_rpn_loc: 0.3104    time: 0.6221  last_time: 0.6369  data_time: 0.0065  last_data_time: 0.0063   lr: 1.998e-05  max_mem: 3372M
#instances   |
# |:-------------:|:-------------|:-------------:|:-------------|:------------:|:-------------|
# | Quarter-panel | 167          |  Front-wheel  | 175          | Back-window  | 232          |
# |     Trunk     | 78           |  Front-door   | 181          | Rocker-panel | 168          |
# |    Grille     | 116          |  Windshield   | 123          | Front-window | 180          |
# |   Back-door   | 146          |   Headlight   | 185          |  Back-wheel  | 170          |
# | Back-windsh.. | 54           |     Hood      | 142          |    Fender    | 183          |
# |  Tail-light   | 145          | License-plate | 67           | Front-bumper | 136          |
# |  Back-bumper  | 82           |    Mirror     | 190          |     Roof     | 158          |
# |               |              |               |              |              |              |
# |     total     | 3078         |               |              |              |              |
# [10/29 03:10:22 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [10/29 03:10:22 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [10/29 03:10:22 d2.data.common]: Serializing 200 elements to byte tensors and concatenating them all ...
# [10/29 03:10:22 d2.data.common]: Serialized dataset takes 1.50 MiB
# WARNING [10/29 03:10:22 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# [10/29 03:10:22 d2.evaluation.evaluator]: Start inference on 200 batches
# [10/29 03:10:49 d2.evaluation.evaluator]: Inference done 11/200. Dataloading: 0.0006 s/iter. Inference: 1.6518 s/iter. Eval: 0.0630 s/iter. Total: 1.7154 s/iter. ETA=0:05:24
# [10/29 03:10:55 d2.evaluation.evaluator]: Inference done 14/200. Dataloading: 0.0007 s/iter. Inference: 1.6939 s/iter. Eval: 0.0725 s/iter. Total: 1.7672 s/iter. ETA=0:05:28
# [10/29 03:11:01 d2.evaluation.evaluator]: Inference done 17/200. Dataloading: 0.0007 s/iter. Inference: 1.7531 s/iter. Eval: 0.0766 s/iter. Total: 1.8306 s/iter. ETA=0:05:34
# [10/29 03:11:07 d2.evaluation.evaluator]: Inference done 21/200. Dataloading: 0.0008 s/iter. Inference: 1.6900 s/iter. Eval: 0.0747 s/iter. Total: 1.7657 s/iter. ETA=0:05:16
# [10/29 03:11:15 d2.evaluation.evaluator]: Inference done 25/200. Dataloading: 0.0008 s/iter. Inference: 1.7296 s/iter. Eval: 0.0718 s/iter. Total: 1.8025 s/iter. ETA=0:05:15
# [10/29 03:11:21 d2.evaluation.evaluator]: Inference done 29/200. Dataloading: 0.0008 s/iter. Inference: 1.6694 s/iter. Eval: 0.0706 s/iter. Total: 1.7410 s/iter. ETA=0:04:57
# [10/29 03:11:28 d2.evaluation.evaluator]: Inference done 31/200. Dataloading: 0.0008 s/iter. Inference: 1.8151 s/iter. Eval: 0.0715 s/iter. Total: 1.8876 s/iter. ETA=0:05:19
# [10/29 03:11:34 d2.evaluation.evaluator]: Inference done 34/200. Dataloading: 0.0008 s/iter. Inference: 1.8441 s/iter. Eval: 0.0714 s/iter. Total: 1.9166 s/iter. ETA=0:05:18
# [10/29 03:11:41 d2.evaluation.evaluator]: Inference done 38/200. Dataloading: 0.0008 s/iter. Inference: 1.8152 s/iter. Eval: 0.0716 s/iter. Total: 1.8880 s/iter. ETA=0:05:05
# [10/29 03:11:46 d2.evaluation.evaluator]: Inference done 42/200. Dataloading: 0.0008 s/iter. Inference: 1.7566 s/iter. Eval: 0.0708 s/iter. Total: 1.8285 s/iter. ETA=0:04:48
# [10/29 03:11:52 d2.evaluation.evaluator]: Inference done 45/200. Dataloading: 0.0008 s/iter. Inference: 1.7573 s/iter. Eval: 0.0699 s/iter. Total: 1.8283 s/iter. ETA=0:04:43
# [10/29 03:11:58 d2.evaluation.evaluator]: Inference done 48/200. Dataloading: 0.0008 s/iter. Inference: 1.7661 s/iter. Eval: 0.0687 s/iter. Total: 1.8359 s/iter. ETA=0:04:39
# [10/29 03:12:03 d2.evaluation.evaluator]: Inference done 51/200. Dataloading: 0.0008 s/iter. Inference: 1.7583 s/iter. Eval: 0.0682 s/iter. Total: 1.8276 s/iter. ETA=0:04:32
# [10/29 03:12:09 d2.evaluation.evaluator]: Inference done 54/200. Dataloading: 0.0008 s/iter. Inference: 1.7673 s/iter. Eval: 0.0692 s/iter. Total: 1.8377 s/iter. ETA=0:04:28
# [10/29 03:12:15 d2.evaluation.evaluator]: Inference done 58/200. Dataloading: 0.0008 s/iter. Inference: 1.7530 s/iter. Eval: 0.0689 s/iter. Total: 1.8230 s/iter. ETA=0:04:18
# [10/29 03:12:21 d2.evaluation.evaluator]: Inference done 61/200. Dataloading: 0.0008 s/iter. Inference: 1.7490 s/iter. Eval: 0.0687 s/iter. Total: 1.8189 s/iter. ETA=0:04:12
# [10/29 03:12:28 d2.evaluation.evaluator]: Inference done 64/200. Dataloading: 0.0008 s/iter. Inference: 1.7813 s/iter. Eval: 0.0687 s/iter. Total: 1.8512 s/iter. ETA=0:04:11
# [10/29 03:12:34 d2.evaluation.evaluator]: Inference done 67/200. Dataloading: 0.0008 s/iter. Inference: 1.7833 s/iter. Eval: 0.0678 s/iter. Total: 1.8522 s/iter. ETA=0:04:06
# [10/29 03:12:40 d2.evaluation.evaluator]: Inference done 71/200. Dataloading: 0.0008 s/iter. Inference: 1.7719 s/iter. Eval: 0.0667 s/iter. Total: 1.8397 s/iter. ETA=0:03:57
# [10/29 03:12:47 d2.evaluation.evaluator]: Inference done 75/200. Dataloading: 0.0008 s/iter. Inference: 1.7656 s/iter. Eval: 0.0660 s/iter. Total: 1.8326 s/iter. ETA=0:03:49
# [10/29 03:12:54 d2.evaluation.evaluator]: Inference done 79/200. Dataloading: 0.0008 s/iter. Inference: 1.7534 s/iter. Eval: 0.0655 s/iter. Total: 1.8200 s/iter. ETA=0:03:40
# [10/29 03:13:00 d2.evaluation.evaluator]: Inference done 83/200. Dataloading: 0.0008 s/iter. Inference: 1.7483 s/iter. Eval: 0.0649 s/iter. Total: 1.8143 s/iter. ETA=0:03:32
# [10/29 03:13:06 d2.evaluation.evaluator]: Inference done 87/200. Dataloading: 0.0008 s/iter. Inference: 1.7236 s/iter. Eval: 0.0639 s/iter. Total: 1.7887 s/iter. ETA=0:03:22
# [10/29 03:13:11 d2.evaluation.evaluator]: Inference done 90/200. Dataloading: 0.0008 s/iter. Inference: 1.7200 s/iter. Eval: 0.0633 s/iter. Total: 1.7845 s/iter. ETA=0:03:16
# [10/29 03:13:16 d2.evaluation.evaluator]: Inference done 93/200. Dataloading: 0.0008 s/iter. Inference: 1.7240 s/iter. Eval: 0.0631 s/iter. Total: 1.7883 s/iter. ETA=0:03:11
# [10/29 03:13:23 d2.evaluation.evaluator]: Inference done 96/200. Dataloading: 0.0008 s/iter. Inference: 1.7359 s/iter. Eval: 0.0625 s/iter. Total: 1.7995 s/iter. ETA=0:03:07
# [10/29 03:13:29 d2.evaluation.evaluator]: Inference done 99/200. Dataloading: 0.0008 s/iter. Inference: 1.7481 s/iter. Eval: 0.0622 s/iter. Total: 1.8115 s/iter. ETA=0:03:02
# [10/29 03:13:34 d2.evaluation.evaluator]: Inference done 102/200. Dataloading: 0.0008 s/iter. Inference: 1.7445 s/iter. Eval: 0.0619 s/iter. Total: 1.8076 s/iter. ETA=0:02:57
# [10/29 03:13:40 d2.evaluation.evaluator]: Inference done 105/200. Dataloading: 0.0008 s/iter. Inference: 1.7528 s/iter. Eval: 0.0616 s/iter. Total: 1.8155 s/iter. ETA=0:02:52
# [10/29 03:13:46 d2.evaluation.evaluator]: Inference done 109/200. Dataloading: 0.0008 s/iter. Inference: 1.7328 s/iter. Eval: 0.0613 s/iter. Total: 1.7953 s/iter. ETA=0:02:43
# [10/29 03:13:52 d2.evaluation.evaluator]: Inference done 113/200. Dataloading: 0.0008 s/iter. Inference: 1.7233 s/iter. Eval: 0.0608 s/iter. Total: 1.7852 s/iter. ETA=0:02:35
# [10/29 03:13:58 d2.evaluation.evaluator]: Inference done 117/200. Dataloading: 0.0008 s/iter. Inference: 1.7189 s/iter. Eval: 0.0600 s/iter. Total: 1.7800 s/iter. ETA=0:02:27
# [10/29 03:14:05 d2.evaluation.evaluator]: Inference done 121/200. Dataloading: 0.0008 s/iter. Inference: 1.7133 s/iter. Eval: 0.0601 s/iter. Total: 1.7745 s/iter. ETA=0:02:20
# [10/29 03:14:10 d2.evaluation.evaluator]: Inference done 124/200. Dataloading: 0.0008 s/iter. Inference: 1.7148 s/iter. Eval: 0.0600 s/iter. Total: 1.7759 s/iter. ETA=0:02:14
# [10/29 03:14:17 d2.evaluation.evaluator]: Inference done 128/200. Dataloading: 0.0008 s/iter. Inference: 1.7115 s/iter. Eval: 0.0595 s/iter. Total: 1.7721 s/iter. ETA=0:02:07
# [10/29 03:14:23 d2.evaluation.evaluator]: Inference done 133/200. Dataloading: 0.0008 s/iter. Inference: 1.6925 s/iter. Eval: 0.0596 s/iter. Total: 1.7532 s/iter. ETA=0:01:57
# [10/29 03:14:29 d2.evaluation.evaluator]: Inference done 136/200. Dataloading: 0.0008 s/iter. Inference: 1.6930 s/iter. Eval: 0.0595 s/iter. Total: 1.7537 s/iter. ETA=0:01:52
# [10/29 03:14:34 d2.evaluation.evaluator]: Inference done 139/200. Dataloading: 0.0008 s/iter. Inference: 1.6975 s/iter. Eval: 0.0594 s/iter. Total: 1.7580 s/iter. ETA=0:01:47
# [10/29 03:14:40 d2.evaluation.evaluator]: Inference done 142/200. Dataloading: 0.0008 s/iter. Inference: 1.6971 s/iter. Eval: 0.0591 s/iter. Total: 1.7573 s/iter. ETA=0:01:41
# [10/29 03:14:46 d2.evaluation.evaluator]: Inference done 145/200. Dataloading: 0.0008 s/iter. Inference: 1.7061 s/iter. Eval: 0.0598 s/iter. Total: 1.7671 s/iter. ETA=0:01:37
# [10/29 03:14:53 d2.evaluation.evaluator]: Inference done 148/200. Dataloading: 0.0008 s/iter. Inference: 1.7165 s/iter. Eval: 0.0600 s/iter. Total: 1.7776 s/iter. ETA=0:01:32
# [10/29 03:14:58 d2.evaluation.evaluator]: Inference done 151/200. Dataloading: 0.0008 s/iter. Inference: 1.7158 s/iter. Eval: 0.0599 s/iter. Total: 1.7769 s/iter. ETA=0:01:27
# [10/29 03:15:04 d2.evaluation.evaluator]: Inference done 155/200. Dataloading: 0.0008 s/iter. Inference: 1.7047 s/iter. Eval: 0.0599 s/iter. Total: 1.7658 s/iter. ETA=0:01:19
# [10/29 03:15:10 d2.evaluation.evaluator]: Inference done 159/200. Dataloading: 0.0008 s/iter. Inference: 1.7003 s/iter. Eval: 0.0597 s/iter. Total: 1.7612 s/iter. ETA=0:01:12
# [10/29 03:15:17 d2.evaluation.evaluator]: Inference done 163/200. Dataloading: 0.0008 s/iter. Inference: 1.6966 s/iter. Eval: 0.0598 s/iter. Total: 1.7575 s/iter. ETA=0:01:05
# [10/29 03:15:22 d2.evaluation.evaluator]: Inference done 166/200. Dataloading: 0.0008 s/iter. Inference: 1.6963 s/iter. Eval: 0.0596 s/iter. Total: 1.7570 s/iter. ETA=0:00:59
# [10/29 03:15:27 d2.evaluation.evaluator]: Inference done 169/200. Dataloading: 0.0008 s/iter. Inference: 1.6965 s/iter. Eval: 0.0594 s/iter. Total: 1.7571 s/iter. ETA=0:00:54
# [10/29 03:15:33 d2.evaluation.evaluator]: Inference done 171/200. Dataloading: 0.0008 s/iter. Inference: 1.7142 s/iter. Eval: 0.0594 s/iter. Total: 1.7747 s/iter. ETA=0:00:51
# [10/29 03:15:38 d2.evaluation.evaluator]: Inference done 174/200. Dataloading: 0.0008 s/iter. Inference: 1.7127 s/iter. Eval: 0.0591 s/iter. Total: 1.7729 s/iter. ETA=0:00:46
# [10/29 03:15:44 d2.evaluation.evaluator]: Inference done 177/200. Dataloading: 0.0008 s/iter. Inference: 1.7114 s/iter. Eval: 0.0594 s/iter. Total: 1.7719 s/iter. ETA=0:00:40
# [10/29 03:15:49 d2.evaluation.evaluator]: Inference done 180/200. Dataloading: 0.0008 s/iter. Inference: 1.7100 s/iter. Eval: 0.0598 s/iter. Total: 1.7710 s/iter. ETA=0:00:35
# [10/29 03:15:54 d2.evaluation.evaluator]: Inference done 183/200. Dataloading: 0.0008 s/iter. Inference: 1.7085 s/iter. Eval: 0.0597 s/iter. Total: 1.7694 s/iter. ETA=0:00:30
# [10/29 03:15:59 d2.evaluation.evaluator]: Inference done 185/200. Dataloading: 0.0008 s/iter. Inference: 1.7180 s/iter. Eval: 0.0596 s/iter. Total: 1.7788 s/iter. ETA=0:00:26
# [10/29 03:16:05 d2.evaluation.evaluator]: Inference done 190/200. Dataloading: 0.0008 s/iter. Inference: 1.7042 s/iter. Eval: 0.0592 s/iter. Total: 1.7646 s/iter. ETA=0:00:17
# [10/29 03:16:11 d2.evaluation.evaluator]: Inference done 193/200. Dataloading: 0.0008 s/iter. Inference: 1.7093 s/iter. Eval: 0.0589 s/iter. Total: 1.7693 s/iter. ETA=0:00:12
# [10/29 03:16:17 d2.evaluation.evaluator]: Inference done 196/200. Dataloading: 0.0008 s/iter. Inference: 1.7097 s/iter. Eval: 0.0587 s/iter. Total: 1.7696 s/iter. ETA=0:00:07
# [10/29 03:16:22 d2.evaluation.evaluator]: Inference done 200/200. Dataloading: 0.0008 s/iter. Inference: 1.6996 s/iter. Eval: 0.0586 s/iter. Total: 1.7593 s/iter. ETA=0:00:00
# [10/29 03:16:22 d2.evaluation.evaluator]: Total inference time: 0:05:43.565922 (1.761877 s / iter per device, on 1 devices)
# [10/29 03:16:22 d2.evaluation.evaluator]: Total inference pure compute time: 0:05:31 (1.699594 s / iter per device, on 1 devices)
# [10/29 03:16:22 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [10/29 03:16:22 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.02s)
# creating index...
# index created!
# [10/29 03:16:22 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [10/29 03:16:23 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.53 seconds.
# [10/29 03:16:23 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [10/29 03:16:23 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.06 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.120
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.284
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.066
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.010
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.067
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.135
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.182
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.277
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.281
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.039
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.193
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.303
# [10/29 03:16:23 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm  |  APl   |
# |:------:|:------:|:------:|:-----:|:-----:|:------:|
# | 11.962 | 28.371 | 6.581  | 0.979 | 6.692 | 13.532 |
# [10/29 03:16:23 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category        | AP    | category      | AP     | category     | AP     |
# |:----------------|:------|:--------------|:-------|:-------------|:-------|
# | Quarter-panel   | 1.279 | Front-wheel   | 25.107 | Back-window  | 9.554  |
# | Trunk           | 1.950 | Front-door    | 12.203 | Rocker-panel | 21.182 |
# | Grille          | 4.928 | Windshield    | 33.156 | Front-window | 5.870  |
# | Back-door       | 7.284 | Headlight     | 20.374 | Back-wheel   | 11.160 |
# | Back-windshield | 0.170 | Hood          | 35.099 | Fender       | 7.316  |
# | Tail-light      | 1.329 | License-plate | 0.000  | Front-bumper | 32.224 |
# | Back-bumper     | 1.268 | Mirror        | 9.102  | Roof         | 10.648 |
# Loading and preparing results...
# DONE (t=0.15s)
# creating index...
# index created!
# [10/29 03:16:23 d2.evaluation.fast_eval_api]: Evaluate annotation type *segm*
# [10/29 03:16:24 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.42 seconds.
# [10/29 03:16:24 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [10/29 03:16:24 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.06 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.114
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.232
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.108
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.006
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.050
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.155
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.167
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.251
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.252
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.045
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.161
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.288
# [10/29 03:16:24 d2.evaluation.coco_evaluation]: Evaluation results for segm:
# |   AP   |  AP50  |  AP75  |  APs  |  APm  |  APl   |
# |:------:|:------:|:------:|:-----:|:-----:|:------:|
# | 11.443 | 23.188 | 10.807 | 0.602 | 5.031 | 15.532 |
# [10/29 03:16:24 d2.evaluation.coco_evaluation]: Per-category segm AP:
# | category        | AP    | category      | AP     | category     | AP     |
# |:----------------|:------|:--------------|:-------|:-------------|:-------|
# | Quarter-panel   | 0.000 | Front-wheel   | 32.717 | Back-window  | 10.348 |
# | Trunk           | 1.305 | Front-door    | 8.475  | Rocker-panel | 0.000  |
# | Grille          | 5.730 | Windshield    | 43.467 | Front-window | 5.284  |
# | Back-door       | 3.305 | Headlight     | 26.722 | Back-wheel   | 18.827 |
# | Back-windshield | 0.226 | Hood          | 39.893 | Fender       | 0.000  |
# | Tail-light      | 2.035 | License-plate | 0.000  | Front-bumper | 15.241 |
# | Back-bumper     | 1.144 | Mirror        | 16.228 | Roof         | 9.358  |
# [10/29 03:16:24 d2.engine.defaults]: Evaluation results for car_val in csv format:
# [10/29 03:16:24 d2.evaluation.testing]: copypaste: Task: bbox
# [10/29 03:16:24 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
#
d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [10/29 03:51:29 d2.data.common]: Serializing 200 elements to byte tensors and concatenating them all ...
# [10/29 03:51:29 d2.data.common]: Serialized dataset takes 1.50 MiB
# WARNING [10/29 03:51:29 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# [10/29 03:51:29 d2.evaluation.evaluator]: Start inference on 200 batches
# [10/29 03:51:51 d2.evaluation.evaluator]: Inference done 11/200. Dataloading: 0.0006 s/iter. Inference: 1.5436 s/iter. Eval: 0.0501 s/iter. Total: 1.5943 s/iter. ETA=0:05:01
# [10/29 03:51:57 d2.evaluation.evaluator]: Inference done 14/200. Dataloading: 0.0007 s/iter. Inference: 1.6299 s/iter. Eval: 0.0565 s/iter. Total: 1.6872 s/iter. ETA=0:05:13
# [10/29 03:52:04 d2.evaluation.evaluator]: Inference done 20/200. Dataloading: 0.0008 s/iter. Inference: 1.4099 s/iter. Eval: 0.0566 s/iter. Total: 1.4674 s/iter. ETA=0:04:24
# [10/29 03:52:10 d2.evaluation.evaluator]: Inference done 24/200. Dataloading: 0.0008 s/iter. Inference: 1.4174 s/iter. Eval: 0.0561 s/iter. Total: 1.4745 s/iter. ETA=0:04:19
# [10/29 03:52:16 d2.evaluation.evaluator]: Inference done 29/200. Dataloading: 0.0008 s/iter. Inference: 1.3794 s/iter. Eval: 0.0544 s/iter. Total: 1.4348 s/iter. ETA=0:04:05
# [10/29 03:52:22 d2.evaluation.evaluator]: Inference done 32/200. Dataloading: 0.0008 s/iter. Inference: 1.4352 s/iter. Eval: 0.0545 s/iter. Total: 1.4908 s/iter. ETA=0:04:10
# [10/29 03:52:27 d2.evaluation.evaluator]: Inference done 37/200. Dataloading: 0.0008 s/iter. Inference: 1.3671 s/iter. Eval: 0.0543 s/iter. Total: 1.4225 s/iter. ETA=0:03:51
# [10/29 03:52:34 d2.evaluation.evaluator]: Inference done 43/200. Dataloading: 0.0008 s/iter. Inference: 1.3298 s/iter. Eval: 0.0539 s/iter. Total: 1.3847 s/iter. ETA=0:03:37
# [10/29 03:52:39 d2.evaluation.evaluator]: Inference done 46/200. Dataloading: 0.0008 s/iter. Inference: 1.3558 s/iter. Eval: 0.0539 s/iter. Total: 1.4107 s/iter. ETA=0:03:37
# [10/29 03:52:45 d2.evaluation.evaluator]: Inference done 49/200. Dataloading: 0.0008 s/iter. Inference: 1.3811 s/iter. Eval: 0.0529 s/iter. Total: 1.4351 s/iter. ETA=0:03:36
# [10/29 03:52:50 d2.evaluation.evaluator]: Inference done 52/200. Dataloading: 0.0008 s/iter. Inference: 1.3988 s/iter. Eval: 0.0532 s/iter. Total: 1.4531 s/iter. ETA=0:03:35
# [10/29 03:52:55 d2.evaluation.evaluator]: Inference done 57/200. Dataloading: 0.0008 s/iter. Inference: 1.3585 s/iter. Eval: 0.0522 s/iter. Total: 1.4118 s/iter. ETA=0:03:21
# [10/29 03:53:01 d2.evaluation.evaluator]: Inference done 61/200. Dataloading: 0.0008 s/iter. Inference: 1.3715 s/iter. Eval: 0.0519 s/iter. Total: 1.4244 s/iter. ETA=0:03:17
# [10/29 03:53:08 d2.evaluation.evaluator]: Inference done 64/200. Dataloading: 0.0008 s/iter. Inference: 1.4056 s/iter. Eval: 0.0520 s/iter. Total: 1.4586 s/iter. ETA=0:03:18
# [10/29 03:53:13 d2.evaluation.evaluator]: Inference done 67/200. Dataloading: 0.0008 s/iter. Inference: 1.4185 s/iter. Eval: 0.0514 s/iter. Total: 1.4710 s/iter. ETA=0:03:15
# [10/29 03:53:18 d2.evaluation.evaluator]: Inference done 71/200. Dataloading: 0.0008 s/iter. Inference: 1.4122 s/iter. Eval: 0.0509 s/iter. Total: 1.4642 s/iter. ETA=0:03:08
# [10/29 03:53:23 d2.evaluation.evaluator]: Inference done 75/200. Dataloading: 0.0008 s/iter. Inference: 1.4024 s/iter. Eval: 0.0507 s/iter. Total: 1.4541 s/iter. ETA=0:03:01
# [10/29 03:53:28 d2.evaluation.evaluator]: Inference done 79/200. Dataloading: 0.0008 s/iter. Inference: 1.3937 s/iter. Eval: 0.0501 s/iter. Total: 1.4449 s/iter. ETA=0:02:54
# [10/29 03:53:34 d2.evaluation.evaluator]: Inference done 83/200. Dataloading: 0.0008 s/iter. Inference: 1.3967 s/iter. Eval: 0.0500 s/iter. Total: 1.4478 s/iter. ETA=0:02:49
# [10/29 03:53:41 d2.evaluation.evaluator]: Inference done 88/200. Dataloading: 0.0008 s/iter. Inference: 1.3887 s/iter. Eval: 0.0492 s/iter. Total: 1.4389 s/iter. ETA=0:02:41
# [10/29 03:53:47 d2.evaluation.evaluator]: Inference done 93/200. Dataloading: 0.0008 s/iter. Inference: 1.3810 s/iter. Eval: 0.0489 s/iter. Total: 1.4310 s/iter. ETA=0:02:33
# [10/29 03:53:54 d2.evaluation.evaluator]: Inference done 97/200. Dataloading: 0.0008 s/iter. Inference: 1.3880 s/iter. Eval: 0.0485 s/iter. Total: 1.4376 s/iter. ETA=0:02:28
# [10/29 03:53:59 d2.evaluation.evaluator]: Inference done 100/200. Dataloading: 0.0008 s/iter. Inference: 1.3957 s/iter. Eval: 0.0483 s/iter. Total: 1.4452 s/iter. ETA=0:02:24
# [10/29 03:54:05 d2.evaluation.evaluator]: Inference done 104/200. Dataloading: 0.0008 s/iter. Inference: 1.4010 s/iter. Eval: 0.0483 s/iter. Total: 1.4504 s/iter. ETA=0:02:19
# [10/29 03:54:10 d2.evaluation.evaluator]: Inference done 108/200. Dataloading: 0.0008 s/iter. Inference: 1.3959 s/iter. Eval: 0.0484 s/iter. Total: 1.4454 s/iter. ETA=0:02:12
# [10/29 03:54:17 d2.evaluation.evaluator]: Inference done 112/200. Dataloading: 0.0008 s/iter. Inference: 1.3993 s/iter. Eval: 0.0482 s/iter. Total: 1.4486 s/iter. ETA=0:02:07
# [10/29 03:54:23 d2.evaluation.evaluator]: Inference done 116/200. Dataloading: 0.0008 s/iter. Inference: 1.4046 s/iter. Eval: 0.0481 s/iter. Total: 1.4538 s/iter. ETA=0:02:02
# [10/29 03:54:29 d2.evaluation.evaluator]: Inference done 122/200. Dataloading: 0.0008 s/iter. Inference: 1.3851 s/iter. Eval: 0.0482 s/iter. Total: 1.4345 s/iter. ETA=0:01:51
# [10/29 03:54:34 d2.evaluation.evaluator]: Inference done 124/200. Dataloading: 0.0008 s/iter. Inference: 1.4034 s/iter. Eval: 0.0480 s/iter. Total: 1.4525 s/iter. ETA=0:01:50
# [10/29 03:54:41 d2.evaluation.evaluator]: Inference done 128/200. Dataloading: 0.0008 s/iter. Inference: 1.4106 s/iter. Eval: 0.0477 s/iter. Total: 1.4594 s/iter. ETA=0:01:45
# [10/29 03:54:47 d2.evaluation.evaluator]: Inference done 134/200. Dataloading: 0.0008 s/iter. Inference: 1.3871 s/iter. Eval: 0.0477 s/iter. Total: 1.4360 s/iter. ETA=0:01:34
# [10/29 03:54:53 d2.evaluation.evaluator]: Inference done 137/200. Dataloading: 0.0008 s/iter. Inference: 1.4034 s/iter. Eval: 0.0478 s/iter. Total: 1.4523 s/iter. ETA=0:01:31
# [10/29 03:55:01 d2.evaluation.evaluator]: Inference done 142/200. Dataloading: 0.0008 s/iter. Inference: 1.4087 s/iter. Eval: 0.0477 s/iter. Total: 1.4575 s/iter. ETA=0:01:24
# [10/29 03:55:07 d2.evaluation.evaluator]: Inference done 145/200. Dataloading: 0.0008 s/iter. Inference: 1.4168 s/iter. Eval: 0.0480 s/iter. Total: 1.4659 s/iter. ETA=0:01:20
# [10/29 03:55:12 d2.evaluation.evaluator]: Inference done 148/200. Dataloading: 0.0008 s/iter. Inference: 1.4231 s/iter. Eval: 0.0480 s/iter. Total: 1.4722 s/iter. ETA=0:01:16
# [10/29 03:55:17 d2.evaluation.evaluator]: Inference done 151/200. Dataloading: 0.0008 s/iter. Inference: 1.4292 s/iter. Eval: 0.0478 s/iter. Total: 1.4782 s/iter. ETA=0:01:12
# [10/29 03:55:23 d2.evaluation.evaluator]: Inference done 155/200. Dataloading: 0.0008 s/iter. Inference: 1.4244 s/iter. Eval: 0.0477 s/iter. Total: 1.4732 s/iter. ETA=0:01:06
# [10/29 03:55:28 d2.evaluation.evaluator]: Inference done 158/200. Dataloading: 0.0008 s/iter. Inference: 1.4283 s/iter. Eval: 0.0478 s/iter. Total: 1.4773 s/iter. ETA=0:01:02
# [10/29 03:55:34 d2.evaluation.evaluator]: Inference done 162/200. Dataloading: 0.0008 s/iter. Inference: 1.4299 s/iter. Eval: 0.0483 s/iter. Total: 1.4793 s/iter. ETA=0:00:56
# [10/29 03:55:40 d2.evaluation.evaluator]: Inference done 166/200. Dataloading: 0.0008 s/iter. Inference: 1.4339 s/iter. Eval: 0.0482 s/iter. Total: 1.4832 s/iter. ETA=0:00:50
# [10/29 03:55:46 d2.evaluation.evaluator]: Inference done 170/200. Dataloading: 0.0008 s/iter. Inference: 1.4305 s/iter. Eval: 0.0478 s/iter. Total: 1.4794 s/iter. ETA=0:00:44
# [10/29 03:55:51 d2.evaluation.evaluator]: Inference done 173/200. Dataloading: 0.0008 s/iter. Inference: 1.4354 s/iter. Eval: 0.0479 s/iter. Total: 1.4843 s/iter. ETA=0:00:40
# [10/29 03:55:58 d2.evaluation.evaluator]: Inference done 178/200. Dataloading: 0.0008 s/iter. Inference: 1.4348 s/iter. Eval: 0.0479 s/iter. Total: 1.4839 s/iter. ETA=0:00:32
# [10/29 03:56:05 d2.evaluation.evaluator]: Inference done 182/200. Dataloading: 0.0008 s/iter. Inference: 1.4366 s/iter. Eval: 0.0483 s/iter. Total: 1.4859 s/iter. ETA=0:00:26
# [10/29 03:56:11 d2.evaluation.evaluator]: Inference done 185/200. Dataloading: 0.0008 s/iter. Inference: 1.4481 s/iter. Eval: 0.0481 s/iter. Total: 1.4973 s/iter. ETA=0:00:22
# [10/29 03:56:17 d2.evaluation.evaluator]: Inference done 191/200. Dataloading: 0.0008 s/iter. Inference: 1.4304 s/iter. Eval: 0.0481 s/iter. Total: 1.4796 s/iter. ETA=0:00:13
# [10/29 03:56:23 d2.evaluation.evaluator]: Inference done 195/200. Dataloading: 0.0008 s/iter. Inference: 1.4324 s/iter. Eval: 0.0479 s/iter. Total: 1.4814 s/iter. ETA=0:00:07
# [10/29 03:56:29 d2.evaluation.evaluator]: Inference done 199/200. Dataloading: 0.0008 s/iter. Inference: 1.4325 s/iter. Eval: 0.0478 s/iter. Total: 1.4815 s/iter. ETA=0:00:01
# [10/29 03:56:30 d2.evaluation.evaluator]: Total inference time: 0:04:48.057162 (1.477216 s / iter per device, on 1 devices)
# [10/29 03:56:30 d2.evaluation.evaluator]: Total inference pure compute time: 0:04:38 (1.425802 s / iter per device, on 1 devices)
# [10/29 03:56:30 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [10/29 03:56:30 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# [10/29 03:56:30 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [10/29 03:56:30 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.29 seconds.
# [10/29 03:56:30 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [10/29 03:56:30 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.06 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.445
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.756
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.469
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.063
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.289
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.513
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.504
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.593
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.593
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.119
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.476
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.648
# [10/29 03:56:30 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 44.452 | 75.647 | 46.929 | 6.283 | 28.852 | 51.270 |
# [10/29 03:56:30 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category        | AP     | category      | AP     | category     | AP     |
# |:----------------|:-------|:--------------|:-------|:-------------|:-------|
# | Quarter-panel   | 23.184 | Front-wheel   | 50.417 | Back-window  | 43.987 |
# | Trunk           | 24.368 | Front-door    | 64.399 | Rocker-panel | 42.532 |
# | Grille          | 36.111 | Windshield    | 68.470 | Front-window | 43.604 |
# | Back-door       | 58.104 | Headlight     | 46.903 | Back-wheel   | 45.963 |
# | Back-windshield | 51.339 | Hood          | 54.918 | Fender       | 46.854 |
# | Tail-light      | 32.523 | License-plate | 39.227 | Front-bumper | 54.472 |
# | Back-bumper     | 44.518 | Mirror        | 31.738 | Roof         | 29.851 |
# Loading and preparing results...
# DONE (t=0.15s)
# creating index...
# index created!
# [10/29 03:56:31 d2.evaluation.fast_eval_api]: Evaluate annotation type *segm*
# [10/29 03:56:31 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.43 seconds.
# [10/29 03:56:31 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [10/29 03:56:31 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.06 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.431
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.702
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.453
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.033
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.245
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.545
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.487
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.569
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.571
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.112
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.439
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.640
# [10/29 03:56:31 d2.evaluation.coco_evaluation]: Evaluation results for segm:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 43.082 | 70.170 | 45.314 | 3.309 | 24.514 | 54.495 |
# [10/29 03:56:31 d2.evaluation.coco_evaluation]: Per-category segm AP:
# | category        | AP     | category      | AP     | category     | AP     |
# |:----------------|:-------|:--------------|:-------|:-------------|:-------|
# | Quarter-panel   | 15.142 | Front-wheel   | 59.075 | Back-window  | 41.670 |
# | Trunk           | 19.210 | Front-door    | 66.919 | Rocker-panel | 4.851  |
# | Grille          | 32.538 | Windshield    | 74.560 | Front-window | 49.738 |
# | Back-door       | 54.703 | Headlight     | 50.028 | Back-wheel   | 49.799 |
# | Back-windshield | 55.175 | Hood          | 63.026 | Fender       | 36.981 |
# | Tail-light      | 36.544 | License-plate | 35.644 | Front-bumper | 45.537 |
# | Back-bumper     | 47.828 | Mirror        | 39.487 | Roof         | 26.278 |
# [10/29 03:56:31 d2.engine.defaults]: Evaluation results for car_val in csv format:
# [10/29 03:56:31 d2.evaluation.testing]: copypaste: Task: bbox
# [10/29 03:56:31 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [10/29 03:56:31 d2.evaluation.testing]: copypaste: 44.4515,75.6474,46.9288,6.2825,28.8520,51.2703
# [10/29 03:56:31 d2.evaluation.testing]: copypaste: Task: segm
# [10/29 03:56:31 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [10/29 03:56:31 d2.evaluation.testing]: copypaste: 43.0825,70.1699,45.3141,3.3087,24.5145,54.4951

# %%
import os
import torch
from detectron2.engine import DefaultPredictor  # Import DefaultPredictor

# Set the path to the trained model
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")  # path to the model we just trained
# Set a custom testing threshold
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5

# Create a predictor
predictor = DefaultPredictor(cfg)
# Out:
# [10/29 03:57:45 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from ./output_20241029_030402\model_final.pth ...
# C:\Users\kurt_\anaconda3\envs\my-env-detectron2\lib\site-packages\fvcore\common\checkpoint.py:252: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(f, map_location=torch.device("cpu"))

# %%
import json
import pandas as pd

metrics_path = r"C:\Users\kurt_\car-parts-and-damage-detection-v4\car-part-detection\output_20241029_030402\metrics.json"
metrics_columns = [
    "data_time",
    "eta_seconds",
    "fast_rcnn/cls_accuracy",
    "fast_rcnn/false_negative",
    "fast_rcnn/fg_cls_accuracy",
    "iteration",
    "loss_box_reg",
    "loss_cls",
    "loss_mask",
    "loss_rpn_cls",
    "loss_rpn_loc",
    "lr",
    "mask_rcnn/accuracy",
    "mask_rcnn/false_negative",
    "mask_rcnn/false_positive",
    "rank_data_time",
    "roi_head/num_bg_samples",
    "roi_head/num_fg_samples",
    "rpn/num_neg_anchors",
    "rpn/num_pos_anchors",
    "time",
    "total_loss"
]


data = []
with open(metrics_path, 'r') as f:
    for line in f:
        json_data = json.loads(line)
        filtered_data = {metric: json_data.get(metric, None) for metric in metrics_columns}
        data.append(filtered_data)

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#      data_time  eta_seconds  fast_rcnn/cls_accuracy  fast_rcnn/false_negative  \
# 0     0.006051  1493.311540                0.255208                  0.479167
# 1     0.005744  1483.978641                0.510417                  0.791667
# 2     0.006686  1492.447472                0.729167                  1.000000
# 3     0.006623  1492.776153                0.750000                  1.000000
# 4     0.005685  1507.685280                0.750000                  1.000000
# ..         ...          ...                     ...                       ...
# 121   0.006121    37.425573                0.875000                  0.250000
# 122   0.006167    24.927752                0.885417                  0.250000
# 123   0.006386    12.453276                0.890625                  0.291667
# 124   0.006229     0.000000                0.875000                  0.270833
# 125        NaN          NaN                     NaN                       NaN
#
#      fast_rcnn/fg_cls_accuracy  iteration  loss_box_reg  loss_cls  loss_mask  \
# 0                     0.000000         19      0.889114  2.898864   0.694549
# 1                     0.000000         39      0.934017  2.771129   0.693971
# 2                     0.000000         59      0.920238  2.501948   0.693353
# 3                     0.000000         79      0.922401  2.122240   0.692677
# 4                     0.000000         99      0.966170  1.739263   0.691076
# ..                         ...        ...           ...       ...        ...
# 121                   0.666667       2439      0.401520  0.343012   0.209962
# 122                   0.645833       2459      0.416664  0.297826   0.205125
# 123                   0.666667       2479      0.450858  0.347475   0.232633
# 124                   0.604167       2499      0.419987  0.355481   0.207827
# 125                        NaN       2500           NaN       NaN        NaN
#
#      loss_rpn_cls  ...  mask_rcnn/accuracy  mask_rcnn/false_negative  \
# 0        0.950187  ...            0.436650                  0.635322
# 1        0.836098  ...            0.468325                  0.634283
# 2        0.717985  ...            0.475553                  0.590505
# 3        0.624182  ...            0.506378                  0.593658
# 4        0.468993  ...            0.552509                  0.493496
# ..            ...  ...                 ...                       ...
# 121      0.072677  ...            0.909014                  0.085251
# 122      0.075934  ...            0.918048                  0.074950
# 123      0.075657  ...            0.900510                  0.096996
# 124      0.067247  ...            0.916560                  0.086392
# 125           NaN  ...                 NaN                       NaN
#
#      mask_rcnn/false_positive  rank_data_time  roi_head/num_bg_samples  \
# 0                    0.495216        0.006051                     12.0
# 1                    0.428119        0.005744                     12.0
# 2                    0.446742        0.006686                     12.0
# 3                    0.379515        0.006623                     12.0
# 4                    0.390551        0.005685                     12.0
# ..                        ...             ...                      ...
# 121                  0.084102        0.006121                     12.0
# 122                  0.083517        0.006167                     12.0
# 123                  0.096151        0.006386                     12.0
# 124                  0.095788        0.006229                     12.0
# 125                       NaN             NaN                      NaN
#
#      roi_head/num_fg_samples  rpn/num_neg_anchors  rpn/num_pos_anchors  \
# 0                        4.0           132.583333           123.416667
# 1                        4.0           130.750000           125.250000
# 2                        4.0           134.833333           121.166667
# 3                        4.0           131.416667           124.583333
# 4                        4.0           131.250000           124.750000
# ..                       ...                  ...                  ...
# 121                      4.0           132.750000           123.250000
# 122                      4.0           131.583333           124.416667
# 123                      4.0           132.333333           123.666667
# 124                      4.0           132.750000           123.250000
# 125                      NaN                  NaN                  NaN
#
#          time  total_loss
# 0    0.602142    5.768508
# 1    0.613746    5.602310
# 2    0.644231    5.153533
# 3    0.641085    4.669874
# 4    0.630769    4.123984
# ..        ...         ...
# 121  0.609932    1.233454
# 122  0.640508    1.181831
# 123  0.620808    1.322165
# 124  0.578230    1.236976
# 125       NaN         NaN
#
# [126 rows x 22 columns]

# %%
df = df.dropna()
df
# Out:
#      data_time  eta_seconds  fast_rcnn/cls_accuracy  fast_rcnn/false_negative  \
# 0     0.006051  1493.311540                0.255208                  0.479167
# 1     0.005744  1483.978641                0.510417                  0.791667
# 2     0.006686  1492.447472                0.729167                  1.000000
# 3     0.006623  1492.776153                0.750000                  1.000000
# 4     0.005685  1507.685280                0.750000                  1.000000
# ..         ...          ...                     ...                       ...
# 120   0.005935    49.913628                0.890625                  0.208333
# 121   0.006121    37.425573                0.875000                  0.250000
# 122   0.006167    24.927752                0.885417                  0.250000
# 123   0.006386    12.453276                0.890625                  0.291667
# 124   0.006229     0.000000                0.875000                  0.270833
#
#      fast_rcnn/fg_cls_accuracy  iteration  loss_box_reg  loss_cls  loss_mask  \
# 0                     0.000000         19      0.889114  2.898864   0.694549
# 1                     0.000000         39      0.934017  2.771129   0.693971
# 2                     0.000000         59      0.920238  2.501948   0.693353
# 3                     0.000000         79      0.922401  2.122240   0.692677
# 4                     0.000000         99      0.966170  1.739263   0.691076
# ..                         ...        ...           ...       ...        ...
# 120                   0.687500       2419      0.404475  0.290268   0.189352
# 121                   0.666667       2439      0.401520  0.343012   0.209962
# 122                   0.645833       2459      0.416664  0.297826   0.205125
# 123                   0.666667       2479      0.450858  0.347475   0.232633
# 124                   0.604167       2499      0.419987  0.355481   0.207827
#
#      loss_rpn_cls  ...  roi_head/num_bg_samples  roi_head/num_fg_samples  \
# 0        0.950187  ...                     12.0                      4.0
# 1        0.836098  ...                     12.0                      4.0
# 2        0.717985  ...                     12.0                      4.0
# 3        0.624182  ...                     12.0                      4.0
# 4        0.468993  ...                     12.0                      4.0
# ..            ...  ...                      ...                      ...
# 120      0.075001  ...                     12.0                      4.0
# 121      0.072677  ...                     12.0                      4.0
# 122      0.075934  ...                     12.0                      4.0
# 123      0.075657  ...                     12.0                      4.0
# 124      0.067247  ...                     12.0                      4.0
#
#      rpn/num_neg_anchors  rpn/num_pos_anchors      time  total_loss  \
# 0             132.583333           123.416667  0.602142    5.768508
# 1             130.750000           125.250000  0.613746    5.602310
# 2             134.833333           121.166667  0.644231    5.153533
# 3             131.416667           124.583333  0.641085    4.669874
# 4             131.250000           124.750000  0.630769    4.123984
# ..                   ...                  ...       ...         ...
# 120           133.500000           122.500000  0.610468    1.137078
# 121           132.750000           123.250000  0.609932    1.233454
# 122           131.583333           124.416667  0.640508    1.181831
# 123           132.333333           123.666667  0.620808    1.322165
# 124           132.750000           123.250000  0.578230    1.236976
#
#      precision    recall  f1_score  accuracy
# 0     0.504784  0.364678  0.423442  0.436650
# 1     0.571881  0.365717  0.446133  0.468325
# 2     0.553258  0.409495  0.470643  0.475553
# 3     0.620485  0.406342  0.491084  0.506378
# 4     0.609449  0.506504  0.553228  0.552509
# ..         ...       ...       ...       ...
# 120   0.915786  0.917647  0.916715  0.919537
# 121   0.915898  0.914749  0.915323  0.909014
# 122   0.916483  0.925050  0.920747  0.918048
# 123   0.903849  0.903004  0.903426  0.900510
# 124   0.904212  0.913608  0.908886  0.916560
#
# [125 rows x 26 columns]

# %%
# F1 Skoru Hesaplama
# F1 Skoru = 2 * (Precision * Recall) / (Precision + Recall)
# Precision = TP / (TP + FP)
# Recall = TP / (TP + FN)

# Varsayımsal olarak mask_rcnn accuracy ve false negative / positive kullanılarak hesaplama
precision = 1 - df['mask_rcnn/false_positive']
recall = 1 - df['mask_rcnn/false_negative']
f1_score = 2 * (precision * recall) / (precision + recall)
accuracy = df['mask_rcnn/accuracy']

# %%
#(Loss) 
plt.figure(figsize=(10, 6))
plt.plot(df['iteration'], df['total_loss'], label='Total Loss')
plt.plot(df['iteration'], df['loss_cls'], label='Classification Loss')
plt.plot(df['iteration'], df['loss_box_reg'], label='Box Regression Loss')
plt.plot(df['iteration'], df['loss_mask'], label='Mask Loss')
plt.plot(df['iteration'], df['loss_rpn_cls'], label='RPN Classification Loss')
plt.plot(df['iteration'], df['loss_rpn_loc'], label='RPN Location Loss')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.title('Loss During Training')
plt.legend()
plt.grid(True)
plt.show()

#  Mask R-CNN Accuracy, False Positive, False Negative 
plt.figure(figsize=(10, 6))
plt.plot(df['iteration'], df['mask_rcnn/accuracy'], label='Mask R-CNN Accuracy')
plt.plot(df['iteration'], df['mask_rcnn/false_positive'], label='Mask R-CNN False Positive')
plt.plot(df['iteration'], df['mask_rcnn/false_negative'], label='Mask R-CNN False Negative')
plt.xlabel('Iteration')
plt.ylabel('Accuracy / Error Rate')
plt.title('Mask R-CNN Accuracy and Error Rates')
plt.legend()
plt.grid(True)
plt.show()

# %%
#f1 score
plt.figure(figsize=(10, 6))
plt.plot(df['iteration'], f1_score, label='F1 Score', color='purple')
plt.xlabel('Iteration')
plt.ylabel('F1 Score')
plt.title('F1 Score During Training')
plt.legend()
plt.grid(True)
plt.show()

# Recall
plt.figure(figsize=(10, 6))
plt.plot(df['iteration'], recall, label='Recall', color='green')
plt.xlabel('Iteration')
plt.ylabel('Recall')
plt.title('Recall During Training')
plt.legend()
plt.grid(True)
plt.show()

# Precision
plt.figure(figsize=(10, 6))
plt.plot(df['iteration'], precision, label='Precision', color='blue')
plt.xlabel('Iteration')
plt.ylabel('Precision')
plt.title('Precision During Training')
plt.legend()
plt.grid(True)
plt.show()

# %%
df = df.assign(precision=precision, recall=recall, f1_score=f1_score, accuracy=accuracy)
result_table = df[['iteration', 'precision', 'recall', 'f1_score', 'accuracy']]
result_table
# Out:
#      iteration  precision    recall  f1_score  accuracy
# 0           19   0.504784  0.364678  0.423442  0.436650
# 1           39   0.571881  0.365717  0.446133  0.468325
# 2           59   0.553258  0.409495  0.470643  0.475553
# 3           79   0.620485  0.406342  0.491084  0.506378
# 4           99   0.609449  0.506504  0.553228  0.552509
# ..         ...        ...       ...       ...       ...
# 120       2419   0.915786  0.917647  0.916715  0.919537
# 121       2439   0.915898  0.914749  0.915323  0.909014
# 122       2459   0.916483  0.925050  0.920747  0.918048
# 123       2479   0.903849  0.903004  0.903426  0.900510
# 124       2499   0.904212  0.913608  0.908886  0.916560
#
# [125 rows x 5 columns]

# %%
import cv2
import matplotlib.pyplot as plt
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog
im = cv2.imread(r"C:\Users\kurt_\Downloads\hasar13.jpg")
output = predictor(im)

# Visualize original image
plt.subplot(1, 2, 1)
plt.imshow(im[:, :, ::-1])
plt.title('Original Image')
plt.axis('off')

v = Visualizer(
    im[:, :, ::-1],
    metadata=MetadataCatalog.get(cfg.DATASETS.TRAIN[0]),
    scale=1,
    instance_mode=1
)
out = v.draw_instance_predictions(output["instances"].to("cpu"))

# Show the masked image with class labels
plt.subplot(1, 2, 2)
plt.imshow(out.get_image()[:, :, ::-1])
plt.title('Masked Image with Class Labels')
plt.axis('off')

plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog
im = cv2.imread(r"C:\Users\kurt_\Downloads\arac.jpg")
output = predictor(im)

# Visualize original image
plt.subplot(1, 2, 1)
plt.imshow(im[:, :, ::-1])
plt.title('Original Image')
plt.axis('off')

v = Visualizer(
    im[:, :, ::-1],
    metadata=MetadataCatalog.get(cfg.DATASETS.TRAIN[0]),
    scale=1,
    instance_mode=1
)
out = v.draw_instance_predictions(output["instances"].to("cpu"))

# Show the masked image with class labels
plt.subplot(1, 2, 2)
plt.imshow(out.get_image()[:, :, ::-1])
plt.title('Masked Image with Class Labels')
plt.axis('off')

plt.show()
