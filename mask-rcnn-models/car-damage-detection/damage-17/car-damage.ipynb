# %%
import sys, os, json, random
import torch
import sys
import datetime

import cv2

import numpy as np
import pandas as pd

import skimage.io as io

import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = [16,9]
# %matplotlib inline

from shapely.geometry import Polygon

# path to the images
data_dir = "C:/Users/kurt_/car-parts-and-damage-detection-v18/car-damage-detection/car-damages/File1"

# create paths for traininig and validaiton data
os.makedirs("C:/Users/kurt_/car-parts-and-damage-detection-v18/car-damage-detection/working/data/", exist_ok=True)
os.makedirs("C:/Users/kurt_/car-parts-and-damage-detection-v18/car-damage-detection/working/data/train/", exist_ok=True)
os.makedirs("C:/Users/kurt_/car-parts-and-damage-detection-v18/car-damage-detection/working/data/val/", exist_ok=True)

# create path to store the model config
os.makedirs("C:/Users/kurt_/car-parts-and-damage-detection-v18/car-damage-detection/working/model/", exist_ok=True)

data_working_dir = "C:/Users/kurt_/car-parts-and-damage-detection-v18/car-damage-detection/working/data/"
model_dir = "C:/Users/kurt_/car-parts-and-damage-detection-v18/car-damage-detection/working/model/"

# %%
import json
import os
import shutil
import random
from PIL import Image

images_dir = os.path.join(data_dir, "img")
annotations_dir = os.path.join(data_dir, "ann")


# Get list of images
images = [f for f in os.listdir(images_dir) if os.path.isfile(os.path.join(images_dir, f))]

# Shuffle the images
random.shuffle(images)

# Split the dataset (e.g., 80% train, 20% val)
split_index = int(0.8 * len(images))
train_images = images[:split_index]
val_images = images[split_index:]

def convert_to_coco(images, images_dir, annotations_dir, output_dir):
    coco_output = {
        "images": [],
        "annotations": [],
        "categories": []
    }

    category_mapping = {
        "Dent": 1,
        "Scratch": 2,
        "Broken part": 3,
        "Paint chip": 4,
        "Missing part": 5,
        "Flaking": 6,
        "Corrosion": 7,
        "Cracked": 8
    }

    for category, id in category_mapping.items():
        coco_output["categories"].append({
            "id": id,
            "name": category
        })

    annotation_id = 1
    for idx, image_filename in enumerate(images):
        image_path = os.path.join(images_dir, image_filename)
        annotation_path = os.path.join(annotations_dir, image_filename + ".json")
        
        # Copy the image to the output directory
        shutil.copy(image_path, output_dir)
        
        # Open the image to get its dimensions
        with Image.open(image_path) as img:
            width, height = img.size
        
        coco_output["images"].append({
            "file_name": image_filename,
            "height": height,
            "width": width,
            "id": idx
        })
        
        with open(annotation_path) as f:
            objs = json.load(f)["objects"]

        for obj in objs:
            px = [point[0] for point in obj["points"]["exterior"]]
            py = [point[1] for point in obj["points"]["exterior"]]
            poly = [(x, y) for x, y in zip(px, py)]
            poly = [p for x in poly for p in x]

            category_id = category_mapping.get(obj["classTitle"], -1)
            if category_id == -1:
                continue  # Skip unknown categories
            
            bbox = [min(px), min(py), max(px) - min(px), max(py) - min(py)]
            
            coco_output["annotations"].append({
                "bbox": bbox,
                "category_id": category_id,
                "image_id": idx,
                "segmentation": [poly],
                "area": bbox[2] * bbox[3],
                "iscrowd": 0,
                "id": annotation_id
            })
            annotation_id += 1

    return coco_output

train_output = convert_to_coco(train_images, images_dir, annotations_dir, os.path.join(data_working_dir, "train"))
val_output = convert_to_coco(val_images, images_dir, annotations_dir, os.path.join(data_working_dir, "val"))

with open(os.path.join(data_working_dir, "train", "annotations.json"), "w") as f:
    json.dump(train_output, f, indent=4)

with open(os.path.join(data_working_dir, "val", "annotations.json"), "w") as f:
    json.dump(val_output, f, indent=4)

# %%
from detectron2.data.datasets import register_coco_instances

# Register train and val datasets
register_coco_instances("car_train", {}, os.path.join(data_working_dir, "train", "annotations.json"), os.path.join(data_working_dir, "train"))
register_coco_instances("car_val", {}, os.path.join(data_working_dir, "val", "annotations.json"), os.path.join(data_working_dir, "val"))

# Load metadata
from detectron2.data import MetadataCatalog
car_metadata = MetadataCatalog.get("car_train")

# %%
import random
from detectron2.utils.visualizer import Visualizer
from detectron2.data import DatasetCatalog

dataset_dicts = DatasetCatalog.get("car_train")
for d in random.sample(dataset_dicts, 3):
    img = cv2.imread(d["file_name"])
    visualizer = Visualizer(img[:, :, ::-1], metadata=car_metadata, scale=1)
    vis = visualizer.draw_dataset_dict(d)
    plt.imshow(vis.get_image()[:, :, ::-1])
    plt.show()

# %%
import os
import torch
import detectron2
import datetime
from detectron2.engine import DefaultTrainer, hooks, HookBase
from detectron2.config import get_cfg
from detectron2 import model_zoo
from detectron2.data import DatasetMapper, build_detection_train_loader
from detectron2.data.transforms import (
    RandomFlip,
    RandomBrightness,
    RandomContrast,
    RandomRotation,
    ResizeShortestEdge
)

# Define output directory
output_dir = "./output_" + datetime.datetime.now().strftime('%Y%m%d_%H%M%S')

# Create configuration
cfg = get_cfg()

# Set output directory
cfg.OUTPUT_DIR = output_dir

# Merge configuration from the model zoo
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_101_FPN_3x.yaml"))

# Set training and testing datasets
cfg.DATASETS.TRAIN = ("car_train",)
cfg.DATASETS.TEST = ("car_val",)  # for evaluation during training
cfg.DATALOADER.NUM_WORKERS = 8

# Set device to cuda if available
cfg.MODEL.DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'

# Set weights from the model zoo
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-InstanceSegmentation/mask_rcnn_R_101_FPN_3x.yaml")  # Let training initialize from model zoo

# Set batch size, learning rate, and maximum iterations
cfg.SOLVER.IMS_PER_BATCH = 4
cfg.SOLVER.BASE_LR = 0.00075 
cfg.SOLVER.MAX_ITER = 10000  # Increase the maximum number of iterations
cfg.SOLVER.STEPS = []  # do not decay learning rate
cfg.INPUT.MASK_FORMAT = 'polygon'

cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.6
cfg.SOLVER.LR_SCHEDULER_NAME = "WarmupCosineLR"
cfg.SOLVER.MOMENTUM = 0.9
cfg.SOLVER.WARMUP_ITERS = 250
cfg.TEST.EVAL_PERIOD = 2000

# Set batch size per image and number of classes
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 256   # images used to calculate cls and reg loss during training.
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 8  # total number of classes


# Create output directory if it does not exist
os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)

# Custom Trainer to add hooks for status updates
class MyTrainer(DefaultTrainer):
    @classmethod
    def build_evaluator(cls, cfg, dataset_name, output_folder=None):
        from detectron2.evaluation import COCOEvaluator, inference_on_dataset, print_csv_format
        return COCOEvaluator(dataset_name, cfg, False, output_folder)

    @classmethod
    def build_train_loader(cls, cfg):
        """
        Customize the data loader to include data augmentation during training.
        """
        return build_detection_train_loader(
            cfg,
            mapper=DatasetMapper(cfg, is_train=True, augmentations=[
                RandomFlip(prob=0.5),  # Randomly flip the image horizontally
                RandomBrightness(0.8, 1.2),  # Adjust brightness randomly
                RandomContrast(0.8, 1.2),  # Adjust contrast randomly
                RandomRotation(angle=[-10, 10]),  # Rotate images within the range -10 to 10 degrees
                ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333)  # Standard resizing
            ])
        )

    def build_hooks(self):
        hooks = super().build_hooks()
        hooks.insert(0, PrintTrainingStatus())
        return hooks

# Custom hook to print training status
class PrintTrainingStatus(HookBase):
    def after_step(self):
        # Print training status every 500 iterations
        if self.trainer.iter % 500 == 0 or self.trainer.iter == self.trainer.max_iter:
            print(f"Iteration {self.trainer.iter}/{self.trainer.max_iter} - Loss: {self.trainer.storage.latest()['total_loss']}")

# Create a trainer
trainer = MyTrainer(cfg)

# Load the model or resume training
trainer.resume_or_load(resume=False)

# Train the model
trainer.train()
# Out:
# [11/30 14:53:35 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (6): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (7): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (8): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (9): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (10): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (11): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (12): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (13): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (14): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (15): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (16): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (17): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (18): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (19): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (20): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (21): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (22): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=9, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=32, bias=True)
#     )
#     (mask_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(14, 14), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(14, 14), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(14, 14), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(14, 14), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (mask_head): MaskRCNNConvUpsampleHead(
#       (mask_fcn1): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn2): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn3): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn4): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (deconv): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#       (deconv_relu): ReLU()
#       (predictor): Conv2d(256, 8, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )
# [11/30 14:53:35 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [RandomFlip(prob=0.5), RandomBrightness(intensity_min=0.8, intensity_max=1.2), RandomContrast(intensity_min=0.8, intensity_max=1.2), RandomRotation(angle=[-10, 10]), ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333)]
# [11/30 14:53:35 d2.data.datasets.coco]: Loaded 651 images in COCO format from C:/Users/kurt_/car-parts-and-damage-detection-v18/car-damage-detection/working/data/train\annotations.json
# [11/30 14:53:35 d2.data.build]: Removed 0 images with no usable annotations. 651 images left.
# [11/30 14:53:35 d2.data.build]: Distribution of instances among all 8 categories:
# |  category  | #instances   |   category   | #instances   |  category   | #instances   |
# |:----------:|:-------------|:------------:|:-------------|:-----------:|:-------------|
# |    Dent    | 1326         |   Scratch    | 2523         | Broken part | 1221         |
# | Paint chip | 1078         | Missing part | 505          |   Flaking   | 245          |
# | Corrosion  | 239          |   Cracked    | 62           |             |              |
# |   total    | 7199         |              |              |             |              |
# [11/30 14:53:35 d2.data.build]: Using training sampler TrainingSampler
# [11/30 14:53:35 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [11/30 14:53:35 d2.data.common]: Serializing 651 elements to byte tensors and concatenating them all ...
# [11/30 14:53:35 d2.data.common]: Serialized dataset takes 2.24 MiB
# [11/30 14:53:35 d2.data.build]: Making batched data loader with batch_size=4
# [11/30 14:53:35 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-InstanceSegmentation/mask_rcnn_R_101_FPN_3x/138205316/model_final_a3ec72.pkl ...
# Skip loading parameter 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (9, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (9,) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 1024) in the checkpoint but (32, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (32,) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.mask_head.predictor.weight' to the model due to incompatible shapes: (80, 256, 1, 1) in the checkpoint but (8, 256, 1, 1) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.mask_head.predictor.bias' to the model due to incompatible shapes: (80,) in the checkpoint but (8,) in the model! You might want to double check if this is expected.
# Some model parameters or buffers are not found in the checkpoint:
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# roi_heads.mask_head.predictor.{bias, weight}
# [11/30 14:53:36 d2.engine.train_loop]: Starting training from iteration 0
# C:\Users\kurt_\anaconda3\envs\my-env-detectron2\lib\site-packages\torch\functional.py:513: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\TensorShape.cpp:3610.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Iteration 0/10000 - Loss: (3.698736160993576, 0)
# [11/30 14:54:51 d2.utils.events]:  eta: 6:24:23  iter: 19  total_loss: 6.044  loss_cls: 2.134  loss_box_reg: 0.2275  loss_mask: 0.692  loss_rpn_cls: 2.669  loss_rpn_loc: 0.3254    time: 3.6382  last_time: 5.6692  data_time: 0.2261  last_data_time: 0.0043   lr: 5.7605e-05  max_mem: 6059M
# [11/30 14:56:08 d2.utils.events]:  eta: 7:03:28  iter: 39  total_loss: 2.663  loss_cls: 1.14  loss_box_reg: 0.1814  loss_mask: 0.6849  loss_rpn_cls: 0.3454  loss_rpn_loc: 0.2318    time: 3.7321  last_time: 2.1872  data_time: 0.0047  last_data_time: 0.0045   lr: 0.00011745  max_mem: 6060M
# [11/30 14:57:09 d2.utils.events]:  eta: 6:27:01  iter: 59  total_loss: 1.757  loss_cls: 0.4325  loss_box_reg: 0.1536  loss_mask: 0.676  loss_rpn_cls: 0.2535  loss_rpn_loc: 0.1541    time: 3.4977  last_time: 2.2864  data_time: 0.0044  last_data_time: 0.0049   lr: 0.0001773  max_mem: 6060M
# [11/30 14:58:15 d2.utils.events]:  eta: 6:26:15  iter: 79  total_loss: 1.92  loss_cls: 0.5933  loss_box_reg: 0.3205  loss_mask: 0.6578  loss_rpn_cls: 0.2168  loss_rpn_loc: 0.1759    time: 3.4576  last_time: 0.8749  data_time: 0.0046  last_data_time: 0.0028   lr: 0.00023715  max_mem: 6060M
# [11/30 14:59:24 d2.utils.events]:  eta: 6:39:43  iter: 99  total_loss: 1.877  loss_cls: 0.5401  loss_box_reg: 0.3165  loss_mask: 0.6447  loss_rpn_cls: 0.2096  loss_rpn_loc: 0.198    time: 3.4529  last_time: 1.0849  data_time: 0.0052  last_data_time: 0.0032   lr: 0.000297  max_mem: 6060M
# [11/30 15:00:41 d2.utils.events]:  eta: 6:40:51  iter: 119  total_loss: 1.971  loss_cls: 0.5678  loss_box_reg: 0.3566  loss_mask: 0.6121  loss_rpn_cls: 0.1917  loss_rpn_loc: 0.1965    time: 3.5191  last_time: 4.6781  data_time: 0.0049  last_data_time: 0.0065   lr: 0.00035684  max_mem: 6060M
# [11/30 15:01:50 d2.utils.events]:  eta: 6:40:03  iter: 139  total_loss: 1.912  loss_cls: 0.5295  loss_box_reg: 0.3312  loss_mask: 0.5774  loss_rpn_cls: 0.1928  loss_rpn_loc: 0.2437    time: 3.5110  last_time: 0.8880  data_time: 0.0045  last_data_time: 0.0056   lr: 0.00041669  max_mem: 6060M
# [11/30 15:02:46 d2.utils.events]:  eta: 6:33:41  iter: 159  total_loss: 1.838  loss_cls: 0.5446  loss_box_reg: 0.3744  loss_mask: 0.547  loss_rpn_cls: 0.1672  loss_rpn_loc: 0.2302    time: 3.4167  last_time: 4.2994  data_time: 0.0041  last_data_time: 0.0050   lr: 0.00047654  max_mem: 6061M
# [11/30 15:03:41 d2.utils.events]:  eta: 6:22:12  iter: 179  total_loss: 1.924  loss_cls: 0.5391  loss_box_reg: 0.3621  loss_mask: 0.5176  loss_rpn_cls: 0.1704  loss_rpn_loc: 0.2566    time: 3.3454  last_time: 2.4343  data_time: 0.0041  last_data_time: 0.0036   lr: 0.00053639  max_mem: 6061M
# [11/30 15:04:47 d2.utils.events]:  eta: 6:18:41  iter: 199  total_loss: 1.675  loss_cls: 0.4931  loss_box_reg: 0.3049  loss_mask: 0.4667  loss_rpn_cls: 0.1805  loss_rpn_loc: 0.1729    time: 3.3373  last_time: 6.4168  data_time: 0.0045  last_data_time: 0.0025   lr: 0.00059623  max_mem: 6061M
# [11/30 15:05:46 d2.utils.events]:  eta: 6:16:27  iter: 219  total_loss: 1.815  loss_cls: 0.523  loss_box_reg: 0.4077  loss_mask: 0.4601  loss_rpn_cls: 0.1534  loss_rpn_loc: 0.2004    time: 3.3028  last_time: 0.8851  data_time: 0.0047  last_data_time: 0.0058   lr: 0.00065608  max_mem: 6061M
# [11/30 15:06:52 d2.utils.events]:  eta: 6:18:48  iter: 239  total_loss: 1.936  loss_cls: 0.6249  loss_box_reg: 0.5118  loss_mask: 0.4576  loss_rpn_cls: 0.1436  loss_rpn_loc: 0.1892    time: 3.3042  last_time: 2.4709  data_time: 0.0048  last_data_time: 0.0071   lr: 0.00071593  max_mem: 6061M
# [11/30 15:08:05 d2.utils.events]:  eta: 6:26:19  iter: 259  total_loss: 1.864  loss_cls: 0.5369  loss_box_reg: 0.3974  loss_mask: 0.4663  loss_rpn_cls: 0.1597  loss_rpn_loc: 0.249    time: 3.3298  last_time: 4.0596  data_time: 0.0043  last_data_time: 0.0040   lr: 0.00074876  max_mem: 6061M
# [11/30 15:08:57 d2.utils.events]:  eta: 6:18:07  iter: 279  total_loss: 1.847  loss_cls: 0.5621  loss_box_reg: 0.4975  loss_mask: 0.4393  loss_rpn_cls: 0.1409  loss_rpn_loc: 0.1358    time: 3.2770  last_time: 0.8339  data_time: 0.0040  last_data_time: 0.0032   lr: 0.00074856  max_mem: 6061M
# [11/30 15:09:55 d2.utils.events]:  eta: 6:15:55  iter: 299  total_loss: 1.884  loss_cls: 0.5482  loss_box_reg: 0.4498  loss_mask: 0.4403  loss_rpn_cls: 0.1391  loss_rpn_loc: 0.2514    time: 3.2520  last_time: 0.8112  data_time: 0.0047  last_data_time: 0.0031   lr: 0.00074835  max_mem: 6061M
# [11/30 15:10:51 d2.utils.events]:  eta: 6:14:45  iter: 319  total_loss: 1.684  loss_cls: 0.5136  loss_box_reg: 0.4544  loss_mask: 0.4265  loss_rpn_cls: 0.1341  loss_rpn_loc: 0.185    time: 3.2230  last_time: 4.7962  data_time: 0.0045  last_data_time: 0.0037   lr: 0.00074812  max_mem: 6061M
# [11/30 15:11:45 d2.utils.events]:  eta: 6:10:35  iter: 339  total_loss: 1.727  loss_cls: 0.4966  loss_box_reg: 0.4074  loss_mask: 0.4302  loss_rpn_cls: 0.1317  loss_rpn_loc: 0.1958    time: 3.1932  last_time: 4.4366  data_time: 0.0050  last_data_time: 0.0071   lr: 0.00074788  max_mem: 6061M
# [11/30 15:12:39 d2.utils.events]:  eta: 6:09:06  iter: 359  total_loss: 1.709  loss_cls: 0.5327  loss_box_reg: 0.4361  loss_mask: 0.4226  loss_rpn_cls: 0.1153  loss_rpn_loc: 0.1768    time: 3.1637  last_time: 0.8436  data_time: 0.0045  last_data_time: 0.0040   lr: 0.00074762  max_mem: 6061M
# [11/30 15:13:21 d2.utils.events]:  eta: 6:06:19  iter: 379  total_loss: 1.779  loss_cls: 0.5365  loss_box_reg: 0.4266  loss_mask: 0.4232  loss_rpn_cls: 0.1392  loss_rpn_loc: 0.1731    time: 3.1076  last_time: 0.8359  data_time: 0.0042  last_data_time: 0.0066   lr: 0.00074734  max_mem: 6061M
# [11/30 15:14:01 d2.utils.events]:  eta: 6:00:17  iter: 399  total_loss: 1.804  loss_cls: 0.5607  loss_box_reg: 0.4651  loss_mask: 0.4349  loss_rpn_cls: 0.1329  loss_rpn_loc: 0.2254    time: 3.0533  last_time: 4.2878  data_time: 0.0044  last_data_time: 0.0063   lr: 0.00074706  max_mem: 6061M
# [11/30 15:15:07 d2.utils.events]:  eta: 6:00:19  iter: 419  total_loss: 1.63  loss_cls: 0.5121  loss_box_reg: 0.4267  loss_mask: 0.4138  loss_rpn_cls: 0.1197  loss_rpn_loc: 0.1839    time: 3.0641  last_time: 0.8297  data_time: 0.0045  last_data_time: 0.0059   lr: 0.00074676  max_mem: 6061M
# [11/30 15:16:22 d2.utils.events]:  eta: 6:03:17  iter: 439  total_loss: 1.654  loss_cls: 0.5027  loss_box_reg: 0.4622  loss_mask: 0.4  loss_rpn_cls: 0.1155  loss_rpn_loc: 0.13    time: 3.0955  last_time: 0.7930  data_time: 0.0044  last_data_time: 0.0050   lr: 0.00074644  max_mem: 6061M
# [11/30 15:17:26 d2.utils.events]:  eta: 6:03:17  iter: 459  total_loss: 1.854  loss_cls: 0.5409  loss_box_reg: 0.4954  loss_mask: 0.4212  loss_rpn_cls: 0.1214  loss_rpn_loc: 0.2434    time: 3.1004  last_time: 0.8655  data_time: 0.0050  last_data_time: 0.0058   lr: 0.00074611  max_mem: 6068M
# [11/30 15:18:18 d2.utils.events]:  eta: 6:03:15  iter: 479  total_loss: 1.744  loss_cls: 0.5047  loss_box_reg: 0.4841  loss_mask: 0.3996  loss_rpn_cls: 0.1132  loss_rpn_loc: 0.2084    time: 3.0792  last_time: 4.0706  data_time: 0.0048  last_data_time: 0.0058   lr: 0.00074576  max_mem: 6068M
# [11/30 15:19:42 d2.utils.events]:  eta: 6:05:40  iter: 499  total_loss: 1.775  loss_cls: 0.541  loss_box_reg: 0.5143  loss_mask: 0.3938  loss_rpn_cls: 0.1086  loss_rpn_loc: 0.2059    time: 3.1247  last_time: 7.9002  data_time: 0.0046  last_data_time: 0.0064   lr: 0.0007454  max_mem: 6068M
# Iteration 500/10000 - Loss: (1.5281995013356209, 500)
# [11/30 15:20:46 d2.utils.events]:  eta: 6:05:29  iter: 519  total_loss: 1.664  loss_cls: 0.5162  loss_box_reg: 0.4423  loss_mask: 0.4131  loss_rpn_cls: 0.1107  loss_rpn_loc: 0.2291    time: 3.1272  last_time: 4.1834  data_time: 0.0040  last_data_time: 0.0037   lr: 0.00074503  max_mem: 6068M
# [11/30 15:21:49 d2.utils.events]:  eta: 6:06:14  iter: 539  total_loss: 1.909  loss_cls: 0.545  loss_box_reg: 0.5035  loss_mask: 0.4141  loss_rpn_cls: 0.1121  loss_rpn_loc: 0.2469    time: 3.1279  last_time: 0.8495  data_time: 0.0041  last_data_time: 0.0059   lr: 0.00074464  max_mem: 6068M
# [11/30 15:22:54 d2.utils.events]:  eta: 6:06:12  iter: 559  total_loss: 1.744  loss_cls: 0.4973  loss_box_reg: 0.4551  loss_mask: 0.4124  loss_rpn_cls: 0.09427  loss_rpn_loc: 0.2025    time: 3.1321  last_time: 4.8957  data_time: 0.0041  last_data_time: 0.0049   lr: 0.00074423  max_mem: 6068M
# [11/30 15:23:55 d2.utils.events]:  eta: 6:05:46  iter: 579  total_loss: 1.809  loss_cls: 0.565  loss_box_reg: 0.4937  loss_mask: 0.4113  loss_rpn_cls: 0.1315  loss_rpn_loc: 0.2    time: 3.1294  last_time: 0.9991  data_time: 0.0039  last_data_time: 0.0049   lr: 0.00074381  max_mem: 6068M
# [11/30 15:24:57 d2.utils.events]:  eta: 6:05:23  iter: 599  total_loss: 1.81  loss_cls: 0.5541  loss_box_reg: 0.485  loss_mask: 0.3967  loss_rpn_cls: 0.09715  loss_rpn_loc: 0.2058    time: 3.1284  last_time: 0.9603  data_time: 0.0040  last_data_time: 0.0031   lr: 0.00074338  max_mem: 6068M
# [11/30 15:25:59 d2.utils.events]:  eta: 6:04:47  iter: 619  total_loss: 1.616  loss_cls: 0.4854  loss_box_reg: 0.4739  loss_mask: 0.3952  loss_rpn_cls: 0.1044  loss_rpn_loc: 0.1892    time: 3.1274  last_time: 6.5856  data_time: 0.0046  last_data_time: 0.0050   lr: 0.00074293  max_mem: 6068M
# [11/30 15:27:02 d2.utils.events]:  eta: 6:04:07  iter: 639  total_loss: 1.657  loss_cls: 0.5113  loss_box_reg: 0.5053  loss_mask: 0.3983  loss_rpn_cls: 0.09925  loss_rpn_loc: 0.1424    time: 3.1284  last_time: 2.4649  data_time: 0.0042  last_data_time: 0.0053   lr: 0.00074247  max_mem: 6068M
# [11/30 15:28:10 d2.utils.events]:  eta: 6:05:53  iter: 659  total_loss: 1.755  loss_cls: 0.5294  loss_box_reg: 0.5131  loss_mask: 0.3998  loss_rpn_cls: 0.1068  loss_rpn_loc: 0.1892    time: 3.1359  last_time: 4.8080  data_time: 0.0043  last_data_time: 0.0068   lr: 0.00074199  max_mem: 6068M
# [11/30 15:29:15 d2.utils.events]:  eta: 6:06:14  iter: 679  total_loss: 1.56  loss_cls: 0.4844  loss_box_reg: 0.4543  loss_mask: 0.3867  loss_rpn_cls: 0.09015  loss_rpn_loc: 0.1124    time: 3.1404  last_time: 0.8679  data_time: 0.0041  last_data_time: 0.0068   lr: 0.0007415  max_mem: 6068M
# [11/30 15:30:25 d2.utils.events]:  eta: 6:05:59  iter: 699  total_loss: 1.762  loss_cls: 0.4993  loss_box_reg: 0.4781  loss_mask: 0.3949  loss_rpn_cls: 0.1075  loss_rpn_loc: 0.1762    time: 3.1501  last_time: 4.8223  data_time: 0.0043  last_data_time: 0.0059   lr: 0.00074099  max_mem: 6068M
# [11/30 15:31:46 d2.utils.events]:  eta: 6:08:05  iter: 719  total_loss: 1.69  loss_cls: 0.4961  loss_box_reg: 0.4902  loss_mask: 0.3911  loss_rpn_cls: 0.1069  loss_rpn_loc: 0.1838    time: 3.1755  last_time: 6.5461  data_time: 0.0043  last_data_time: 0.0032   lr: 0.00074047  max_mem: 6068M
# [11/30 15:32:46 d2.utils.events]:  eta: 6:09:56  iter: 739  total_loss: 1.72  loss_cls: 0.4899  loss_box_reg: 0.4825  loss_mask: 0.3942  loss_rpn_cls: 0.102  loss_rpn_loc: 0.2305    time: 3.1705  last_time: 2.4378  data_time: 0.0040  last_data_time: 0.0021   lr: 0.00073994  max_mem: 6068M
# [11/30 15:33:50 d2.utils.events]:  eta: 6:09:08  iter: 759  total_loss: 1.672  loss_cls: 0.4916  loss_box_reg: 0.472  loss_mask: 0.3834  loss_rpn_cls: 0.1007  loss_rpn_loc: 0.1685    time: 3.1709  last_time: 2.3649  data_time: 0.0041  last_data_time: 0.0023   lr: 0.00073939  max_mem: 6068M
# [11/30 15:35:04 d2.utils.events]:  eta: 6:08:59  iter: 779  total_loss: 1.558  loss_cls: 0.4693  loss_box_reg: 0.4905  loss_mask: 0.3954  loss_rpn_cls: 0.1107  loss_rpn_loc: 0.1771    time: 3.1851  last_time: 7.3799  data_time: 0.0040  last_data_time: 0.0022   lr: 0.00073883  max_mem: 6068M
# [11/30 15:36:16 d2.utils.events]:  eta: 6:08:43  iter: 799  total_loss: 1.811  loss_cls: 0.5174  loss_box_reg: 0.5476  loss_mask: 0.3715  loss_rpn_cls: 0.0923  loss_rpn_loc: 0.2067    time: 3.1945  last_time: 0.9851  data_time: 0.0046  last_data_time: 0.0032   lr: 0.00073825  max_mem: 6068M
# [11/30 15:37:25 d2.utils.events]:  eta: 6:10:41  iter: 819  total_loss: 1.654  loss_cls: 0.4985  loss_box_reg: 0.4728  loss_mask: 0.3844  loss_rpn_cls: 0.1167  loss_rpn_loc: 0.2173    time: 3.2012  last_time: 0.8617  data_time: 0.0042  last_data_time: 0.0048   lr: 0.00073766  max_mem: 6068M
# [11/30 15:38:22 d2.utils.events]:  eta: 6:10:06  iter: 839  total_loss: 1.685  loss_cls: 0.5384  loss_box_reg: 0.4774  loss_mask: 0.3856  loss_rpn_cls: 0.08281  loss_rpn_loc: 0.1171    time: 3.1922  last_time: 8.0184  data_time: 0.0043  last_data_time: 0.0055   lr: 0.00073705  max_mem: 6068M
# [11/30 15:39:12 d2.utils.events]:  eta: 6:09:22  iter: 859  total_loss: 1.702  loss_cls: 0.5335  loss_box_reg: 0.5279  loss_mask: 0.3892  loss_rpn_cls: 0.09691  loss_rpn_loc: 0.1762    time: 3.1771  last_time: 0.9085  data_time: 0.0042  last_data_time: 0.0043   lr: 0.00073643  max_mem: 6068M
# [11/30 15:40:07 d2.utils.events]:  eta: 6:08:54  iter: 879  total_loss: 1.548  loss_cls: 0.4705  loss_box_reg: 0.4818  loss_mask: 0.3796  loss_rpn_cls: 0.09449  loss_rpn_loc: 0.1479    time: 3.1672  last_time: 0.8774  data_time: 0.0045  last_data_time: 0.0059   lr: 0.00073579  max_mem: 6068M
# [11/30 15:41:16 d2.utils.events]:  eta: 6:09:34  iter: 899  total_loss: 1.682  loss_cls: 0.4784  loss_box_reg: 0.4846  loss_mask: 0.3631  loss_rpn_cls: 0.0895  loss_rpn_loc: 0.1922    time: 3.1731  last_time: 0.8141  data_time: 0.0046  last_data_time: 0.0034   lr: 0.00073514  max_mem: 6068M
# [11/30 15:42:12 d2.utils.events]:  eta: 6:08:46  iter: 919  total_loss: 1.741  loss_cls: 0.5063  loss_box_reg: 0.5175  loss_mask: 0.387  loss_rpn_cls: 0.09196  loss_rpn_loc: 0.2271    time: 3.1654  last_time: 0.8292  data_time: 0.0049  last_data_time: 0.0024   lr: 0.00073448  max_mem: 6068M
# [11/30 15:43:28 d2.utils.events]:  eta: 6:09:58  iter: 939  total_loss: 1.651  loss_cls: 0.5141  loss_box_reg: 0.5079  loss_mask: 0.3738  loss_rpn_cls: 0.08891  loss_rpn_loc: 0.1595    time: 3.1787  last_time: 2.5565  data_time: 0.0048  last_data_time: 0.0027   lr: 0.0007338  max_mem: 6068M
# [11/30 15:44:27 d2.utils.events]:  eta: 6:09:09  iter: 959  total_loss: 1.826  loss_cls: 0.5285  loss_box_reg: 0.5179  loss_mask: 0.3866  loss_rpn_cls: 0.11  loss_rpn_loc: 0.2006    time: 3.1736  last_time: 2.5462  data_time: 0.0045  last_data_time: 0.0037   lr: 0.00073311  max_mem: 6068M
# [11/30 15:45:44 d2.utils.events]:  eta: 6:09:04  iter: 979  total_loss: 1.604  loss_cls: 0.4713  loss_box_reg: 0.4578  loss_mask: 0.371  loss_rpn_cls: 0.09103  loss_rpn_loc: 0.2136    time: 3.1880  last_time: 2.6558  data_time: 0.0044  last_data_time: 0.0037   lr: 0.0007324  max_mem: 6068M
# [11/30 15:46:52 d2.utils.events]:  eta: 6:08:30  iter: 999  total_loss: 1.67  loss_cls: 0.5043  loss_box_reg: 0.4854  loss_mask: 0.3766  loss_rpn_cls: 0.09468  loss_rpn_loc: 0.1429    time: 3.1920  last_time: 2.7148  data_time: 0.0044  last_data_time: 0.0020   lr: 0.00073168  max_mem: 6073M
# Iteration 1000/10000 - Loss: (1.6484980881214142, 1000)
# [11/30 15:47:55 d2.utils.events]:  eta: 6:08:03  iter: 1019  total_loss: 1.613  loss_cls: 0.5035  loss_box_reg: 0.4754  loss_mask: 0.3699  loss_rpn_cls: 0.08785  loss_rpn_loc: 0.1816    time: 3.1915  last_time: 6.8565  data_time: 0.0042  last_data_time: 0.0018   lr: 0.00073095  max_mem: 6073M
# [11/30 15:49:07 d2.utils.events]:  eta: 6:07:14  iter: 1039  total_loss: 1.704  loss_cls: 0.5217  loss_box_reg: 0.5166  loss_mask: 0.3841  loss_rpn_cls: 0.09813  loss_rpn_loc: 0.1953    time: 3.1987  last_time: 6.6226  data_time: 0.0046  last_data_time: 0.0031   lr: 0.0007302  max_mem: 6073M
# [11/30 15:50:07 d2.utils.events]:  eta: 6:07:04  iter: 1059  total_loss: 1.526  loss_cls: 0.4402  loss_box_reg: 0.4491  loss_mask: 0.3743  loss_rpn_cls: 0.08364  loss_rpn_loc: 0.1521    time: 3.1952  last_time: 0.8219  data_time: 0.0043  last_data_time: 0.0020   lr: 0.00072944  max_mem: 6073M
# [11/30 15:51:13 d2.utils.events]:  eta: 6:06:52  iter: 1079  total_loss: 1.539  loss_cls: 0.4729  loss_box_reg: 0.4597  loss_mask: 0.3733  loss_rpn_cls: 0.09009  loss_rpn_loc: 0.1332    time: 3.1975  last_time: 6.6430  data_time: 0.0045  last_data_time: 0.0062   lr: 0.00072866  max_mem: 6073M
# [11/30 15:52:25 d2.utils.events]:  eta: 6:06:18  iter: 1099  total_loss: 1.597  loss_cls: 0.4928  loss_box_reg: 0.4944  loss_mask: 0.3791  loss_rpn_cls: 0.09068  loss_rpn_loc: 0.1572    time: 3.2041  last_time: 5.1963  data_time: 0.0043  last_data_time: 0.0052   lr: 0.00072787  max_mem: 6073M
# [11/30 15:53:36 d2.utils.events]:  eta: 6:06:23  iter: 1119  total_loss: 1.652  loss_cls: 0.4984  loss_box_reg: 0.5146  loss_mask: 0.3784  loss_rpn_cls: 0.09936  loss_rpn_loc: 0.1842    time: 3.2101  last_time: 2.5020  data_time: 0.0048  last_data_time: 0.0025   lr: 0.00072707  max_mem: 6073M
# [11/30 15:54:22 d2.utils.events]:  eta: 6:05:33  iter: 1139  total_loss: 1.669  loss_cls: 0.4761  loss_box_reg: 0.4776  loss_mask: 0.3656  loss_rpn_cls: 0.09463  loss_rpn_loc: 0.1702    time: 3.1949  last_time: 0.8742  data_time: 0.0044  last_data_time: 0.0026   lr: 0.00072625  max_mem: 6073M
# [11/30 15:55:35 d2.utils.events]:  eta: 6:06:34  iter: 1159  total_loss: 1.638  loss_cls: 0.4663  loss_box_reg: 0.5198  loss_mask: 0.3587  loss_rpn_cls: 0.09132  loss_rpn_loc: 0.2381    time: 3.2022  last_time: 0.8377  data_time: 0.0042  last_data_time: 0.0025   lr: 0.00072542  max_mem: 6073M
# [11/30 15:56:41 d2.utils.events]:  eta: 6:06:54  iter: 1179  total_loss: 1.525  loss_cls: 0.4623  loss_box_reg: 0.4846  loss_mask: 0.3611  loss_rpn_cls: 0.08382  loss_rpn_loc: 0.1235    time: 3.2037  last_time: 0.7934  data_time: 0.0043  last_data_time: 0.0029   lr: 0.00072457  max_mem: 6073M
# [11/30 15:57:52 d2.utils.events]:  eta: 6:07:01  iter: 1199  total_loss: 1.815  loss_cls: 0.5403  loss_box_reg: 0.5459  loss_mask: 0.3991  loss_rpn_cls: 0.09102  loss_rpn_loc: 0.2569    time: 3.2096  last_time: 2.6113  data_time: 0.0048  last_data_time: 0.0021   lr: 0.00072371  max_mem: 6073M
# [11/30 15:58:59 d2.utils.events]:  eta: 6:07:10  iter: 1219  total_loss: 1.65  loss_cls: 0.4733  loss_box_reg: 0.5127  loss_mask: 0.3673  loss_rpn_cls: 0.08636  loss_rpn_loc: 0.1819    time: 3.2124  last_time: 0.8722  data_time: 0.0046  last_data_time: 0.0030   lr: 0.00072284  max_mem: 6073M
# [11/30 15:59:45 d2.utils.events]:  eta: 6:05:26  iter: 1239  total_loss: 1.476  loss_cls: 0.4421  loss_box_reg: 0.4687  loss_mask: 0.3542  loss_rpn_cls: 0.08928  loss_rpn_loc: 0.129    time: 3.1971  last_time: 0.8733  data_time: 0.0054  last_data_time: 0.0026   lr: 0.00072195  max_mem: 6073M
# [11/30 16:00:49 d2.utils.events]:  eta: 6:05:12  iter: 1259  total_loss: 1.617  loss_cls: 0.4948  loss_box_reg: 0.5311  loss_mask: 0.3606  loss_rpn_cls: 0.07383  loss_rpn_loc: 0.1131    time: 3.1974  last_time: 2.6050  data_time: 0.0053  last_data_time: 0.0071   lr: 0.00072105  max_mem: 6073M
# [11/30 16:02:10 d2.utils.events]:  eta: 6:06:18  iter: 1279  total_loss: 1.648  loss_cls: 0.4502  loss_box_reg: 0.4607  loss_mask: 0.362  loss_rpn_cls: 0.08569  loss_rpn_loc: 0.2312    time: 3.2109  last_time: 6.8030  data_time: 0.0056  last_data_time: 0.0071   lr: 0.00072013  max_mem: 6073M
# [11/30 16:03:14 d2.utils.events]:  eta: 6:05:47  iter: 1299  total_loss: 1.57  loss_cls: 0.4473  loss_box_reg: 0.4951  loss_mask: 0.3799  loss_rpn_cls: 0.0788  loss_rpn_loc: 0.1882    time: 3.2108  last_time: 0.8807  data_time: 0.0052  last_data_time: 0.0031   lr: 0.0007192  max_mem: 6073M
# [11/30 16:04:23 d2.utils.events]:  eta: 6:06:36  iter: 1319  total_loss: 1.399  loss_cls: 0.3973  loss_box_reg: 0.445  loss_mask: 0.3563  loss_rpn_cls: 0.07658  loss_rpn_loc: 0.1126    time: 3.2140  last_time: 4.9404  data_time: 0.0051  last_data_time: 0.0018   lr: 0.00071826  max_mem: 6073M
# [11/30 16:05:12 d2.utils.events]:  eta: 6:05:45  iter: 1339  total_loss: 1.606  loss_cls: 0.4676  loss_box_reg: 0.5216  loss_mask: 0.3626  loss_rpn_cls: 0.08547  loss_rpn_loc: 0.1863    time: 3.2025  last_time: 0.8709  data_time: 0.0047  last_data_time: 0.0055   lr: 0.00071731  max_mem: 6073M
# [11/30 16:06:12 d2.utils.events]:  eta: 6:05:51  iter: 1359  total_loss: 1.601  loss_cls: 0.479  loss_box_reg: 0.4992  loss_mask: 0.3703  loss_rpn_cls: 0.08351  loss_rpn_loc: 0.1675    time: 3.1995  last_time: 0.8501  data_time: 0.0052  last_data_time: 0.0044   lr: 0.00071634  max_mem: 6073M
# [11/30 16:07:10 d2.utils.events]:  eta: 6:06:51  iter: 1379  total_loss: 1.666  loss_cls: 0.4938  loss_box_reg: 0.5086  loss_mask: 0.3573  loss_rpn_cls: 0.07267  loss_rpn_loc: 0.1985    time: 3.1956  last_time: 2.5734  data_time: 0.0050  last_data_time: 0.0036   lr: 0.00071536  max_mem: 6073M
# ...
# [12/01 01:02:04 d2.utils.events]:  eta: 0:44:06  iter: 9399  total_loss: 1.082  loss_cls: 0.2194  loss_box_reg: 0.3974  loss_mask: 0.2704  loss_rpn_cls: 0.01622  loss_rpn_loc: 0.1374    time: 3.8742  last_time: 6.9206  data_time: 0.0052  last_data_time: 0.0023   lr: 6.6644e-06  max_mem: 6199M
# [12/01 01:03:31 d2.utils.events]:  eta: 0:42:40  iter: 9419  total_loss: 0.9926  loss_cls: 0.1974  loss_box_reg: 0.3858  loss_mask: 0.2666  loss_rpn_cls: 0.02093  loss_rpn_loc: 0.09764    time: 3.8752  last_time: 6.8377  data_time: 0.0040  last_data_time: 0.0030   lr: 6.2294e-06  max_mem: 6199M
# [12/01 01:04:49 d2.utils.events]:  eta: 0:41:08  iter: 9439  total_loss: 0.9813  loss_cls: 0.2206  loss_box_reg: 0.3911  loss_mask: 0.2715  loss_rpn_cls: 0.02338  loss_rpn_loc: 0.09928    time: 3.8753  last_time: 0.8482  data_time: 0.0039  last_data_time: 0.0035   lr: 5.809e-06  max_mem: 6199M
# [12/01 01:05:55 d2.utils.events]:  eta: 0:39:42  iter: 9459  total_loss: 1.065  loss_cls: 0.212  loss_box_reg: 0.4102  loss_mask: 0.274  loss_rpn_cls: 0.01826  loss_rpn_loc: 0.1652    time: 3.8741  last_time: 0.9024  data_time: 0.0042  last_data_time: 0.0024   lr: 5.4032e-06  max_mem: 6199M
# [12/01 01:07:27 d2.utils.events]:  eta: 0:38:14  iter: 9479  total_loss: 1.067  loss_cls: 0.2229  loss_box_reg: 0.4159  loss_mask: 0.2682  loss_rpn_cls: 0.02069  loss_rpn_loc: 0.12    time: 3.8756  last_time: 0.8776  data_time: 0.0045  last_data_time: 0.0022   lr: 5.0119e-06  max_mem: 6199M
# [12/01 01:08:55 d2.utils.events]:  eta: 0:36:54  iter: 9499  total_loss: 1.067  loss_cls: 0.2284  loss_box_reg: 0.3853  loss_mask: 0.2729  loss_rpn_cls: 0.02214  loss_rpn_loc: 0.1238    time: 3.8767  last_time: 4.5702  data_time: 0.0041  last_data_time: 0.0047   lr: 4.6353e-06  max_mem: 6199M
# Iteration 9500/10000 - Loss: (1.2786047123372555, 9500)
# [12/01 01:10:29 d2.utils.events]:  eta: 0:35:35  iter: 9519  total_loss: 1.168  loss_cls: 0.2619  loss_box_reg: 0.4021  loss_mask: 0.279  loss_rpn_cls: 0.01939  loss_rpn_loc: 0.1268    time: 3.8784  last_time: 4.8792  data_time: 0.0044  last_data_time: 0.0072   lr: 4.2733e-06  max_mem: 6199M
# [12/01 01:11:55 d2.utils.events]:  eta: 0:34:01  iter: 9539  total_loss: 1.025  loss_cls: 0.212  loss_box_reg: 0.4264  loss_mask: 0.2643  loss_rpn_cls: 0.02154  loss_rpn_loc: 0.09544    time: 3.8793  last_time: 0.9023  data_time: 0.0044  last_data_time: 0.0065   lr: 3.9259e-06  max_mem: 6199M
# [12/01 01:13:27 d2.utils.events]:  eta: 0:32:32  iter: 9559  total_loss: 1.005  loss_cls: 0.2162  loss_box_reg: 0.394  loss_mask: 0.2615  loss_rpn_cls: 0.02321  loss_rpn_loc: 0.0694    time: 3.8808  last_time: 0.8706  data_time: 0.0043  last_data_time: 0.0027   lr: 3.5932e-06  max_mem: 6199M
# [12/01 01:14:47 d2.utils.events]:  eta: 0:30:56  iter: 9579  total_loss: 0.9869  loss_cls: 0.2162  loss_box_reg: 0.395  loss_mask: 0.2648  loss_rpn_cls: 0.02035  loss_rpn_loc: 0.09418    time: 3.8811  last_time: 0.8614  data_time: 0.0042  last_data_time: 0.0030   lr: 3.2752e-06  max_mem: 6199M
# [12/01 01:15:48 d2.utils.events]:  eta: 0:29:23  iter: 9599  total_loss: 1.003  loss_cls: 0.2154  loss_box_reg: 0.3604  loss_mask: 0.2512  loss_rpn_cls: 0.01857  loss_rpn_loc: 0.1064    time: 3.8793  last_time: 4.5426  data_time: 0.0050  last_data_time: 0.0025   lr: 2.9718e-06  max_mem: 6199M
# [12/01 01:17:12 d2.utils.events]:  eta: 0:27:56  iter: 9619  total_loss: 1.069  loss_cls: 0.2273  loss_box_reg: 0.4077  loss_mask: 0.2801  loss_rpn_cls: 0.01864  loss_rpn_loc: 0.1118    time: 3.8799  last_time: 0.8779  data_time: 0.0049  last_data_time: 0.0031   lr: 2.6831e-06  max_mem: 6199M
# [12/01 01:18:37 d2.utils.events]:  eta: 0:26:29  iter: 9639  total_loss: 1.138  loss_cls: 0.2416  loss_box_reg: 0.399  loss_mask: 0.2755  loss_rpn_cls: 0.02334  loss_rpn_loc: 0.1429    time: 3.8808  last_time: 0.8901  data_time: 0.0053  last_data_time: 0.0018   lr: 2.4091e-06  max_mem: 6199M
# [12/01 01:20:20 d2.utils.events]:  eta: 0:25:04  iter: 9659  total_loss: 0.9992  loss_cls: 0.2303  loss_box_reg: 0.4105  loss_mask: 0.2648  loss_rpn_cls: 0.01807  loss_rpn_loc: 0.1078    time: 3.8834  last_time: 1.0177  data_time: 0.0048  last_data_time: 0.0025   lr: 2.1498e-06  max_mem: 6199M
# [12/01 01:21:56 d2.utils.events]:  eta: 0:23:43  iter: 9679  total_loss: 1.055  loss_cls: 0.2013  loss_box_reg: 0.4092  loss_mask: 0.2604  loss_rpn_cls: 0.0195  loss_rpn_loc: 0.1083    time: 3.8853  last_time: 4.7011  data_time: 0.0047  last_data_time: 0.0045   lr: 1.9052e-06  max_mem: 6199M
# [12/01 01:23:40 d2.utils.events]:  eta: 0:22:16  iter: 9699  total_loss: 1.019  loss_cls: 0.2143  loss_box_reg: 0.3894  loss_mask: 0.2635  loss_rpn_cls: 0.02162  loss_rpn_loc: 0.09702    time: 3.8879  last_time: 7.0496  data_time: 0.0051  last_data_time: 0.0070   lr: 1.6754e-06  max_mem: 6199M
# [12/01 01:24:55 d2.utils.events]:  eta: 0:20:48  iter: 9719  total_loss: 1.077  loss_cls: 0.2306  loss_box_reg: 0.3871  loss_mask: 0.2849  loss_rpn_cls: 0.02079  loss_rpn_loc: 0.1161    time: 3.8877  last_time: 4.3545  data_time: 0.0051  last_data_time: 0.0085   lr: 1.4603e-06  max_mem: 6199M
# [12/01 01:26:06 d2.utils.events]:  eta: 0:19:19  iter: 9739  total_loss: 0.8889  loss_cls: 0.1957  loss_box_reg: 0.348  loss_mask: 0.2482  loss_rpn_cls: 0.01916  loss_rpn_loc: 0.09345    time: 3.8870  last_time: 6.6573  data_time: 0.0044  last_data_time: 0.0054   lr: 1.2599e-06  max_mem: 6199M
# [12/01 01:27:26 d2.utils.events]:  eta: 0:17:50  iter: 9759  total_loss: 1.063  loss_cls: 0.2409  loss_box_reg: 0.3984  loss_mask: 0.2733  loss_rpn_cls: 0.02474  loss_rpn_loc: 0.144    time: 3.8872  last_time: 0.9244  data_time: 0.0043  last_data_time: 0.0060   lr: 1.0743e-06  max_mem: 6199M
# [12/01 01:29:04 d2.utils.events]:  eta: 0:16:21  iter: 9779  total_loss: 0.9899  loss_cls: 0.213  loss_box_reg: 0.3979  loss_mask: 0.26  loss_rpn_cls: 0.01977  loss_rpn_loc: 0.09115    time: 3.8893  last_time: 0.8959  data_time: 0.0050  last_data_time: 0.0071   lr: 9.0346e-07  max_mem: 6199M
# [12/01 01:30:24 d2.utils.events]:  eta: 0:14:52  iter: 9799  total_loss: 0.9803  loss_cls: 0.1892  loss_box_reg: 0.3732  loss_mask: 0.2592  loss_rpn_cls: 0.02398  loss_rpn_loc: 0.1192    time: 3.8895  last_time: 0.9311  data_time: 0.0049  last_data_time: 0.0064   lr: 7.4739e-07  max_mem: 6199M
# [12/01 01:32:11 d2.utils.events]:  eta: 0:13:25  iter: 9819  total_loss: 0.9992  loss_cls: 0.2208  loss_box_reg: 0.3968  loss_mask: 0.2609  loss_rpn_cls: 0.02411  loss_rpn_loc: 0.08686    time: 3.8925  last_time: 7.2861  data_time: 0.0052  last_data_time: 0.0085   lr: 6.061e-07  max_mem: 6199M
# [12/01 01:33:55 d2.utils.events]:  eta: 0:11:57  iter: 9839  total_loss: 1.169  loss_cls: 0.2422  loss_box_reg: 0.4454  loss_mask: 0.2787  loss_rpn_cls: 0.02047  loss_rpn_loc: 0.13    time: 3.8952  last_time: 7.1024  data_time: 0.0046  last_data_time: 0.0022   lr: 4.7958e-07  max_mem: 6199M
# [12/01 01:35:12 d2.utils.events]:  eta: 0:10:28  iter: 9859  total_loss: 0.9717  loss_cls: 0.2056  loss_box_reg: 0.398  loss_mask: 0.2664  loss_rpn_cls: 0.01852  loss_rpn_loc: 0.08541    time: 3.8950  last_time: 7.3885  data_time: 0.0046  last_data_time: 0.0033   lr: 3.6785e-07  max_mem: 6199M
# [12/01 01:36:31 d2.utils.events]:  eta: 0:08:58  iter: 9879  total_loss: 0.9446  loss_cls: 0.1909  loss_box_reg: 0.3778  loss_mask: 0.273  loss_rpn_cls: 0.02061  loss_rpn_loc: 0.07526    time: 3.8952  last_time: 0.8378  data_time: 0.0049  last_data_time: 0.0032   lr: 2.7091e-07  max_mem: 6199M
# [12/01 01:37:48 d2.utils.events]:  eta: 0:07:28  iter: 9899  total_loss: 1.083  loss_cls: 0.2002  loss_box_reg: 0.3843  loss_mask: 0.2758  loss_rpn_cls: 0.02087  loss_rpn_loc: 0.1304    time: 3.8950  last_time: 0.9318  data_time: 0.0049  last_data_time: 0.0031   lr: 1.8876e-07  max_mem: 6199M
# [12/01 01:39:29 d2.utils.events]:  eta: 0:05:58  iter: 9919  total_loss: 0.9953  loss_cls: 0.218  loss_box_reg: 0.3897  loss_mask: 0.2602  loss_rpn_cls: 0.01906  loss_rpn_loc: 0.1193    time: 3.8974  last_time: 7.0710  data_time: 0.0047  last_data_time: 0.0027   lr: 1.2141e-07  max_mem: 6199M
# [12/01 01:40:44 d2.utils.events]:  eta: 0:04:29  iter: 9939  total_loss: 1.033  loss_cls: 0.2169  loss_box_reg: 0.3946  loss_mask: 0.2744  loss_rpn_cls: 0.02216  loss_rpn_loc: 0.1258    time: 3.8971  last_time: 0.8489  data_time: 0.0051  last_data_time: 0.0047   lr: 6.8857e-08  max_mem: 6199M
# [12/01 01:42:18 d2.utils.events]:  eta: 0:02:59  iter: 9959  total_loss: 1.142  loss_cls: 0.2465  loss_box_reg: 0.4299  loss_mask: 0.2783  loss_rpn_cls: 0.02042  loss_rpn_loc: 0.1404    time: 3.8987  last_time: 9.0778  data_time: 0.0050  last_data_time: 0.0024   lr: 3.1107e-08  max_mem: 6199M
# [12/01 01:43:58 d2.utils.events]:  eta: 0:01:29  iter: 9979  total_loss: 1.044  loss_cls: 0.2433  loss_box_reg: 0.4108  loss_mask: 0.2752  loss_rpn_cls: 0.02486  loss_rpn_loc: 0.1059    time: 3.9010  last_time: 6.7018  data_time: 0.0047  last_data_time: 0.0025   lr: 8.1609e-09  max_mem: 6199M
# [12/01 01:45:14 d2.utils.events]:  eta: 0:00:00  iter: 9999  total_loss: 1.076  loss_cls: 0.2339  loss_box_reg: 0.4176  loss_mask: 0.274  loss_rpn_cls: 0.02519  loss_rpn_loc: 0.1303    time: 3.9006  last_time: 0.9001  data_time: 0.0045  last_data_time: 0.0025   lr: 1.8506e-11  max_mem: 6199M
# [12/01 01:45:14 d2.engine.hooks]: Overall training speed: 9998 iterations in 10:49:58 (3.9006 s / it)
# [12/01 01:45:14 d2.engine.hooks]: Total training time: 10:51:31 (0:01:33 on hooks)
# [12/01 01:45:14 d2.data.datasets.coco]: Loaded 163 images in COCO format from C:/Users/kurt_/car-parts-and-damage-detection-v18/car-damage-detection/working/data/val\annotations.json
# [12/01 01:45:14 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [12/01 01:45:14 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [12/01 01:45:14 d2.data.common]: Serializing 163 elements to byte tensors and concatenating them all ...
# [12/01 01:45:14 d2.data.common]: Serialized dataset takes 0.62 MiB
# WARNING [12/01 01:45:14 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# [12/01 01:45:14 d2.evaluation.evaluator]: Start inference on 163 batches
# [12/01 01:45:20 d2.evaluation.evaluator]: Inference done 11/163. Dataloading: 0.0004 s/iter. Inference: 0.0868 s/iter. Eval: 0.0026 s/iter. Total: 0.0899 s/iter. ETA=0:00:13
# [12/01 01:45:25 d2.evaluation.evaluator]: Inference done 68/163. Dataloading: 0.0007 s/iter. Inference: 0.0837 s/iter. Eval: 0.0042 s/iter. Total: 0.0886 s/iter. ETA=0:00:08
# [12/01 01:45:30 d2.evaluation.evaluator]: Inference done 121/163. Dataloading: 0.0007 s/iter. Inference: 0.0868 s/iter. Eval: 0.0042 s/iter. Total: 0.0918 s/iter. ETA=0:00:03
# [12/01 01:45:35 d2.evaluation.evaluator]: Total inference time: 0:00:15.116860 (0.095676 s / iter per device, on 1 devices)
# [12/01 01:45:35 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:13 (0.086299 s / iter per device, on 1 devices)
# [12/01 01:45:35 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [12/01 01:45:35 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [12/01 01:45:35 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [12/01 01:45:35 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.05 seconds.
# [12/01 01:45:35 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [12/01 01:45:35 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.02 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.043
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.089
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.043
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.018
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.041
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.065
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.061
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.086
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.086
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.036
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.078
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.114
# [12/01 01:45:35 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |  AP   |  AP50  |  AP75  |  APs  |  APm  |  APl  |
# |:-----:|:------:|:------:|:-----:|:-----:|:-----:|
# | 4.290 | 8.936  | 4.300  | 1.832 | 4.134 | 6.494 |
# [12/01 01:45:35 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP    | category     | AP     | category    | AP    |
# |:-----------|:------|:-------------|:-------|:------------|:------|
# | Dent       | 2.939 | Scratch      | 1.561  | Broken part | 6.470 |
# | Paint chip | 0.187 | Missing part | 20.667 | Flaking     | 0.000 |
# | Corrosion  | 0.713 | Cracked      | 1.782  |             |       |
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# [12/01 01:45:35 d2.evaluation.fast_eval_api]: Evaluate annotation type *segm*
# [12/01 01:45:35 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.12 seconds.
# [12/01 01:45:35 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [12/01 01:45:35 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.02 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.037
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.076
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.036
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.010
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.040
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.072
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.059
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.079
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.079
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.031
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.072
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.103
# [12/01 01:45:35 d2.evaluation.coco_evaluation]: Evaluation results for segm:
# |  AP   |  AP50  |  AP75  |  APs  |  APm  |  APl  |
# |:-----:|:------:|:------:|:-----:|:-----:|:-----:|
# | 3.744 | 7.624  | 3.649  | 1.005 | 3.984 | 7.153 |
# [12/01 01:45:35 d2.evaluation.coco_evaluation]: Per-category segm AP:
# | category   | AP    | category     | AP     | category    | AP    |
# |:-----------|:------|:-------------|:-------|:------------|:------|
# | Dent       | 2.737 | Scratch      | 0.577  | Broken part | 4.534 |
# | Paint chip | 0.137 | Missing part | 19.856 | Flaking     | 0.000 |
# | Corrosion  | 0.331 | Cracked      | 1.782  |             |       |
# [12/01 01:45:35 d2.engine.defaults]: Evaluation results for car_val in csv format:
# [12/01 01:45:35 d2.evaluation.testing]: copypaste: Task: bbox
# [12/01 01:45:35 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [12/01 01:45:35 d2.evaluation.testing]: copypaste: 4.2898,8.9365,4.2996,1.8324,4.1344,6.4939
# [12/01 01:45:35 d2.evaluation.testing]: copypaste: Task: segm
# [12/01 01:45:35 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [12/01 01:45:35 d2.evaluation.testing]: copypaste: 3.7443,7.6242,3.6492,1.0049,3.9840,7.1530

# %%
import os
import torch
from detectron2.engine import DefaultPredictor  # Import DefaultPredictor

# Set the path to the trained model
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")  # path to the model we just trained
# Set a custom testing threshold
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5

# Create a predictor
predictor = DefaultPredictor(cfg)
# Out:
# [12/01 01:45:54 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from ./output_20241130_145334\model_final.pth ...
# C:\Users\kurt_\anaconda3\envs\my-env-detectron2\lib\site-packages\fvcore\common\checkpoint.py:252: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(f, map_location=torch.device("cpu"))

# %%
import json
import pandas as pd

metrics_path = r"C:\Users\kurt_\car-parts-and-damage-detection-v18\car-damage-detection\output_20241130_145334\metrics.json"
metrics_columns = [
    "data_time",
    "eta_seconds",
    "fast_rcnn/cls_accuracy",
    "fast_rcnn/false_negative",
    "fast_rcnn/fg_cls_accuracy",
    "iteration",
    "loss_box_reg",
    "loss_cls",
    "loss_mask",
    "loss_rpn_cls",
    "loss_rpn_loc",
    "lr",
    "mask_rcnn/accuracy",
    "mask_rcnn/false_negative",
    "mask_rcnn/false_positive",
    "rank_data_time",
    "roi_head/num_bg_samples",
    "roi_head/num_fg_samples",
    "rpn/num_neg_anchors",
    "rpn/num_pos_anchors",
    "time",
    "total_loss"
]


data = []
with open(metrics_path, 'r') as f:
    for line in f:
        json_data = json.loads(line)
        filtered_data = {metric: json_data.get(metric, None) for metric in metrics_columns}
        data.append(filtered_data)

# %%
df = pd.DataFrame(data)
df = df.dropna()
df
# Out:
#      data_time   eta_seconds  fast_rcnn/cls_accuracy  \
# 0     0.004167  23063.054454                0.236816
# 1     0.004469  25408.850424                0.914062
# 2     0.004408  23221.933364                0.921387
# 3     0.004515  23175.209152                0.878906
# 4     0.005427  23983.547445                0.890137
# ..         ...           ...                     ...
# 495   0.003670    358.991448                0.916504
# 496   0.004823    269.112915                0.919922
# 497   0.004859    179.533214                0.910645
# 498   0.004901     89.830538                0.914062
# 499   0.004269      0.000000                0.913574
#
#      fast_rcnn/false_negative  fast_rcnn/fg_cls_accuracy  iteration  \
# 0                    0.292824                   0.027282         19
# 1                    1.000000                   0.000000         39
# 2                    1.000000                   0.000000         59
# 3                    1.000000                   0.000000         79
# 4                    1.000000                   0.000000         99
# ..                        ...                        ...        ...
# 495                  0.218750                   0.765625       9919
# 496                  0.216564                   0.775595       9939
# 497                  0.214844                   0.746094       9959
# 498                  0.224609                   0.734375       9979
# 499                  0.223195                   0.750000       9999
#
#      loss_box_reg  loss_cls  loss_mask  loss_rpn_cls  ...  mask_rcnn/accuracy  \
# 0        0.227512  2.133876   0.692028      2.669325  ...            0.542927
# 1        0.181414  1.139815   0.684947      0.345386  ...            0.638270
# 2        0.153609  0.432503   0.676014      0.253452  ...            0.667980
# 3        0.320478  0.593325   0.657768      0.216786  ...            0.704470
# 4        0.316528  0.540054   0.644737      0.209572  ...            0.708328
# ..            ...       ...        ...           ...  ...                 ...
# 495      0.389703  0.217998   0.260204      0.019057  ...            0.882974
# 496      0.394598  0.216934   0.274400      0.022156  ...            0.875363
# 497      0.429901  0.246515   0.278256      0.020419  ...            0.875188
# 498      0.410772  0.243256   0.275161      0.024864  ...            0.878367
# 499      0.417561  0.233866   0.274038      0.025187  ...            0.876848
#
#      mask_rcnn/false_negative  mask_rcnn/false_positive  rank_data_time  \
# 0                    0.727367                  0.284551        0.004167
# 1                    0.774893                  0.057753        0.004469
# 2                    0.671869                  0.038657        0.004408
# 3                    0.633508                  0.046533        0.004515
# 4                    0.633283                  0.047640        0.005427
# ..                        ...                       ...             ...
# 495                  0.157202                  0.087803        0.003670
# 496                  0.160659                  0.095587        0.004823
# 497                  0.166858                  0.093502        0.004859
# 498                  0.173336                  0.091613        0.004901
# 499                  0.172016                  0.091205        0.004269
#
#      roi_head/num_bg_samples  roi_head/num_fg_samples  rpn/num_neg_anchors  \
# 0                    230.250                   25.750              188.125
# 1                    234.250                   21.750              198.125
# 2                    235.875                   20.125              207.750
# 3                    225.000                   31.000              200.125
# 4                    227.875                   28.125              202.250
# ..                       ...                      ...                  ...
# 495                  194.750                   61.250              197.625
# 496                  193.375                   62.625              192.125
# 497                  193.250                   62.750              191.250
# 498                  196.000                   60.000              190.250
# 499                  192.875                   63.125              194.875
#
#      rpn/num_pos_anchors      time  total_loss
# 0                 67.875  2.310927    6.044488
# 1                 57.875  3.722801    2.663016
# 2                 48.250  2.269139    1.756938
# 3                 55.875  1.786999    1.920184
# 4                 53.750  2.692950    1.876845
# ..                   ...       ...         ...
# 495               58.375  5.919965    0.995338
# 496               63.875  4.313736    1.032640
# 497               64.750  4.624657    1.142327
# 498               65.750  6.381079    1.043743
# 499               61.125  4.405543    1.076042
#
# [500 rows x 22 columns]

# %%
# F1 Skoru Hesaplama
# F1 Skoru = 2 * (Precision * Recall) / (Precision + Recall)
# Precision = TP / (TP + FP)
# Recall = TP / (TP + FN)

accuracy = df['mask_rcnn/accuracy']
# FP ve FN değerlerini al
FP = df['mask_rcnn/false_positive']
FN =df['mask_rcnn/false_negative']

# TP hesaplama
TP = df['mask_rcnn/accuracy']

# Precision ve Recall hesaplama
precision = TP / (TP + FP)
recall = TP / (TP + FN)

# F1 Skoru hesaplama
f1_score = 2 * (precision * recall) / (precision + recall)

# %%
import matplotlib.pyplot as plt
#(Loss) 
plt.figure(figsize=(10, 6))
plt.plot(df['iteration'], df['total_loss'], label='Total Loss')
plt.plot(df['iteration'], df['loss_cls'], label='Classification Loss')
plt.plot(df['iteration'], df['loss_box_reg'], label='Box Regression Loss')
plt.plot(df['iteration'], df['loss_mask'], label='Mask Loss')
plt.plot(df['iteration'], df['loss_rpn_cls'], label='RPN Classification Loss')
plt.plot(df['iteration'], df['loss_rpn_loc'], label='RPN Location Loss')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.title('Loss During Training')
plt.legend()
plt.grid(True)
plt.show()

#  Mask R-CNN Accuracy, False Positive, False Negative 
plt.figure(figsize=(10, 6))
plt.plot(df['iteration'], df['mask_rcnn/accuracy'], label='Mask R-CNN Accuracy')
plt.plot(df['iteration'], df['mask_rcnn/false_positive'], label='Mask R-CNN False Positive')
plt.plot(df['iteration'], df['mask_rcnn/false_negative'], label='Mask R-CNN False Negative')
plt.xlabel('Iteration')
plt.ylabel('Accuracy / Error Rate')
plt.title('Mask R-CNN Accuracy and Error Rates')
plt.legend()
plt.grid(True)
plt.show()

# %%
#f1 score
plt.figure(figsize=(10, 6))
plt.plot(df['iteration'], f1_score, label='F1 Score', color='purple')
plt.xlabel('Iteration')
plt.ylabel('F1 Score')
plt.title('F1 Score During Training')
plt.legend()
plt.grid(True)
plt.show()

# Recall
plt.figure(figsize=(10, 6))
plt.plot(df['iteration'], recall, label='Recall', color='green')
plt.xlabel('Iteration')
plt.ylabel('Recall')
plt.title('Recall During Training')
plt.legend()
plt.grid(True)
plt.show()

# Precision
plt.figure(figsize=(10, 6))
plt.plot(df['iteration'], precision, label='Precision', color='blue')
plt.xlabel('Iteration')
plt.ylabel('Precision')
plt.title('Precision During Training')
plt.legend()
plt.grid(True)
plt.show()

# %%
df = df.assign(precision=precision, recall=recall, f1_score=f1_score, accuracy=accuracy)
result_table = df[['iteration', 'precision', 'recall', 'f1_score', 'accuracy']]
result_table
# Out:
#      iteration  precision    recall  f1_score  accuracy
# 0           19   0.656123  0.427403  0.517622  0.542927
# 1           39   0.917025  0.451661  0.605229  0.638270
# 2           59   0.945295  0.498549  0.652807  0.667980
# 3           79   0.938038  0.526518  0.674463  0.704470
# 4           99   0.936981  0.527968  0.675377  0.708328
# ..         ...        ...       ...       ...       ...
# 495       9919   0.909554  0.848870  0.878165  0.882974
# 496       9939   0.901553  0.844927  0.872322  0.875363
# 497       9959   0.903476  0.839875  0.870515  0.875188
# 498       9979   0.905551  0.835185  0.868946  0.878367
# 499       9999   0.905785  0.835998  0.869493  0.876848
#
# [500 rows x 5 columns]

# %%
import cv2
import matplotlib.pyplot as plt
from detectron2.utils.visualizer import Visualizer


# Load image
im = cv2.imread(r"C:\Users\kurt_\Downloads\hasar9.jpg")

# Make predictions using the predictor
output = predictor(im)

print(output)

# Visualize original image
plt.subplot(1, 2, 1)
plt.imshow(im[:, :, ::-1])
plt.title('Original Image')
plt.axis('off')

# Draw the predictions on the test image
v = Visualizer(im[:, :, ::-1], metadata=MetadataCatalog.get(cfg.DATASETS.TRAIN[0]), scale=1)
out = v.draw_instance_predictions(output["instances"].to("cpu"))

# Show the image with predictions
plt.subplot(1, 2, 2)
plt.imshow(out.get_image()[:, :, ::-1])
plt.title('Predicted Image')
plt.axis('off')

plt.show()
# Out:
# {'instances': Instances(num_instances=5, image_height=171, image_width=295, fields=[pred_boxes: Boxes(tensor([[205.8757,  77.5888, 267.0711,  93.0584],
#         [228.7939,  84.9257, 283.9881, 145.7936],
#         [ 64.4197,  85.1084,  81.1153, 101.8520],
#         [199.8920,  93.2682, 234.2780, 102.9096],
#         [ 75.4739, 104.5685,  80.3296, 110.9935]], device='cuda:0')), scores: tensor([0.9054, 0.8121, 0.6073, 0.6020, 0.5932], device='cuda:0'), pred_classes: tensor([2, 2, 1, 1, 1], device='cuda:0'), pred_masks: tensor([[[False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          ...,
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False]],
#
#         [[False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          ...,
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False]],
#
#         [[False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          ...,
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False]],
#
#         [[False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          ...,
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False]],
#
#         [[False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          ...,
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False]]], device='cuda:0')])}
